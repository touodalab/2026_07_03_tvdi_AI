# %%
import json
from pprint import pprint
with open("空氣品質aqi.json",encoding="utf-8") as file:
    data:dict = json.load(file)
contents:list[dict]= data['records']
pprint(contents)
# Out:
# [{'aqi': '64',
#   'co': '0.18',
#   'co_8hr': '0.1',
#   'county': '屏東縣',
#   'datacreationdate': '2024-03-15 09:00',
#   'latitude': '22.260899',
#   'longitude': '120.651472',
#   'no': '0.3',
#   'no2': '2.1',
#   'nox': '2.4',
#   'o3': '58.1',
#   'o3_8hr': '60.0',
#   'pm10': '25',
#   'pm10_avg': '25',
#   'pm2.5': '14',
#   'pm2.5_avg': '12.5',
#   'pollutant': '臭氧八小時',
#   'siteid': '313',
#   'sitename': '屏東(枋山)',
#   'so2': '0.4',
#   'so2_avg': '0',
#   'status': '普通',
#   'unit': '',
#   'winddirec': '91',
#   'windspeed': '7.3'},
#  {'aqi': '78',
#   'co': '0.76',
#   'co_8hr': '0.4',
#   'county': '新北市',
#   'datacreationdate': '2024-03-15 09:00',
#   'latitude': '24.94902778',
#   'longitude': '121.38352778',
#   'no': '25.4',
#   'no2': '24.5',
#   'nox': '50',
#   'o3': '5.4',
#   'o3_8hr': '9.8',
#   'pm10': '44',
#   'pm10_avg': '37',
#   'pm2.5': '27',
#   'pm2.5_avg': '26.6',
#   'pollutant': '細懸浮微粒',
#   'siteid': '311',
#   'sitename': '新北(樹林)',
#   'so2': '0.8',
#   'so2_avg': '0',
#   'status': '普通',
#   'unit': '',
#   'winddirec': '109',
#   'windspeed': '0'},
#  {'aqi': '94',
#   'co': '0.38',
#   'co_8hr': '0.3',
#   'county': '屏東縣',
#   'datacreationdate': '2024-03-15 09:00',
#   'latitude': '22.35222',
#   'longitude': '120.37722',
#   'no': '1.3',
#   'no2': '8',
#   'nox': '9.3',
#   'o3': '51.9',
#   'o3_8hr': '51.6',
#   'pm10': '74',
#   'pm10_avg': '67',
#   'pm2.5': '33',
#   'pm2.5_avg': '33',
#   'pollutant': '細懸浮微粒',
#   'siteid': '204',
#   'sitename': '屏東(琉球)',
#   'so2': '2.9',
#   'so2_avg': '2',
#   'status': '普通',
#   'unit': '',
#   'winddirec': '61',
#   'windspeed': '1'},
#  {'aqi': '152',
#   'co': '0.48',
#   'co_8hr': '0.4',
#   'county': '臺南市',
#   'datacreationdate': '2024-03-15 09:00',
#   'latitude': '23.17904722',
#   'longitude': '120.24583056',
#   'no': '5.1',
#   'no2': '15.7',
#   'nox': '20.8',
#   'o3': '18.2',
#   'o3_8hr': '10.6',
#   'pm10': '109',
#   'pm10_avg': '101',
#   'pm2.5': '61',
#   'pm2.5_avg': '57.2',
#   'pollutant': '細懸浮微粒',
#   'siteid': '203',
#   'sitename': '臺南(麻豆)',
#   'so2': '1.4',
#   'so2_avg': '1',
#   'status': '對所有族群不健康',
#   'unit': '',
#   'winddirec': '358',
#   'windspeed': '0.7'},
#  {'aqi': '148',
#   'co': '0.52',
#   'co_8hr': '0.4',
#   'county': '高雄市',
#   'datacreationdate': '2024-03-15 09:00',
#   'latitude': '22.87985556',
#   'longitude': '120.24535',
#   'no': '5.5',
#   'no2': '17.2',
#   'nox': '22.7',
#   'o3': '18.7',
#   'o3_8hr': '7.0',
#   'pm10': '109',
#   'pm10_avg': '100',
#   'pm2.5': '57',
#   'pm2.5_avg': '53.5',
#   'pollutant': '細懸浮微粒',
#   'siteid': '202',
#   'sitename': '高雄(湖內)',
#   'so2': '2.6',
#   'so2_avg': '1',
#   'status': '對敏感族群不健康',
#   'unit': '',
#   'winddirec': '311',
#   'windspeed': '0.9'},
#  {'aqi': '119',
#   'co': '0.54',
#   'co_8hr': '0.4',
#   'county': '彰化縣',
#   'datacreationdate': '2024-03-15 09:00',
#   'latitude': '23.96117',
#   'longitude': '120.56373',
#   'no': '4.7',
#   'no2': '14.7',
#   'nox': '19.5',
#   'o3': '21.2',
#   'o3_8hr': '10.4',
#   'pm10': '73',
#   'pm10_avg': '75',
#   'pm2.5': '41',
#   'pm2.5_avg': '42.4',
#   'pollutant': '細懸浮微粒',
#   'siteid': '201',
#   'sitename': '彰化(員林)',
#   'so2': '3',
#   'so2_avg': '2',
#   'status': '對敏感族群不健康',
#   'unit': '',
#   'winddirec': '12',
#   'windspeed': '1'},
#  {'aqi': '84',
#   'co': '0.16',
#   'co_8hr': '0.1',
#   'county': '彰化縣',
#   'datacreationdate': '2024-03-15 09:00',
#   'latitude': '23.85493056',
#   'longitude': '120.26964167',
#   'no': '4.2',
#   'no2': '9.1',
#   'nox': '13.4',
#   'o3': '29.4',
#   'o3_8hr': '36.0',
#   'pm10': '70',
#   'pm10_avg': '55',
#   'pm2.5': '34',
#   'pm2.5_avg': '28.7',
#   'pollutant': '細懸浮微粒',
#   'siteid': '85',
#   'sitename': '大城',
#   'so2': '1.1',
#   'so2_avg': '0',
#   'status': '普通',
#   'unit': '',
#   'winddirec': '60',
#   'windspeed': '2.7'},
#  {'aqi': '52',
#   'co': '0.28',
#   'co_8hr': '0.2',
#   'county': '新北市',
#   'datacreationdate': '2024-03-15 09:00',
#   'latitude': '25.29681695',
#   'longitude': '121.53656894',
#   'no': '0.5',
#   'no2': '7.8',
#   'nox': '8.3',
#   'o3': '31.6',
#   'o3_8hr': '40.9',
#   'pm10': '46',
#   'pm10_avg': '47',
#   'pm2.5': '15',
#   'pm2.5_avg': '16',
#   'pollutant': '細懸浮微粒',
#   'siteid': '84',
#   'sitename': '富貴角',
#   'so2': '0.7',
#   'so2_avg': '1',
#   'status': '普通',
#   'unit': '',
#   'winddirec': '155',
#   'windspeed': '1.3'},
#  {'aqi': '86',
#   'co': '0.28',
#   'co_8hr': '0.2',
#   'county': '雲林縣',
#   'datacreationdate': '2024-03-15 09:00',
#   'latitude': '23.753506',
#   'longitude': '120.251825',
#   'no': '',
#   'no2': '',
#   'nox': '',
#   'o3': '32.6',
#   'o3_8hr': '31.6',
#   'pm10': '78',
#   'pm10_avg': '63',
#   'pm2.5': '37',
#   'pm2.5_avg': '29.8',
#   'pollutant': '細懸浮微粒',
#   'siteid': '83',
#   'sitename': '麥寮',
#   'so2': '1.7',
#   'so2_avg': '1',
#   'status': '普通',
#   'unit': '',
#   'winddirec': '37',
#   'windspeed': '3.2'},
#  {'aqi': '55',
#   'co': '0.28',
#   'co_8hr': '0.2',
#   'county': '臺東縣',
#   'datacreationdate': '2024-03-15 09:00',
#   'latitude': '23.045083',
#   'longitude': '121.161933',
#   'no': '2.2',
#   'no2': '9',
#   'nox': '11.3',
#   'o3': '20.2',
#   'o3_8hr': '29.0',
#   'pm10': '48',
#   'pm10_avg': '34',
#   'pm2.5': '21',
#   'pm2.5_avg': '17',
#   'pollutant': '細懸浮微粒',
#   'siteid': '80',
#   'sitename': '關山',
#   'so2': '1',
#   'so2_avg': '0',
#   'status': '普通',
#   'unit': '',
#   'winddirec': '76',
#   'windspeed': '0.5'},
#  {'aqi': '65',
#   'co': '0.32',
#   'co_8hr': '0.2',
#   'county': '澎湖縣',
#   'datacreationdate': '2024-03-15 09:00',
#   'latitude': '23.569031',
#   'longitude': '119.566158',
#   'no': '1.4',
#   'no2': '9.2',
#   'nox': '10.7',
#   'o3': '44.2',
#   'o3_8hr': '46.0',
#   'pm10': '40',
#   'pm10_avg': '35',
#   'pm2.5': '27',
#   'pm2.5_avg': '21',
#   'pollutant': '細懸浮微粒',
#   'siteid': '78',
#   'sitename': '馬公',
#   'so2': '0.2',
#   'so2_avg': '0',
#   'status': '普通',
#   'unit': '',
#   'winddirec': '41',
#   'windspeed': '3.3'},
#  {'aqi': '126',
#   'co': '0.53',
#   'co_8hr': '0.4',
#   'county': '金門縣',
#   'datacreationdate': '2024-03-15 09:00',
#   'latitude': '24.432133',
#   'longitude': '118.312256',
#   'no': '2.1',
#   'no2': '18.7',
#   'nox': '20.8',
#   'o3': '13.5',
#   'o3_8hr': '21',
#   'pm10': '63',
#   'pm10_avg': '63',
#   'pm2.5': '45',
#   'pm2.5_avg': '45',
#   'pollutant': '細懸浮微粒',
#   'siteid': '77',
#   'sitename': '金門',
#   'so2': '2.7',
#   'so2_avg': '2',
#   'status': '對敏感族群不健康',
#   'unit': '',
#   'winddirec': '354',
#   'windspeed': '1.1'},
#  {'aqi': '65',
#   'co': '0.26',
#   'co_8hr': '0.3',
#   'county': '連江縣',
#   'datacreationdate': '2024-03-15 09:00',
#   'latitude': '26.15188416',
#   'longitude': '119.93149378',
#   'no': '0.7',
#   'no2': '7.8',
#   'nox': '8.6',
#   'o3': '42',
#   'o3_8hr': '38.2',
#   'pm10': '29',
#   'pm10_avg': '26',
#   'pm2.5': '18',
#   'pm2.5_avg': '21',
#   'pollutant': '細懸浮微粒',
#   'siteid': '75',
#   'sitename': '馬祖',
#   'so2': '0.8',
#   'so2_avg': '1',
#   'status': '普通',
#   'unit': '',
#   'winddirec': '337',
#   'windspeed': '1.9'},
#  {'aqi': '69',
#   'co': '0.44',
#   'co_8hr': '0.3',
#   'county': '南投縣',
#   'datacreationdate': '2024-03-15 09:00',
#   'latitude': '23.968842',
#   'longitude': '120.967903',
#   'no': '8.6',
#   'no2': '9.3',
#   'nox': '17.9',
#   'o3': '12.5',
#   'o3_8hr': '9.0',
#   'pm10': '35',
#   'pm10_avg': '30',
#   'pm2.5': '22',
#   'pm2.5_avg': '23',
#   'pollutant': '細懸浮微粒',
#   'siteid': '72',
#   'sitename': '埔里',
#   'so2': '1.3',
#   'so2_avg': '1',
#   'status': '普通',
#   'unit': '',
#   'winddirec': '207',
#   'windspeed': '0.4'},
#  {'aqi': '137',
#   'co': '0.98',
#   'co_8hr': '0.7',
#   'county': '高雄市',
#   'datacreationdate': '2024-03-15 09:00',
#   'latitude': '22.608711',
#   'longitude': '120.312017',
#   'no': '4.1',
#   'no2': '27.1',
#   'nox': '31.3',
#   'o3': '44.3',
#   'o3_8hr': '23.3',
#   'pm10': '78',
#   'pm10_avg': '84',
#   'pm2.5': '39',
#   'pm2.5_avg': '49.2',
#   'pollutant': '細懸浮微粒',
#   'siteid': '71',
#   'sitename': '復興',
#   'so2': '1.9',
#   'so2_avg': '2',
#   'status': '對敏感族群不健康',
#   'unit': '',
#   'winddirec': '131',
#   'windspeed': '0.8'},
#  {'aqi': '72',
#   'co': '2.07',
#   'co_8hr': '0.9',
#   'county': '新北市',
#   'datacreationdate': '2024-03-15 09:00',
#   'latitude': '25.017',
#   'longitude': '121.516306',
#   'no': '57.4',
#   'no2': '36.8',
#   'nox': '94.2',
#   'o3': '2.8',
#   'o3_8hr': '20.3',
#   'pm10': '56',
#   'pm10_avg': '41',
#   'pm2.5': '31',
#   'pm2.5_avg': '24',
#   'pollutant': '細懸浮微粒',
#   'siteid': '70',
#   'sitename': '永和',
#   'so2': '2.2',
#   'so2_avg': '1',
#   'status': '普通',
#   'unit': '',
#   'winddirec': '293',
#   'windspeed': '1.2'},
#  {'aqi': '101',
#   'co': '0.41',
#   'co_8hr': '0.3',
#   'county': '南投縣',
#   'datacreationdate': '2024-03-15 09:00',
#   'latitude': '23.756389',
#   'longitude': '120.677306',
#   'no': '7',
#   'no2': '13.3',
#   'nox': '20.3',
#   'o3': '15.7',
#   'o3_8hr': '11.0',
#   'pm10': '44',
#   'pm10_avg': '51',
#   'pm2.5': '31',
#   'pm2.5_avg': '35.5',
#   'pollutant': '細懸浮微粒',
#   'siteid': '69',
#   'sitename': '竹山',
#   'so2': '1.5',
#   'so2_avg': '1',
#   'status': '對敏感族群不健康',
#   'unit': '',
#   'winddirec': '21',
#   'windspeed': '1.5'},
#  {'aqi': '137',
#   'co': '2.74',
#   'co_8hr': '1.3',
#   'county': '桃園市',
#   'datacreationdate': '2024-03-15 09:00',
#   'latitude': '24.953278',
#   'longitude': '121.221667',
#   'no': '94.9',
#   'no2': '41.7',
#   'nox': '136.6',
#   'o3': '1.5',
#   'o3_8hr': '3.7',
#   'pm10': '73',
#   'pm10_avg': '71',
#   'pm2.5': '46',
#   'pm2.5_avg': '49.2',
#   'pollutant': '細懸浮微粒',
#   'siteid': '68',
#   'sitename': '中壢',
#   'so2': '3.9',
#   'so2_avg': '2',
#   'status': '對敏感族群不健康',
#   'unit': '',
#   'winddirec': '236',
#   'windspeed': '0.2'},
#  {'aqi': '75',
#   'co': '2.58',
#   'co_8hr': '1.2',
#   'county': '新北市',
#   'datacreationdate': '2024-03-15 09:00',
#   'latitude': '25.072611',
#   'longitude': '121.493806',
#   'no': '139.3',
#   'no2': '44.8',
#   'nox': '184.2',
#   'o3': '1.3',
#   'o3_8hr': '9.7',
#   'pm10': '54',
#   'pm10_avg': '42',
#   'pm2.5': '32',
#   'pm2.5_avg': '25.4',
#   'pollutant': '細懸浮微粒',
#   'siteid': '67',
#   'sitename': '三重',
#   'so2': '1.9',
#   'so2_avg': '1',
#   'status': '普通',
#   'unit': '',
#   'winddirec': '-',
#   'windspeed': '-'},
#  {'aqi': '64',
#   'co': '0.52',
#   'co_8hr': '0.4',
#   'county': '宜蘭縣',
#   'datacreationdate': '2024-03-15 09:00',
#   'latitude': '24.632203',
#   'longitude': '121.792928',
#   'no': '16.1',
#   'no2': '22',
#   'nox': '38.2',
#   'o3': '10.4',
#   'o3_8hr': '15.5',
#   'pm10': '51',
#   'pm10_avg': '40',
#   'pm2.5': '24',
#   'pm2.5_avg': '20.7',
#   'pollutant': '細懸浮微粒',
#   'siteid': '66',
#   'sitename': '冬山',
#   'so2': '0.8',
#   'so2_avg': '0',
#   'status': '普通',
#   'unit': '',
#   'winddirec': '314',
#   'windspeed': '0.7'},
#  {'aqi': '58',
#   'co': '0.43',
#   'co_8hr': '0.3',
#   'county': '宜蘭縣',
#   'datacreationdate': '2024-03-15 09:00',
#   'latitude': '24.747917',
#   'longitude': '121.746394',
#   'no': '2.3',
#   'no2': '10.6',
#   'nox': '12.9',
#   'o3': '22.3',
#   'o3_8hr': '26.7',
#   'pm10': '40',
#   'pm10_avg': '33',
#   'pm2.5': '17',
#   'pm2.5_avg': '18.2',
#   'pollutant': '細懸浮微粒',
#   'siteid': '65',
#   'sitename': '宜蘭',
#   'so2': '1.3',
#   'so2_avg': '1',
#   'status': '普通',
#   'unit': '',
#   'winddirec': '218',
#   'windspeed': '0.4'},
#  {'aqi': '54',
#   'co': '0.25',
#   'co_8hr': '0.2',
#   'county': '臺北市',
#   'datacreationdate': '2024-03-15 09:00',
#   'latitude': '25.182722',
#   'longitude': '121.529583',
#   'no': '0.4',
#   'no2': '1.8',
#   'nox': '2.3',
#   'o3': '51.8',
#   'o3_8hr': '54.7',
#   'pm10': '19',
#   'pm10_avg': '25',
#   'pm2.5': '19',
#   'pm2.5_avg': '16.6',
#   'pollutant': '細懸浮微粒',
#   'siteid': '64',
#   'sitename': '陽明',
#   'so2': '1.3',
#   'so2_avg': '1',
#   'status': '普通',
#   'unit': '',
#   'winddirec': '180',
#   'windspeed': '1.8'},
#  {'aqi': '55',
#   'co': '0.3',
#   'co_8hr': '0.2',
#   'county': '花蓮縣',
#   'datacreationdate': '2024-03-15 09:00',
#   'latitude': '23.971306',
#   'longitude': '121.599769',
#   'no': '1.9',
#   'no2': '6.3',
#   'nox': '8.3',
#   'o3': '22.7',
#   'o3_8hr': '21.6',
#   'pm10': '31',
#   'pm10_avg': '23',
#   'pm2.5': '18',
#   'pm2.5_avg': '17',
#   'pollutant': '細懸浮微粒',
#   'siteid': '63',
#   'sitename': '花蓮',
#   'so2': '0.5',
#   'so2_avg': '0',
#   'status': '普通',
#   'unit': '',
#   'winddirec': '210',
#   'windspeed': '1.8'},
#  {'aqi': '57',
#   'co': '0.38',
#   'co_8hr': '0.2',
#   'county': '臺東縣',
#   'datacreationdate': '2024-03-15 09:00',
#   'latitude': '22.755358',
#   'longitude': '121.15045',
#   'no': '1.1',
#   'no2': '10.2',
#   'nox': '11.3',
#   'o3': '35.4',
#   'o3_8hr': '42.5',
#   'pm10': '43',
#   'pm10_avg': '39',
#   'pm2.5': '17',
#   'pm2.5_avg': '17.9',
#   'pollutant': '細懸浮微粒',
#   'siteid': '62',
#   'sitename': '臺東',
#   'so2': '0.5',
#   'so2_avg': '0',
#   'status': '普通',
#   'unit': '',
#   'winddirec': '318',
#   'windspeed': '0.2'},
#  {'aqi': '67',
#   'co': '0.2',
#   'co_8hr': '0.2',
#   'county': '屏東縣',
#   'datacreationdate': '2024-03-15 09:00',
#   'latitude': '21.958069',
#   'longitude': '120.788928',
#   'no': '0.6',
#   'no2': '1',
#   'nox': '1.7',
#   'o3': '58.4',
#   'o3_8hr': '60.6',
#   'pm10': '25',
#   'pm10_avg': '27',
#   'pm2.5': '14',
#   'pm2.5_avg': '14.8',
#   'pollutant': '臭氧八小時',
#   'siteid': '61',
#   'sitename': '恆春',
#   'so2': '1.6',
#   'so2_avg': '1',
#   'status': '普通',
#   'unit': '',
#   'winddirec': '40',
#   'windspeed': '7'},
#  {'aqi': '91',
#   'co': '0.41',
#   'co_8hr': '0.4',
#   'county': '屏東縣',
#   'datacreationdate': '2024-03-15 09:00',
#   'latitude': '22.523108',
#   'longitude': '120.561175',
#   'no': '2.1',
#   'no2': '8.5',
#   'nox': '10.6',
#   'o3': '43.7',
#   'o3_8hr': '29.5',
#   'pm10': '83',
#   'pm10_avg': '62',
#   'pm2.5': '32',
#   'pm2.5_avg': '31.6',
#   'pollutant': '細懸浮微粒',
#   'siteid': '60',
#   'sitename': '潮州',
#   'so2': '1.9',
#   'so2_avg': '1',
#   'status': '普通',
#   'unit': '',
#   'winddirec': '305',
#   'windspeed': '1.6'},
#  {'aqi': '106',
#   'co': '0.59',
#   'co_8hr': '0.4',
#   'county': '屏東縣',
#   'datacreationdate': '2024-03-15 09:00',
#   'latitude': '22.673081',
#   'longitude': '120.488033',
#   'no': '3.9',
#   'no2': '17.3',
#   'nox': '21.3',
#   'o3': '34.8',
#   'o3_8hr': '29.0',
#   'pm10': '75',
#   'pm10_avg': '72',
#   'pm2.5': '34',
#   'pm2.5_avg': '37.4',
#   'pollutant': '細懸浮微粒',
#   'siteid': '59',
#   'sitename': '屏東',
#   'so2': '2.6',
#   'so2_avg': '2',
#   'status': '對敏感族群不健康',
#   'unit': '',
#   'winddirec': '269',
#   'windspeed': '0.6'},
#  {'aqi': '118',
#   'co': '0.5',
#   'co_8hr': '0.5',
#   'county': '高雄市',
#   'datacreationdate': '2024-03-15 09:00',
#   'latitude': '22.565833',
#   'longitude': '120.337736',
#   'no': '6.9',
#   'no2': '25.5',
#   'nox': '32.4',
#   'o3': '39.9',
#   'o3_8hr': '32.2',
#   'pm10': '76',
#   'pm10_avg': '77',
#   'pm2.5': '40',
#   'pm2.5_avg': '42.2',
#   'pollutant': '細懸浮微粒',
#   'siteid': '58',
#   'sitename': '小港',
#   'so2': '1.8',
#   'so2_avg': '2',
#   'status': '對敏感族群不健康',
#   'unit': '',
#   'winddirec': '307',
#   'windspeed': '1.2'},
#  {'aqi': '125',
#   'co': '0.73',
#   'co_8hr': '0.6',
#   'county': '高雄市',
#   'datacreationdate': '2024-03-15 09:00',
#   'latitude': '22.6044507',
#   'longitude': '120.30833356',
#   'no': '3.8',
#   'no2': '22.4',
#   'nox': '26.3',
#   'o3': '48.2',
#   'o3_8hr': '22.9',
#   'pm10': '79',
#   'pm10_avg': '91',
#   'pm2.5': '36',
#   'pm2.5_avg': '44.7',
#   'pollutant': '細懸浮微粒',
#   'siteid': '57',
#   'sitename': '前鎮',
#   'so2': '2.8',
#   'so2_avg': '2',
#   'status': '對敏感族群不健康',
#   'unit': '',
#   'winddirec': '338',
#   'windspeed': '0.2'},
#  {'aqi': '147',
#   'co': '0.75',
#   'co_8hr': '0.5',
#   'county': '高雄市',
#   'datacreationdate': '2024-03-15 09:00',
#   'latitude': '22.63390278',
#   'longitude': '120.28676111',
#   'no': '3.7',
#   'no2': '25.2',
#   'nox': '29',
#   'o3': '43.1',
#   'o3_8hr': '19.7',
#   'pm10': '95',
#   'pm10_avg': '102',
#   'pm2.5': '48',
#   'pm2.5_avg': '53.2',
#   'pollutant': '細懸浮微粒',
#   'siteid': '56',
#   'sitename': '前金',
#   'so2': '3',
#   'so2_avg': '1',
#   'status': '對敏感族群不健康',
#   'unit': '',
#   'winddirec': '207',
#   'windspeed': '1.5'},
#  {'aqi': '151',
#   'co': '0.76',
#   'co_8hr': '0.5',
#   'county': '高雄市',
#   'datacreationdate': '2024-03-15 09:00',
#   'latitude': '22.674861',
#   'longitude': '120.292917',
#   'no': '4.8',
#   'no2': '28.8',
#   'nox': '33.7',
#   'o3': '41.5',
#   'o3_8hr': '19.1',
#   'pm10': '83',
#   'pm10_avg': '92',
#   'pm2.5': '50',
#   'pm2.5_avg': '54.7',
#   'pollutant': '細懸浮微粒',
#   'siteid': '54',
#   'sitename': '左營',
#   'so2': '3.2',
#   'so2_avg': '1',
#   'status': '對所有族群不健康',
#   'unit': '',
#   'winddirec': '140',
#   'windspeed': '0.7'},
#  {'aqi': '130',
#   'co': '0.69',
#   'co_8hr': '0.4',
#   'county': '高雄市',
#   'datacreationdate': '2024-03-15 09:00',
#   'latitude': '22.733667',
#   'longitude': '120.328289',
#   'no': '7',
#   'no2': '31.4',
#   'nox': '38.5',
#   'o3': '29.1',
#   'o3_8hr': '17.7',
#   'pm10': '101',
#   'pm10_avg': '88',
#   'pm2.5': '42',
#   'pm2.5_avg': '46.5',
#   'pollutant': '細懸浮微粒',
#   'siteid': '53',
#   'sitename': '楠梓',
#   'so2': '1.6',
#   'so2_avg': '1',
#   'status': '對敏感族群不健康',
#   'unit': '',
#   'winddirec': '332',
#   'windspeed': '0.5'},
#  {'aqi': '127',
#   'co': '0.48',
#   'co_8hr': '0.4',
#   'county': '高雄市',
#   'datacreationdate': '2024-03-15 09:00',
#   'latitude': '22.4795',
#   'longitude': '120.41175',
#   'no': '1.8',
#   'no2': '11',
#   'nox': '12.9',
#   'o3': '42.7',
#   'o3_8hr': '27.8',
#   'pm10': '89',
#   'pm10_avg': '90',
#   'pm2.5': '43',
#   'pm2.5_avg': '45.4',
#   'pollutant': '細懸浮微粒',
#   'siteid': '52',
#   'sitename': '林園',
#   'so2': '3',
#   'so2_avg': '1',
#   'status': '對敏感族群不健康',
#   'unit': '',
#   'winddirec': '118',
#   'windspeed': '1.5'},
#  {'aqi': '133',
#   'co': '0.48',
#   'co_8hr': '0.4',
#   'county': '高雄市',
#   'datacreationdate': '2024-03-15 09:00',
#   'latitude': '22.56413611',
#   'longitude': '120.425311',
#   'no': '5',
#   'no2': '18.9',
#   'nox': '23.9',
#   'o3': '40.3',
#   'o3_8hr': '24.2',
#   'pm10': '85',
#   'pm10_avg': '80',
#   'pm2.5': '43',
#   'pm2.5_avg': '47.8',
#   'pollutant': '細懸浮微粒',
#   'siteid': '51',
#   'sitename': '大寮',
#   'so2': '6.8',
#   'so2_avg': '7',
#   'status': '對敏感族群不健康',
#   'unit': '',
#   'winddirec': '89',
#   'windspeed': '1.2'},
#  {'aqi': '120',
#   'co': '0.68',
#   'co_8hr': '0.5',
#   'county': '高雄市',
#   'datacreationdate': '2024-03-15 09:00',
#   'latitude': '22.628126',
#   'longitude': '120.357422',
#   'no': '2.5',
#   'no2': '17',
#   'nox': '19.6',
#   'o3': '43.5',
#   'o3_8hr': '31.1',
#   'pm10': '117',
#   'pm10_avg': '90',
#   'pm2.5': '34',
#   'pm2.5_avg': '42.9',
#   'pollutant': '細懸浮微粒',
#   'siteid': '50',
#   'sitename': '鳳山',
#   'so2': '3',
#   'so2_avg': '2',
#   'status': '對敏感族群不健康',
#   'unit': '',
#   'winddirec': '141',
#   'windspeed': '0.8'},
#  {'aqi': '151',
#   'co': '0.62',
#   'co_8hr': '0.5',
#   'county': '高雄市',
#   'datacreationdate': '2024-03-15 09:00',
#   'latitude': '22.689056',
#   'longitude': '120.332631',
#   'no': '3.5',
#   'no2': '23.1',
#   'nox': '26.6',
#   'o3': '42.8',
#   'o3_8hr': '13.8',
#   'pm10': '88',
#   'pm10_avg': '91',
#   'pm2.5': '52',
#   'pm2.5_avg': '55.1',
#   'pollutant': '細懸浮微粒',
#   'siteid': '49',
#   'sitename': '仁武',
#   'so2': '4',
#   'so2_avg': '1',
#   'status': '對所有族群不健康',
#   'unit': '',
#   'winddirec': '89',
#   'windspeed': '1.1'},
#  {'aqi': '138',
#   'co': '0.55',
#   'co_8hr': '0.4',
#   'county': '高雄市',
#   'datacreationdate': '2024-03-15 09:00',
#   'latitude': '22.757506',
#   'longitude': '120.305689',
#   'no': '6.5',
#   'no2': '24.3',
#   'nox': '30.9',
#   'o3': '25.3',
#   'o3_8hr': '12.9',
#   'pm10': '74',
#   'pm10_avg': '80',
#   'pm2.5': '47',
#   'pm2.5_avg': '49.7',
#   'pollutant': '細懸浮微粒',
#   'siteid': '48',
#   'sitename': '橋頭',
#   'so2': '1.6',
#   'so2_avg': '1',
#   'status': '對敏感族群不健康',
#   'unit': '',
#   'winddirec': '277',
#   'windspeed': '1.3'},
#  {'aqi': '90',
#   'co': '0.42',
#   'co_8hr': '0.3',
#   'county': '高雄市',
#   'datacreationdate': '2024-03-15 09:00',
#   'latitude': '22.883583',
#   'longitude': '120.530542',
#   'no': '1.4',
#   'no2': '9',
#   'nox': '10.5',
#   'o3': '49.3',
#   'o3_8hr': '37.7',
#   'pm10': '63',
#   'pm10_avg': '58',
#   'pm2.5': '31',
#   'pm2.5_avg': '31.5',
#   'pollutant': '細懸浮微粒',
#   'siteid': '47',
#   'sitename': '美濃',
#   'so2': '1.4',
#   'so2_avg': '0',
#   'status': '普通',
#   'unit': '',
#   'winddirec': '154',
#   'windspeed': '1'},
#  {'aqi': '155',
#   'co': '0.83',
#   'co_8hr': '0.5',
#   'county': '臺南市',
#   'datacreationdate': '2024-03-15 09:00',
#   'latitude': '22.98928311',
#   'longitude': '120.21947897',
#   'no': '16.4',
#   'no2': '30.1',
#   'nox': '46.5',
#   'o3': '13.7',
#   'o3_8hr': '7.8',
#   'pm10': '131',
#   'pm10_avg': '108',
#   'pm2.5': '85',
#   'pm2.5_avg': '62.1',
#   'pollutant': '細懸浮微粒',
#   'siteid': '46',
#   'sitename': '臺南',
#   'so2': '2.4',
#   'so2_avg': '1',
#   'status': '對所有族群不健康',
#   'unit': '',
#   'winddirec': '8',
#   'windspeed': '1.3'},
#  {'aqi': '156',
#   'co': '0.63',
#   'co_8hr': '0.4',
#   'county': '臺南市',
#   'datacreationdate': '2024-03-15 09:00',
#   'latitude': '23.048197',
#   'longitude': '120.2175',
#   'no': '11.6',
#   'no2': '23.4',
#   'nox': '35.1',
#   'o3': '13.5',
#   'o3_8hr': '9.3',
#   'pm10': '108',
#   'pm10_avg': '95',
#   'pm2.5': '75',
#   'pm2.5_avg': '64.7',
#   'pollutant': '細懸浮微粒',
#   'siteid': '45',
#   'sitename': '安南',
#   'so2': '2.1',
#   'so2_avg': '1',
#   'status': '對所有族群不健康',
#   'unit': '',
#   'winddirec': '32',
#   'windspeed': '1.3'},
#  {'aqi': '145',
#   'co': '0.45',
#   'co_8hr': '0.4',
#   'county': '臺南市',
#   'datacreationdate': '2024-03-15 09:00',
#   'latitude': '23.11337642',
#   'longitude': '120.29740529',
#   'no': '6',
#   'no2': '14.2',
#   'nox': '20.3',
#   'o3': '18.5',
#   'o3_8hr': '10.3',
#   'pm10': '112',
#   'pm10_avg': '98',
#   'pm2.5': '66',
#   'pm2.5_avg': '52.6',
#   'pollutant': '細懸浮微粒',
#   'siteid': '44',
#   'sitename': '善化',
#   'so2': '3.8',
#   'so2_avg': '1',
#   'status': '對敏感族群不健康',
#   'unit': '',
#   'winddirec': '35',
#   'windspeed': '2'},
#  {'aqi': '152',
#   'co': '0.43',
#   'co_8hr': '0.4',
#   'county': '臺南市',
#   'datacreationdate': '2024-03-15 09:00',
#   'latitude': '23.305633',
#   'longitude': '120.31725',
#   'no': '5.1',
#   'no2': '15.9',
#   'nox': '21.1',
#   'o3': '20.7',
#   'o3_8hr': '10.3',
#   'pm10': '90',
#   'pm10_avg': '89',
#   'pm2.5': '59',
#   'pm2.5_avg': '56.2',
#   'pollutant': '細懸浮微粒',
#   'siteid': '43',
#   'sitename': '新營',
#   'so2': '2.1',
#   'so2_avg': '1',
#   'status': '對所有族群不健康',
#   'unit': '',
#   'winddirec': '36',
#   'windspeed': '1.4'},
#  {'aqi': '153',
#   'co': '0.56',
#   'co_8hr': '0.4',
#   'county': '嘉義市',
#   'datacreationdate': '2024-03-15 09:00',
#   'latitude': '23.46477865',
#   'longitude': '120.44125148',
#   'no': '7.6',
#   'no2': '19.9',
#   'nox': '27.6',
#   'o3': '17.1',
#   'o3_8hr': '9.8',
#   'pm10': '91',
#   'pm10_avg': '88',
#   'pm2.5': '64',
#   'pm2.5_avg': '58.7',
#   'pollutant': '細懸浮微粒',
#   'siteid': '42',
#   'sitename': '嘉義',
#   'so2': '2.3',
#   'so2_avg': '2',
#   'status': '對所有族群不健康',
#   'unit': '',
#   'winddirec': '53',
#   'windspeed': '1.8'},
#  {'aqi': '73',
#   'co': '0.29',
#   'co_8hr': '0.2',
#   'county': '雲林縣',
#   'datacreationdate': '2024-03-15 09:00',
#   'latitude': '23.702175',
#   'longitude': '120.19933333',
#   'no': '1.7',
#   'no2': '8.9',
#   'nox': '10.6',
#   'o3': '30.1',
#   'o3_8hr': '31.1',
#   'pm10': '81',
#   'pm10_avg': '69',
#   'pm2.5': '31',
#   'pm2.5_avg': '24.5',
#   'pollutant': '細懸浮微粒',
#   'siteid': '41',
#   'sitename': '臺西',
#   'so2': '1.4',
#   'so2_avg': '1',
#   'status': '普通',
#   'unit': '',
#   'winddirec': '45',
#   'windspeed': '3.6'},
#  {'aqi': '128',
#   'co': '0.45',
#   'co_8hr': '0.3',
#   'county': '嘉義縣',
#   'datacreationdate': '2024-03-15 09:00',
#   'latitude': '23.46538',
#   'longitude': '120.2478',
#   'no': '22.1',
#   'no2': '11.1',
#   'nox': '33.2',
#   'o3': '21.6',
#   'o3_8hr': '17.1',
#   'pm10': '101',
#   'pm10_avg': '85',
#   'pm2.5': '56',
#   'pm2.5_avg': '46',
#   'pollutant': '細懸浮微粒',
#   'siteid': '40',
#   'sitename': '朴子',
#   'so2': '2.3',
#   'so2_avg': '2',
#   'status': '對敏感族群不健康',
#   'unit': '',
#   'winddirec': '13',
#   'windspeed': '0.9'},
#  {'aqi': '134',
#   'co': '0.44',
#   'co_8hr': '0.4',
#   'county': '嘉義縣',
#   'datacreationdate': '2024-03-15 09:00',
#   'latitude': '23.554839',
#   'longitude': '120.345531',
#   'no': '5.6',
#   'no2': '17.1',
#   'nox': '22.8',
#   'o3': '21.4',
#   'o3_8hr': '14.9',
#   'pm10': '102',
#   'pm10_avg': '92',
#   'pm2.5': '60',
#   'pm2.5_avg': '48.1',
#   'pollutant': '細懸浮微粒',
#   'siteid': '39',
#   'sitename': '新港',
#   'so2': '2.2',
#   'so2_avg': '2',
#   'status': '對敏感族群不健康',
#   'unit': '',
#   'winddirec': '17',
#   'windspeed': '1.9'},
#  {'aqi': '111',
#   'co': '0.36',
#   'co_8hr': '0.3',
#   'county': '雲林縣',
#   'datacreationdate': '2024-03-15 09:00',
#   'latitude': '23.757547',
#   'longitude': '120.348742',
#   'no': '2.3',
#   'no2': '10.5',
#   'nox': '12.9',
#   'o3': '27.4',
#   'o3_8hr': '20.5',
#   'pm10': '94',
#   'pm10_avg': '85',
#   'pm2.5': '56',
#   'pm2.5_avg': '39.2',
#   'pollutant': '細懸浮微粒',
#   'siteid': '38',
#   'sitename': '崙背',
#   'so2': '1.6',
#   'so2_avg': '1',
#   'status': '對敏感族群不健康',
#   'unit': '',
#   'winddirec': '116',
#   'windspeed': '1.9'},
#  {'aqi': '152',
#   'co': '0.42',
#   'co_8hr': '0.3',
#   'county': '雲林縣',
#   'datacreationdate': '2024-03-15 09:00',
#   'latitude': '23.711853',
#   'longitude': '120.544994',
#   'no': '8.1',
#   'no2': '16',
#   'nox': '24.1',
#   'o3': '15.9',
#   'o3_8hr': '8.3',
#   'pm10': '91',
#   'pm10_avg': '93',
#   'pm2.5': '53',
#   'pm2.5_avg': '55.8',
#   'pollutant': '細懸浮微粒',
#   'siteid': '37',
#   'sitename': '斗六',
#   'so2': '1.9',
#   'so2_avg': '1',
#   'status': '對所有族群不健康',
#   'unit': '',
#   'winddirec': '350',
#   'windspeed': '1.1'},
#  {'aqi': '90',
#   'co': '0.52',
#   'co_8hr': '0.4',
#   'county': '南投縣',
#   'datacreationdate': '2024-03-15 09:00',
#   'latitude': '23.913',
#   'longitude': '120.685306',
#   'no': '7.3',
#   'no2': '13.9',
#   'nox': '21.2',
#   'o3': '14.2',
#   'o3_8hr': '5.6',
#   'pm10': '63',
#   'pm10_avg': '53',
#   'pm2.5': '39',
#   'pm2.5_avg': '31.5',
#   'pollutant': '細懸浮微粒',
#   'siteid': '36',
#   'sitename': '南投',
#   'so2': '1',
#   'so2_avg': '0',
#   'status': '普通',
#   'unit': '',
#   'winddirec': '196',
#   'windspeed': '0.2'},
#  {'aqi': '102',
#   'co': '0.32',
#   'co_8hr': '0.3',
#   'county': '彰化縣',
#   'datacreationdate': '2024-03-15 09:00',
#   'latitude': '23.925175',
#   'longitude': '120.409653',
#   'no': '2.2',
#   'no2': '11.2',
#   'nox': '13.5',
#   'o3': '30.7',
#   'o3_8hr': '25.5',
#   'pm10': '94',
#   'pm10_avg': '78',
#   'pm2.5': '42',
#   'pm2.5_avg': '35.9',
#   'pollutant': '細懸浮微粒',
#   'siteid': '35',
#   'sitename': '二林',
#   'so2': '1',
#   'so2_avg': '1',
#   'status': '對敏感族群不健康',
#   'unit': '',
#   'winddirec': '32',
#   'windspeed': '2.3'},
#  {'aqi': '77',
#   'co': '0.32',
#   'co_8hr': '0.2',
#   'county': '彰化縣',
#   'datacreationdate': '2024-03-15 09:00',
#   'latitude': '24.131672',
#   'longitude': '120.469061',
#   'no': '2.6',
#   'no2': '13.5',
#   'nox': '16.2',
#   'o3': '26.5',
#   'o3_8hr': '28.4',
#   'pm10': '68',
#   'pm10_avg': '63',
#   'pm2.5': '29',
#   'pm2.5_avg': '26',
#   'pollutant': '細懸浮微粒',
#   'siteid': '34',
#   'sitename': '線西',
#   'so2': '1.2',
#   'so2_avg': '2',
#   'status': '普通',
#   'unit': '',
#   'winddirec': '35',
#   'windspeed': '0.8'},
#  {'aqi': '92',
#   'co': '0.49',
#   'co_8hr': '0.3',
#   'county': '彰化縣',
#   'datacreationdate': '2024-03-15 09:00',
#   'latitude': '24.066',
#   'longitude': '120.541519',
#   'no': '3.3',
#   'no2': '16.8',
#   'nox': '20.1',
#   'o3': '23.3',
#   'o3_8hr': '19.9',
#   'pm10': '65',
#   'pm10_avg': '65',
#   'pm2.5': '42',
#   'pm2.5_avg': '32.2',
#   'pollutant': '細懸浮微粒',
#   'siteid': '33',
#   'sitename': '彰化',
#   'so2': '1.6',
#   'so2_avg': '1',
#   'status': '普通',
#   'unit': '',
#   'winddirec': '109',
#   'windspeed': '0.6'},
#  {'aqi': '107',
#   'co': '0.59',
#   'co_8hr': '0.3',
#   'county': '臺中市',
#   'datacreationdate': '2024-03-15 09:00',
#   'latitude': '24.162197',
#   'longitude': '120.616917',
#   'no': '6.9',
#   'no2': '25.5',
#   'nox': '32.5',
#   'o3': '17.6',
#   'o3_8hr': '21.0',
#   'pm10': '83',
#   'pm10_avg': '71',
#   'pm2.5': '48',
#   'pm2.5_avg': '37.9',
#   'pollutant': '細懸浮微粒',
#   'siteid': '32',
#   'sitename': '西屯',
#   'so2': '2.2',
#   'so2_avg': '1',
#   'status': '對敏感族群不健康',
#   'unit': '',
#   'winddirec': '13',
#   'windspeed': '0.5'},
#  {'aqi': '105',
#   'co': '0.79',
#   'co_8hr': '0.4',
#   'county': '臺中市',
#   'datacreationdate': '2024-03-15 09:00',
#   'latitude': '24.151958',
#   'longitude': '120.641092',
#   'no': '7.1',
#   'no2': '23.6',
#   'nox': '30.7',
#   'o3': '16.1',
#   'o3_8hr': '22.0',
#   'pm10': '69',
#   'pm10_avg': '72',
#   'pm2.5': '35',
#   'pm2.5_avg': '37.2',
#   'pollutant': '細懸浮微粒',
#   'siteid': '31',
#   'sitename': '忠明',
#   'so2': '2.1',
#   'so2_avg': '1',
#   'status': '對敏感族群不健康',
#   'unit': '',
#   'winddirec': '39',
#   'windspeed': '0.3'},
#  {'aqi': '120',
#   'co': '0.64',
#   'co_8hr': '0.5',
#   'county': '臺中市',
#   'datacreationdate': '2024-03-15 09:00',
#   'latitude': '24.09961111',
#   'longitude': '120.67844444',
#   'no': '12.3',
#   'no2': '21.7',
#   'nox': '34',
#   'o3': '9.5',
#   'o3_8hr': '4.2',
#   'pm10': '68',
#   'pm10_avg': '61',
#   'pm2.5': '48',
#   'pm2.5_avg': '43',
#   'pollutant': '細懸浮微粒',
#   'siteid': '30',
#   'sitename': '大里',
#   'so2': '1.7',
#   'so2_avg': '1',
#   'status': '對敏感族群不健康',
#   'unit': '',
#   'winddirec': '350',
#   'windspeed': '0.7'},
#  {'aqi': '87',
#   'co': '0.46',
#   'co_8hr': '0.3',
#   'county': '臺中市',
#   'datacreationdate': '2024-03-15 09:00',
#   'latitude': '24.225628',
#   'longitude': '120.568794',
#   'no': '3.1',
#   'no2': '18',
#   'nox': '21.1',
#   'o3': '21.1',
#   'o3_8hr': '25.4',
#   'pm10': '82',
#   'pm10_avg': '70',
#   'pm2.5': '39',
#   'pm2.5_avg': '30.3',
#   'pollutant': '細懸浮微粒',
#   'siteid': '29',
#   'sitename': '沙鹿',
#   'so2': '1.3',
#   'so2_avg': '0',
#   'status': '普通',
#   'unit': '',
#   'winddirec': '309',
#   'windspeed': '1.2'},
#  {'aqi': '71',
#   'co': '0.82',
#   'co_8hr': '0.4',
#   'county': '臺中市',
#   'datacreationdate': '2024-03-15 09:00',
#   'latitude': '24.25699731',
#   'longitude': '120.74252414',
#   'no': '16.3',
#   'no2': '24.5',
#   'nox': '40.8',
#   'o3': '8.9',
#   'o3_8hr': '13.1',
#   'pm10': '44',
#   'pm10_avg': '39',
#   'pm2.5': '30',
#   'pm2.5_avg': '23.8',
#   'pollutant': '細懸浮微粒',
#   'siteid': '28',
#   'sitename': '豐原',
#   'so2': '1.2',
#   'so2_avg': '1',
#   'status': '普通',
#   'unit': '',
#   'winddirec': '303',
#   'windspeed': '0.2'},
#  {'aqi': '83',
#   'co': '0.42',
#   'co_8hr': '0.3',
#   'county': '苗栗縣',
#   'datacreationdate': '2024-03-15 09:00',
#   'latitude': '24.38248443',
#   'longitude': '120.75956754',
#   'no': '5',
#   'no2': '15.8',
#   'nox': '20.8',
#   'o3': '22.8',
#   'o3_8hr': '21.0',
#   'pm10': '38',
#   'pm10_avg': '47',
#   'pm2.5': '24',
#   'pm2.5_avg': '28.5',
#   'pollutant': '細懸浮微粒',
#   'siteid': '27',
#   'sitename': '三義',
#   'so2': '1.4',
#   'so2_avg': '1',
#   'status': '普通',
#   'unit': '',
#   'winddirec': '248',
#   'windspeed': '0.3'},
#  {'aqi': '100',
#   'co': '0.64',
#   'co_8hr': '0.3',
#   'county': '苗栗縣',
#   'datacreationdate': '2024-03-15 09:00',
#   'latitude': '24.56499183',
#   'longitude': '120.82011468',
#   'no': '8.2',
#   'no2': '19.6',
#   'nox': '27.8',
#   'o3': '8.3',
#   'o3_8hr': '8.8',
#   'pm10': '75',
#   'pm10_avg': '60',
#   'pm2.5': '42',
#   'pm2.5_avg': '35.3',
#   'pollutant': '細懸浮微粒',
#   'siteid': '26',
#   'sitename': '苗栗',
#   'so2': '1.5',
#   'so2_avg': '1',
#   'status': '普通',
#   'unit': '',
#   'winddirec': '155',
#   'windspeed': '0.9'},
#  {'aqi': '95',
#   'co': '0.74',
#   'co_8hr': '0.4',
#   'county': '苗栗縣',
#   'datacreationdate': '2024-03-15 09:00',
#   'latitude': '24.69690679',
#   'longitude': '120.89869286',
#   'no': '10.7',
#   'no2': '22.4',
#   'nox': '33.1',
#   'o3': '7.8',
#   'o3_8hr': '8',
#   'pm10': '76',
#   'pm10_avg': '57',
#   'pm2.5': '42',
#   'pm2.5_avg': '33.4',
#   'pollutant': '細懸浮微粒',
#   'siteid': '25',
#   'sitename': '頭份',
#   'so2': '2.9',
#   'so2_avg': '2',
#   'status': '普通',
#   'unit': '',
#   'winddirec': '356',
#   'windspeed': '0.6'},
#  {'aqi': '107',
#   'co': '0.88',
#   'co_8hr': '0.6',
#   'county': '新竹市',
#   'datacreationdate': '2024-03-15 09:00',
#   'latitude': '24.8056356',
#   'longitude': '120.97236752',
#   'no': '30.3',
#   'no2': '28.5',
#   'nox': '58.9',
#   'o3': '2.3',
#   'o3_8hr': '2.0',
#   'pm10': '64',
#   'pm10_avg': '55',
#   'pm2.5': '41',
#   'pm2.5_avg': '38',
#   'pollutant': '細懸浮微粒',
#   'siteid': '24',
#   'sitename': '新竹',
#   'so2': '1.4',
#   'so2_avg': '1',
#   'status': '對敏感族群不健康',
#   'unit': '',
#   'winddirec': '56',
#   'windspeed': '0.3'},
#  {'aqi': '70',
#   'co': '0.47',
#   'co_8hr': '0.3',
#   'county': '新竹縣',
#   'datacreationdate': '2024-03-15 09:00',
#   'latitude': '24.74091408',
#   'longitude': '121.08895493',
#   'no': '3.8',
#   'no2': '16',
#   'nox': '19.8',
#   'o3': '17.6',
#   'o3_8hr': '14.7',
#   'pm10': '51',
#   'pm10_avg': '35',
#   'pm2.5': '31',
#   'pm2.5_avg': '23.4',
#   'pollutant': '細懸浮微粒',
#   'siteid': '23',
#   'sitename': '竹東',
#   'so2': '2.8',
#   'so2_avg': '1',
#   'status': '普通',
#   'unit': '',
#   'winddirec': '225',
#   'windspeed': '0.2'},
#  {'aqi': '135',
#   'co': '0.56',
#   'co_8hr': '0.6',
#   'county': '新竹縣',
#   'datacreationdate': '2024-03-15 09:00',
#   'latitude': '24.90009696',
#   'longitude': '121.03886894',
#   'no': '12.3',
#   'no2': '32',
#   'nox': '44.3',
#   'o3': '5.8',
#   'o3_8hr': '2.9',
#   'pm10': '89',
#   'pm10_avg': '73',
#   'pm2.5': '49',
#   'pm2.5_avg': '48.7',
#   'pollutant': '細懸浮微粒',
#   'siteid': '22',
#   'sitename': '湖口',
#   'so2': '3.5',
#   'so2_avg': '1',
#   'status': '對敏感族群不健康',
#   'unit': '',
#   'winddirec': '174',
#   'windspeed': '0.8'},
#  {'aqi': '102',
#   'co': '0.57',
#   'co_8hr': '0.5',
#   'county': '桃園市',
#   'datacreationdate': '2024-03-15 09:00',
#   'latitude': '24.86400048',
#   'longitude': '121.21645772',
#   'no': '7.6',
#   'no2': '27.6',
#   'nox': '35.3',
#   'o3': '15',
#   'o3_8hr': '11.3',
#   'pm10': '73',
#   'pm10_avg': '59',
#   'pm2.5': '38',
#   'pm2.5_avg': '35.9',
#   'pollutant': '細懸浮微粒',
#   'siteid': '21',
#   'sitename': '龍潭',
#   'so2': '2.4',
#   'so2_avg': '1',
#   'status': '對敏感族群不健康',
#   'unit': '',
#   'winddirec': '222',
#   'windspeed': '1'},
#  {'aqi': '122',
#   'co': '0.93',
#   'co_8hr': '0.7',
#   'county': '桃園市',
#   'datacreationdate': '2024-03-15 09:00',
#   'latitude': '24.952786',
#   'longitude': '121.203986',
#   'no': '16.2',
#   'no2': '40.7',
#   'nox': '57',
#   'o3': '4.5',
#   'o3_8hr': '2.7',
#   'pm10': '71',
#   'pm10_avg': '68',
#   'pm2.5': '44',
#   'pm2.5_avg': '43.5',
#   'pollutant': '細懸浮微粒',
#   'siteid': '20',
#   'sitename': '平鎮',
#   'so2': '1.7',
#   'so2_avg': '1',
#   'status': '對敏感族群不健康',
#   'unit': '',
#   'winddirec': '147',
#   'windspeed': '0.2'},
#  {'aqi': '145',
#   'co': '0.51',
#   'co_8hr': '0.4',
#   'county': '桃園市',
#   'datacreationdate': '2024-03-15 09:00',
#   'latitude': '25.03556747',
#   'longitude': '121.08283092',
#   'no': '6.3',
#   'no2': '26.3',
#   'nox': '32.7',
#   'o3': '8.5',
#   'o3_8hr': '13.7',
#   'pm10': '91',
#   'pm10_avg': '81',
#   'pm2.5': '47',
#   'pm2.5_avg': '52.3',
#   'pollutant': '細懸浮微粒',
#   'siteid': '19',
#   'sitename': '觀音',
#   'so2': '1.7',
#   'so2_avg': '1',
#   'status': '對敏感族群不健康',
#   'unit': '',
#   'winddirec': '204',
#   'windspeed': '1.1'},
#  {'aqi': '144',
#   'co': '0.75',
#   'co_8hr': '0.5',
#   'county': '桃園市',
#   'datacreationdate': '2024-03-15 09:00',
#   'latitude': '25.06100357',
#   'longitude': '121.20251473',
#   'no': '11.4',
#   'no2': '35',
#   'nox': '46.4',
#   'o3': '2.9',
#   'o3_8hr': '12.2',
#   'pm10': '102',
#   'pm10_avg': '80',
#   'pm2.5': '60',
#   'pm2.5_avg': '52.2',
#   'pollutant': '細懸浮微粒',
#   'siteid': '18',
#   'sitename': '大園',
#   'so2': '2.9',
#   'so2_avg': '2',
#   'status': '對敏感族群不健康',
#   'unit': '',
#   'winddirec': '152',
#   'windspeed': '0.9'},
#  {'aqi': '87',
#   'co': '0.99',
#   'co_8hr': '0.6',
#   'county': '桃園市',
#   'datacreationdate': '2024-03-15 09:00',
#   'latitude': '24.9947107',
#   'longitude': '121.30500531',
#   'no': '18',
#   'no2': '34.7',
#   'nox': '52.8',
#   'o3': '4.1',
#   'o3_8hr': '6.4',
#   'pm10': '42',
#   'pm10_avg': '49',
#   'pm2.5': '25',
#   'pm2.5_avg': '30.3',
#   'pollutant': '細懸浮微粒',
#   'siteid': '17',
#   'sitename': '桃園',
#   'so2': '1.8',
#   'so2_avg': '1',
#   'status': '普通',
#   'unit': '',
#   'winddirec': '206',
#   'windspeed': '0.7'},
#  {'aqi': '80',
#   'co': '4.91',
#   'co_8hr': '1.3',
#   'county': '臺北市',
#   'datacreationdate': '2024-03-15 09:00',
#   'latitude': '25.06331455',
#   'longitude': '121.51342074',
#   'no': '198.5',
#   'no2': '39.8',
#   'nox': '238.3',
#   'o3': '1.2',
#   'o3_8hr': '16.0',
#   'pm10': '59',
#   'pm10_avg': '45',
#   'pm2.5': '37',
#   'pm2.5_avg': '27.2',
#   'pollutant': '細懸浮微粒',
#   'siteid': '16',
#   'sitename': '大同',
#   'so2': '2.6',
#   'so2_avg': '1',
#   'status': '普通',
#   'unit': '',
#   'winddirec': '-',
#   'windspeed': '-'},
#  {'aqi': '79',
#   'co': '1.02',
#   'co_8hr': '0.5',
#   'county': '臺北市',
#   'datacreationdate': '2024-03-15 09:00',
#   'latitude': '25.05',
#   'longitude': '121.578611',
#   'no': '34.9',
#   'no2': '41',
#   'nox': '75.9',
#   'o3': '3.1',
#   'o3_8hr': '18.1',
#   'pm10': '39',
#   'pm10_avg': '37',
#   'pm2.5': '29',
#   'pm2.5_avg': '26.7',
#   'pollutant': '細懸浮微粒',
#   'siteid': '15',
#   'sitename': '松山',
#   'so2': '2.1',
#   'so2_avg': '1',
#   'status': '普通',
#   'unit': '',
#   'winddirec': '300',
#   'windspeed': '0.4'},
#  {'aqi': '67',
#   'co': '0.97',
#   'co_8hr': '0.4',
#   'county': '臺北市',
#   'datacreationdate': '2024-03-15 09:00',
#   'latitude': '25.020608',
#   'longitude': '121.529556',
#   'no': '21',
#   'no2': '34.5',
#   'nox': '55.5',
#   'o3': '3.2',
#   'o3_8hr': '29.3',
#   'pm10': '41',
#   'pm10_avg': '34',
#   'pm2.5': '27',
#   'pm2.5_avg': '22',
#   'pollutant': '細懸浮微粒',
#   'siteid': '14',
#   'sitename': '古亭',
#   'so2': '1.3',
#   'so2_avg': '1',
#   'status': '普通',
#   'unit': '',
#   'winddirec': '320',
#   'windspeed': '0.7'},
#  {'aqi': '70',
#   'co': '1.31',
#   'co_8hr': '0.6',
#   'county': '臺北市',
#   'datacreationdate': '2024-03-15 09:00',
#   'latitude': '25.046503',
#   'longitude': '121.507972',
#   'no': '33.7',
#   'no2': '39.5',
#   'nox': '73.3',
#   'o3': '3.1',
#   'o3_8hr': '25.4',
#   'pm10': '49',
#   'pm10_avg': '39',
#   'pm2.5': '25',
#   'pm2.5_avg': '23.2',
#   'pollutant': '細懸浮微粒',
#   'siteid': '13',
#   'sitename': '萬華',
#   'so2': '1.2',
#   'so2_avg': '1',
#   'status': '普通',
#   'unit': '',
#   'winddirec': '296',
#   'windspeed': '0.9'},
#  {'aqi': '64',
#   'co': '1.3',
#   'co_8hr': '0.6',
#   'county': '臺北市',
#   'datacreationdate': '2024-03-15 09:00',
#   'latitude': '25.062361',
#   'longitude': '121.526528',
#   'no': '37.2',
#   'no2': '40',
#   'nox': '77.2',
#   'o3': '3',
#   'o3_8hr': '27.1',
#   'pm10': '53',
#   'pm10_avg': '40',
#   'pm2.5': '26',
#   'pm2.5_avg': '20.8',
#   'pollutant': '細懸浮微粒',
#   'siteid': '12',
#   'sitename': '中山',
#   'so2': '1.1',
#   'so2_avg': '1',
#   'status': '普通',
#   'unit': '',
#   'winddirec': '254',
#   'windspeed': '0.9'},
#  {'aqi': '62',
#   'co': '0.96',
#   'co_8hr': '0.4',
#   'county': '臺北市',
#   'datacreationdate': '2024-03-15 09:00',
#   'latitude': '25.10334003',
#   'longitude': '121.51666356',
#   'no': '35.5',
#   'no2': '42',
#   'nox': '77.6',
#   'o3': '1.8',
#   'o3_8hr': '30.1',
#   'pm10': '55',
#   'pm10_avg': '37',
#   'pm2.5': '32',
#   'pm2.5_avg': '19.8',
#   'pollutant': '細懸浮微粒',
#   'siteid': '11',
#   'sitename': '士林',
#   'so2': '1.3',
#   'so2_avg': '1',
#   'status': '普通',
#   'unit': '',
#   'winddirec': '127',
#   'windspeed': '0.7'},
#  {'aqi': '71',
#   'co': '1',
#   'co_8hr': '0.5',
#   'county': '新北市',
#   'datacreationdate': '2024-03-15 09:00',
#   'latitude': '25.1645',
#   'longitude': '121.449239',
#   'no': '20.6',
#   'no2': '32.7',
#   'nox': '53.4',
#   'o3': '3.9',
#   'o3_8hr': '26.0',
#   'pm10': '39',
#   'pm10_avg': '39',
#   'pm2.5': '21',
#   'pm2.5_avg': '23.5',
#   'pollutant': '細懸浮微粒',
#   'siteid': '10',
#   'sitename': '淡水',
#   'so2': '0.9',
#   'so2_avg': '0',
#   'status': '普通',
#   'unit': '',
#   'winddirec': '110',
#   'windspeed': '0.4'},
#  {'aqi': '60',
#   'co': '0.55',
#   'co_8hr': '0.3',
#   'county': '新北市',
#   'datacreationdate': '2024-03-15 09:00',
#   'latitude': '25.07798949',
#   'longitude': '121.36548982',
#   'no': '28.5',
#   'no2': '33.4',
#   'nox': '62',
#   'o3': '15',
#   'o3_8hr': '37.6',
#   'pm10': '41',
#   'pm10_avg': '36',
#   'pm2.5': '21',
#   'pm2.5_avg': '19',
#   'pollutant': '細懸浮微粒',
#   'siteid': '9',
#   'sitename': '林口',
#   'so2': '1.3',
#   'so2_avg': '1',
#   'status': '普通',
#   'unit': '',
#   'winddirec': '112',
#   'windspeed': '0.8'},
#  {'aqi': '78',
#   'co': '1.64',
#   'co_8hr': '0.7',
#   'county': '新北市',
#   'datacreationdate': '2024-03-15 09:00',
#   'latitude': '25.06895',
#   'longitude': '121.481028',
#   'no': '57.3',
#   'no2': '41.2',
#   'nox': '98.6',
#   'o3': '1.4',
#   'o3_8hr': '15.2',
#   'pm10': '50',
#   'pm10_avg': '42',
#   'pm2.5': '34',
#   'pm2.5_avg': '26.5',
#   'pollutant': '細懸浮微粒',
#   'siteid': '8',
#   'sitename': '菜寮',
#   'so2': '1.5',
#   'so2_avg': '1',
#   'status': '普通',
#   'unit': '',
#   'winddirec': '188',
#   'windspeed': '0.5'},
#  {'aqi': '79',
#   'co': '1.35',
#   'co_8hr': '0.6',
#   'county': '新北市',
#   'datacreationdate': '2024-03-15 09:00',
#   'latitude': '25.037972',
#   'longitude': '121.4325',
#   'no': '51.8',
#   'no2': '30.5',
#   'nox': '82.3',
#   'o3': '1.2',
#   'o3_8hr': '9.8',
#   'pm10': '62',
#   'pm10_avg': '49',
#   'pm2.5': '27',
#   'pm2.5_avg': '26.8',
#   'pollutant': '細懸浮微粒',
#   'siteid': '7',
#   'sitename': '新莊',
#   'so2': '1.4',
#   'so2_avg': '1',
#   'status': '普通',
#   'unit': '',
#   'winddirec': '253',
#   'windspeed': '0.4'},
#  {'aqi': '65',
#   'co': '0.81',
#   'co_8hr': '0.5',
#   'county': '新北市',
#   'datacreationdate': '2024-03-15 09:00',
#   'latitude': '25.012972',
#   'longitude': '121.458667',
#   'no': '17.8',
#   'no2': '34.3',
#   'nox': '52.2',
#   'o3': '3.6',
#   'o3_8hr': '12.1',
#   'pm10': '45',
#   'pm10_avg': '37',
#   'pm2.5': '21',
#   'pm2.5_avg': '21.2',
#   'pollutant': '細懸浮微粒',
#   'siteid': '6',
#   'sitename': '板橋',
#   'so2': '1.4',
#   'so2_avg': '1',
#   'status': '普通',
#   'unit': '',
#   'winddirec': '211',
#   'windspeed': '0.5'},
#  {'aqi': '73',
#   'co': '1.1',
#   'co_8hr': '0.6',
#   'county': '新北市',
#   'datacreationdate': '2024-03-15 09:00',
#   'latitude': '24.982528',
#   'longitude': '121.451861',
#   'no': '61.8',
#   'no2': '32.4',
#   'nox': '94.3',
#   'o3': '2.7',
#   'o3_8hr': '7.1',
#   'pm10': '58',
#   'pm10_avg': '40',
#   'pm2.5': '29',
#   'pm2.5_avg': '24.6',
#   'pollutant': '細懸浮微粒',
#   'siteid': '5',
#   'sitename': '土城',
#   'so2': '1.5',
#   'so2_avg': '1',
#   'status': '普通',
#   'unit': '',
#   'winddirec': '112',
#   'windspeed': '0.3'},
#  {'aqi': '65',
#   'co': '0.66',
#   'co_8hr': '0.4',
#   'county': '新北市',
#   'datacreationdate': '2024-03-15 09:00',
#   'latitude': '24.977222',
#   'longitude': '121.537778',
#   'no': '6.9',
#   'no2': '30.3',
#   'nox': '37.2',
#   'o3': '12.4',
#   'o3_8hr': '36',
#   'pm10': '35',
#   'pm10_avg': '32',
#   'pm2.5': '24',
#   'pm2.5_avg': '21',
#   'pollutant': '細懸浮微粒',
#   'siteid': '4',
#   'sitename': '新店',
#   'so2': '1.2',
#   'so2_avg': '1',
#   'status': '普通',
#   'unit': '',
#   'winddirec': '301',
#   'windspeed': '0.4'},
#  {'aqi': '49',
#   'co': '0.31',
#   'co_8hr': '0.2',
#   'county': '新北市',
#   'datacreationdate': '2024-03-15 09:00',
#   'latitude': '25.179667',
#   'longitude': '121.689881',
#   'no': '2.4',
#   'no2': '7.6',
#   'nox': '10.1',
#   'o3': '19.2',
#   'o3_8hr': '29.8',
#   'pm10': '29',
#   'pm10_avg': '27',
#   'pm2.5': '18',
#   'pm2.5_avg': '15',
#   'pollutant': '',
#   'siteid': '3',
#   'sitename': '萬里',
#   'so2': '1.3',
#   'so2_avg': '1',
#   'status': '良好',
#   'unit': '',
#   'winddirec': '223',
#   'windspeed': '2'},
#  {'aqi': '60',
#   'co': '1.19',
#   'co_8hr': '0.5',
#   'county': '新北市',
#   'datacreationdate': '2024-03-15 09:00',
#   'latitude': '25.06624',
#   'longitude': '121.64081',
#   'no': '79.1',
#   'no2': '34.7',
#   'nox': '113.8',
#   'o3': '0',
#   'o3_8hr': '4.8',
#   'pm10': '49',
#   'pm10_avg': '34',
#   'pm2.5': '23',
#   'pm2.5_avg': '19.2',
#   'pollutant': '細懸浮微粒',
#   'siteid': '2',
#   'sitename': '汐止',
#   'so2': '1.8',
#   'so2_avg': '1',
#   'status': '普通',
#   'unit': '',
#   'winddirec': '354',
#   'windspeed': '0.4'},
#  {'aqi': '59',
#   'co': '0.86',
#   'co_8hr': '0.4',
#   'county': '基隆市',
#   'datacreationdate': '2024-03-15 09:00',
#   'latitude': '25.129167',
#   'longitude': '121.760056',
#   'no': '11.9',
#   'no2': '28.9',
#   'nox': '40.8',
#   'o3': '5.2',
#   'o3_8hr': '26.7',
#   'pm10': '27',
#   'pm10_avg': '28',
#   'pm2.5': '18',
#   'pm2.5_avg': '18.8',
#   'pollutant': '細懸浮微粒',
#   'siteid': '1',
#   'sitename': '基隆',
#   'so2': '1.4',
#   'so2_avg': '1',
#   'status': '普通',
#   'unit': '',
#   'winddirec': '298',
#   'windspeed': '0.5'},
#  {'aqi': '67',
#   'co': '0.19',
#   'co_8hr': '0.1',
#   'county': '屏東縣',
#   'datacreationdate': '2024-03-15 08:00',
#   'latitude': '22.260899',
#   'longitude': '120.651472',
#   'no': '0.3',
#   'no2': '3.2',
#   'nox': '3.5',
#   'o3': '57.7',
#   'o3_8hr': '60.8',
#   'pm10': '27',
#   'pm10_avg': '26',
#   'pm2.5': '11',
#   'pm2.5_avg': '12.3',
#   'pollutant': '臭氧八小時',
#   'siteid': '313',
#   'sitename': '屏東(枋山)',
#   'so2': '0.3',
#   'so2_avg': '0',
#   'status': '普通',
#   'unit': '',
#   'winddirec': '90',
#   'windspeed': '5.2'},
#  {'aqi': '79',
#   'co': '0.64',
#   'co_8hr': '0.3',
#   'county': '新北市',
#   'datacreationdate': '2024-03-15 08:00',
#   'latitude': '24.94902778',
#   'longitude': '121.38352778',
#   'no': '20.2',
#   'no2': '22.6',
#   'nox': '42.8',
#   'o3': '6.9',
#   'o3_8hr': '11.1',
#   'pm10': '33',
#   'pm10_avg': '36',
#   'pm2.5': '22',
#   'pm2.5_avg': '26.7',
#   'pollutant': '細懸浮微粒',
#   'siteid': '311',
#   'sitename': '新北(樹林)',
#   'so2': '0.5',
#   'so2_avg': '0',
#   'status': '普通',
#   'unit': '',
#   'winddirec': '114',
#   'windspeed': '0.1'},
#  {'aqi': '94',
#   'co': '0.39',
#   'co_8hr': '0.3',
#   'county': '屏東縣',
#   'datacreationdate': '2024-03-15 08:00',
#   'latitude': '22.35222',
#   'longitude': '120.37722',
#   'no': '0.9',
#   'no2': '8.9',
#   'nox': '9.8',
#   'o3': '44.2',
#   'o3_8hr': '52.9',
#   'pm10': '63',
#   'pm10_avg': '66',
#   'pm2.5': '32',
#   'pm2.5_avg': '32.9',
#   'pollutant': '細懸浮微粒',
#   'siteid': '204',
#   'sitename': '屏東(琉球)',
#   'so2': '2.4',
#   'so2_avg': '2',
#   'status': '普通',
#   'unit': '',
#   'winddirec': '32',
#   'windspeed': '1'},
#  {'aqi': '152',
#   'co': '0.53',
#   'co_8hr': '0.4',
#   'county': '臺南市',
#   'datacreationdate': '2024-03-15 08:00',
#   'latitude': '23.17904722',
#   'longitude': '120.24583056',
#   'no': '5.2',
#   'no2': '18.3',
#   'nox': '23.6',
#   'o3': '10.2',
#   'o3_8hr': '10.8',
#   'pm10': '109',
#   'pm10_avg': '98',
#   'pm2.5': '61',
#   'pm2.5_avg': '56.2',
#   'pollutant': '細懸浮微粒',
#   'siteid': '203',
#   'sitename': '臺南(麻豆)',
#   'so2': '1.1',
#   'so2_avg': '1',
#   'status': '對所有族群不健康',
#   'unit': '',
#   'winddirec': '352',
#   'windspeed': '1.3'},
#  {'aqi': '144',
#   'co': '0.53',
#   'co_8hr': '0.4',
#   'county': '高雄市',
#   'datacreationdate': '2024-03-15 08:00',
#   'latitude': '22.87985556',
#   'longitude': '120.24535',
#   'no': '7.6',
#   'no2': '17.8',
#   'nox': '25.4',
#   'o3': '5.5',
#   'o3_8hr': '6.9',
#   'pm10': '112',
#   'pm10_avg': '97',
#   'pm2.5': '64',
#   'pm2.5_avg': '51.9',
#   'pollutant': '細懸浮微粒',
#   'siteid': '202',
#   'sitename': '高雄(湖內)',
#   'so2': '2',
#   'so2_avg': '1',
#   'status': '對敏感族群不健康',
#   'unit': '',
#   'winddirec': '51',
#   'windspeed': '1.2'},
#  {'aqi': '118',
#   'co': '0.59',
#   'co_8hr': '0.4',
#   'county': '彰化縣',
#   'datacreationdate': '2024-03-15 08:00',
#   'latitude': '23.96117',
#   'longitude': '120.56373',
#   'no': '4.2',
#   'no2': '19',
#   'nox': '23.2',
#   'o3': '14',
#   'o3_8hr': '9.1',
#   'pm10': '86',
#   'pm10_avg': '75',
#   'pm2.5': '',
#   'pm2.5_avg': '42',
#   'pollutant': '細懸浮微粒',
#   'siteid': '201',
#   'sitename': '彰化(員林)',
#   'so2': '5.8',
#   'so2_avg': '2',
#   'status': '對敏感族群不健康',
#   'unit': '',
#   'winddirec': '60',
#   'windspeed': '0.6'},
#  {'aqi': '80',
#   'co': '0.14',
#   'co_8hr': '0.1',
#   'county': '彰化縣',
#   'datacreationdate': '2024-03-15 08:00',
#   'latitude': '23.85493056',
#   'longitude': '120.26964167',
#   'no': '1.8',
#   'no2': '7.2',
#   'nox': '9',
#   'o3': '29.9',
#   'o3_8hr': '37.1',
#   'pm10': '63',
#   'pm10_avg': '51',
#   'pm2.5': '28',
#   'pm2.5_avg': '27.4',
#   'pollutant': '細懸浮微粒',
#   'siteid': '85',
#   'sitename': '大城',
#   'so2': '0.8',
#   'so2_avg': '0',
#   'status': '普通',
#   'unit': '',
#   'winddirec': '67',
#   'windspeed': '3'},
#  {'aqi': '52',
#   'co': '0.29',
#   'co_8hr': '0.2',
#   'county': '新北市',
#   'datacreationdate': '2024-03-15 08:00',
#   'latitude': '25.29681695',
#   'longitude': '121.53656894',
#   'no': '0.3',
#   'no2': '8.3',
#   'nox': '8.6',
#   'o3': '31.8',
#   'o3_8hr': '43.7',
#   'pm10': '45',
#   'pm10_avg': '46',
#   'pm2.5': '18',
#   'pm2.5_avg': '16.1',
#   'pollutant': '細懸浮微粒',
#   'siteid': '84',
#   'sitename': '富貴角',
#   'so2': '0.6',
#   'so2_avg': '1',
#   'status': '普通',
#   'unit': '',
#   'winddirec': '191',
#   'windspeed': '1'},
#  {'aqi': '84',
#   'co': '0.25',
#   'co_8hr': '0.2',
#   'county': '雲林縣',
#   'datacreationdate': '2024-03-15 08:00',
#   'latitude': '23.753506',
#   'longitude': '120.251825',
#   'no': '0.4',
#   'no2': '10.1',
#   'nox': '10.6',
#   'o3': '27.8',
#   'o3_8hr': '31.9',
#   'pm10': '73',
#   'pm10_avg': '58',
#   'pm2.5': '29',
#   'pm2.5_avg': '28.8',
#   'pollutant': '細懸浮微粒',
#   'siteid': '83',
#   'sitename': '麥寮',
#   'so2': '1.5',
#   'so2_avg': '1',
#   'status': '普通',
#   'unit': '',
#   'winddirec': '25',
#   'windspeed': '2.4'},
#  {'aqi': '53',
#   'co': '0.3',
#   'co_8hr': '0.2',
#   'county': '臺東縣',
#   'datacreationdate': '2024-03-15 08:00',
#   'latitude': '23.045083',
#   'longitude': '121.161933',
#   'no': '1.2',
#   'no2': '6.6',
#   'nox': '7.8',
#   'o3': '22.4',
#   'o3_8hr': '30.8',
#   'pm10': '37',
#   'pm10_avg': '31',
#   'pm2.5': '18',
#   'pm2.5_avg': '16.5',
#   'pollutant': '細懸浮微粒',
#   'siteid': '80',
#   'sitename': '關山',
#   'so2': '1',
#   'so2_avg': '0',
#   'status': '普通',
#   'unit': '',
#   'winddirec': '87',
#   'windspeed': '0.4'},
#  {'aqi': '62',
#   'co': '0.29',
#   'co_8hr': '0.2',
#   'county': '澎湖縣',
#   'datacreationdate': '2024-03-15 08:00',
#   'latitude': '23.569031',
#   'longitude': '119.566158',
#   'no': '0.7',
#   'no2': '6',
#   'nox': '6.8',
#   'o3': '47.2',
#   'o3_8hr': '46.6',
#   'pm10': '38',
#   'pm10_avg': '34',
#   'pm2.5': '21',
#   'pm2.5_avg': '20',
#   'pollutant': '細懸浮微粒',
#   'siteid': '78',
#   'sitename': '馬公',
#   'so2': '0.1',
#   'so2_avg': '0',
#   'status': '普通',
#   'unit': '',
#   'winddirec': '55',
#   'windspeed': '3.4'},
#  {'aqi': '126',
#   'co': '0.49',
#   'co_8hr': '0.4',
#   'county': '金門縣',
#   'datacreationdate': '2024-03-15 08:00',
#   'latitude': '24.432133',
#   'longitude': '118.312256',
#   'no': '0.9',
#   'no2': '14.2',
#   'nox': '15.2',
#   'o3': '16.7',
# ...
#   'datacreationdate': '2024-03-14 22:00',
#   'latitude': '23.46538',
#   'longitude': '120.2478',
#   'no': '0.3',
#   'no2': '7',
#   'nox': '7.3',
#   'o3': '39',
#   'o3_8hr': '52.4',
#   'pm10': '65',
#   'pm10_avg': '68',
#   'pm2.5': '35',
#   'pm2.5_avg': '36.7',
#   'pollutant': '細懸浮微粒',
#   'siteid': '40',
#   'sitename': '朴子',
#   'so2': '1.9',
#   'so2_avg': '2',
#   'status': '對敏感族群不健康',
#   'unit': '',
#   'winddirec': '60',
#   'windspeed': '0.5'},
#  {'aqi': '110',
#   'co': '0.3',
#   'co_8hr': '0.3',
#   'county': '嘉義縣',
#   'datacreationdate': '2024-03-14 22:00',
#   'latitude': '23.554839',
#   'longitude': '120.345531',
#   'no': '0.9',
#   'no2': '11.6',
#   'nox': '12.5',
#   'o3': '34.1',
#   'o3_8hr': '55.5',
#   'pm10': '75',
#   'pm10_avg': '78',
#   'pm2.5': '41',
#   'pm2.5_avg': '39',
#   'pollutant': '細懸浮微粒',
#   'siteid': '39',
#   'sitename': '新港',
#   'so2': '2.3',
#   'so2_avg': '2',
#   'status': '對敏感族群不健康',
#   'unit': '',
#   'winddirec': '8',
#   'windspeed': '1.6'},
#  {'aqi': '105',
#   'co': '0.34',
#   'co_8hr': '0.2',
#   'county': '雲林縣',
#   'datacreationdate': '2024-03-14 22:00',
#   'latitude': '23.757547',
#   'longitude': '120.348742',
#   'no': '0.8',
#   'no2': '16.3',
#   'nox': '17.2',
#   'o3': '20',
#   'o3_8hr': '41.4',
#   'pm10': '80',
#   'pm10_avg': '77',
#   'pm2.5': '38',
#   'pm2.5_avg': '37.1',
#   'pollutant': '細懸浮微粒',
#   'siteid': '38',
#   'sitename': '崙背',
#   'so2': '1.4',
#   'so2_avg': '1',
#   'status': '對敏感族群不健康',
#   'unit': '',
#   'winddirec': '33',
#   'windspeed': '1.5'},
#  {'aqi': '122',
#   'co': '0.39',
#   'co_8hr': '0.4',
#   'county': '雲林縣',
#   'datacreationdate': '2024-03-14 22:00',
#   'latitude': '23.711853',
#   'longitude': '120.544994',
#   'no': '0.4',
#   'no2': '17.3',
#   'nox': '17.7',
#   'o3': '27.5',
#   'o3_8hr': '49.3',
#   'pm10': '88',
#   'pm10_avg': '89',
#   'pm2.5': '48',
#   'pm2.5_avg': '43.6',
#   'pollutant': '細懸浮微粒',
#   'siteid': '37',
#   'sitename': '斗六',
#   'so2': '1.7',
#   'so2_avg': '1',
#   'status': '對敏感族群不健康',
#   'unit': '',
#   'winddirec': '9',
#   'windspeed': '0.8'},
#  {'aqi': '93',
#   'co': '0.56',
#   'co_8hr': '0.4',
#   'county': '南投縣',
#   'datacreationdate': '2024-03-14 22:00',
#   'latitude': '23.913',
#   'longitude': '120.685306',
#   'no': '0',
#   'no2': '28.2',
#   'nox': '27.8',
#   'o3': '12.4',
#   'o3_8hr': '42.6',
#   'pm10': '68',
#   'pm10_avg': '67',
#   'pm2.5': '39',
#   'pm2.5_avg': '32.7',
#   'pollutant': '細懸浮微粒',
#   'siteid': '36',
#   'sitename': '南投',
#   'so2': '0.8',
#   'so2_avg': '0',
#   'status': '普通',
#   'unit': '',
#   'winddirec': '199',
#   'windspeed': '0.6'},
#  {'aqi': '107',
#   'co': '0.4',
#   'co_8hr': '0.3',
#   'county': '彰化縣',
#   'datacreationdate': '2024-03-14 22:00',
#   'latitude': '23.925175',
#   'longitude': '120.409653',
#   'no': '0.1',
#   'no2': '20.7',
#   'nox': '20.9',
#   'o3': '18.7',
#   'o3_8hr': '44.6',
#   'pm10': '80',
#   'pm10_avg': '78',
#   'pm2.5': '39',
#   'pm2.5_avg': '37.7',
#   'pollutant': '細懸浮微粒',
#   'siteid': '35',
#   'sitename': '二林',
#   'so2': '2.4',
#   'so2_avg': '1',
#   'status': '對敏感族群不健康',
#   'unit': '',
#   'winddirec': '337',
#   'windspeed': '1.2'},
#  {'aqi': '80',
#   'co': '0.35',
#   'co_8hr': '0.3',
#   'county': '彰化縣',
#   'datacreationdate': '2024-03-14 22:00',
#   'latitude': '24.131672',
#   'longitude': '120.469061',
#   'no': '0.8',
#   'no2': '20',
#   'nox': '20.8',
#   'o3': '26.5',
#   'o3_8hr': '39.2',
#   'pm10': '63',
#   'pm10_avg': '60',
#   'pm2.5': '32',
#   'pm2.5_avg': '27.3',
#   'pollutant': '細懸浮微粒',
#   'siteid': '34',
#   'sitename': '線西',
#   'so2': '2.5',
#   'so2_avg': '2',
#   'status': '普通',
#   'unit': '',
#   'winddirec': '31',
#   'windspeed': '2.8'},
#  {'aqi': '86',
#   'co': '0.41',
#   'co_8hr': '0.3',
#   'county': '彰化縣',
#   'datacreationdate': '2024-03-14 22:00',
#   'latitude': '24.066',
#   'longitude': '120.541519',
#   'no': '0.8',
#   'no2': '25.1',
#   'nox': '25.9',
#   'o3': '19.5',
#   'o3_8hr': '38.5',
#   'pm10': '62',
#   'pm10_avg': '64',
#   'pm2.5': '30',
#   'pm2.5_avg': '29.9',
#   'pollutant': '細懸浮微粒',
#   'siteid': '33',
#   'sitename': '彰化',
#   'so2': '1.1',
#   'so2_avg': '1',
#   'status': '普通',
#   'unit': '',
#   'winddirec': '332',
#   'windspeed': '2.2'},
#  {'aqi': '92',
#   'co': '0.4',
#   'co_8hr': '0.3',
#   'county': '臺中市',
#   'datacreationdate': '2024-03-14 22:00',
#   'latitude': '24.162197',
#   'longitude': '120.616917',
#   'no': '1.7',
#   'no2': '20.7',
#   'nox': '22.4',
#   'o3': '23.3',
#   'o3_8hr': '43.5',
#   'pm10': '65',
#   'pm10_avg': '66',
#   'pm2.5': '32',
#   'pm2.5_avg': '32.2',
#   'pollutant': '細懸浮微粒',
#   'siteid': '32',
#   'sitename': '西屯',
#   'so2': '1.4',
#   'so2_avg': '1',
#   'status': '普通',
#   'unit': '',
#   'winddirec': '23',
#   'windspeed': '0.8'},
#  {'aqi': '92',
#   'co': '0.48',
#   'co_8hr': '0.4',
#   'county': '臺中市',
#   'datacreationdate': '2024-03-14 22:00',
#   'latitude': '24.151958',
#   'longitude': '120.641092',
#   'no': '0.9',
#   'no2': '21.9',
#   'nox': '22.8',
#   'o3': '20.4',
#   'o3_8hr': '40.9',
#   'pm10': '62',
#   'pm10_avg': '67',
#   'pm2.5': '35',
#   'pm2.5_avg': '32.3',
#   'pollutant': '細懸浮微粒',
#   'siteid': '31',
#   'sitename': '忠明',
#   'so2': '1.6',
#   'so2_avg': '1',
#   'status': '普通',
#   'unit': '',
#   'winddirec': '320',
#   'windspeed': '0.8'},
#  {'aqi': '105',
#   'co': '0.67',
#   'co_8hr': '0.5',
#   'county': '臺中市',
#   'datacreationdate': '2024-03-14 22:00',
#   'latitude': '24.09961111',
#   'longitude': '120.67844444',
#   'no': '2',
#   'no2': '33.1',
#   'nox': '35.1',
#   'o3': '9',
#   'o3_8hr': '41.7',
#   'pm10': '58',
#   'pm10_avg': '63',
#   'pm2.5': '39',
#   'pm2.5_avg': '36.9',
#   'pollutant': '細懸浮微粒',
#   'siteid': '30',
#   'sitename': '大里',
#   'so2': '1.7',
#   'so2_avg': '1',
#   'status': '對敏感族群不健康',
#   'unit': '',
#   'winddirec': '238',
#   'windspeed': '1'},
#  {'aqi': '84',
#   'co': '0.34',
#   'co_8hr': '0.2',
#   'county': '臺中市',
#   'datacreationdate': '2024-03-14 22:00',
#   'latitude': '24.225628',
#   'longitude': '120.568794',
#   'no': '1.4',
#   'no2': '16.4',
#   'nox': '17.8',
#   'o3': '25.7',
#   'o3_8hr': '42.7',
#   'pm10': '65',
#   'pm10_avg': '62',
#   'pm2.5': '31',
#   'pm2.5_avg': '29',
#   'pollutant': '細懸浮微粒',
#   'siteid': '29',
#   'sitename': '沙鹿',
#   'so2': '0.4',
#   'so2_avg': '0',
#   'status': '普通',
#   'unit': '',
#   'winddirec': '16',
#   'windspeed': '1.8'},
#  {'aqi': '91',
#   'co': '0.44',
#   'co_8hr': '0.4',
#   'county': '臺中市',
#   'datacreationdate': '2024-03-14 22:00',
#   'latitude': '24.25699731',
#   'longitude': '120.74252414',
#   'no': '0.8',
#   'no2': '15.3',
#   'nox': '16.1',
#   'o3': '26.8',
#   'o3_8hr': '41.1',
#   'pm10': '49',
#   'pm10_avg': '65',
#   'pm2.5': '26',
#   'pm2.5_avg': '31.8',
#   'pollutant': '細懸浮微粒',
#   'siteid': '28',
#   'sitename': '豐原',
#   'so2': '1.1',
#   'so2_avg': '1',
#   'status': '普通',
#   'unit': '',
#   'winddirec': '129',
#   'windspeed': '0.2'},
#  {'aqi': '87',
#   'co': '0.3',
#   'co_8hr': '0.3',
#   'county': '苗栗縣',
#   'datacreationdate': '2024-03-14 22:00',
#   'latitude': '24.38248443',
#   'longitude': '120.75956754',
#   'no': '1.3',
#   'no2': '9',
#   'nox': '10.3',
#   'o3': '23.6',
#   'o3_8hr': '42.4',
#   'pm10': '45',
#   'pm10_avg': '57',
#   'pm2.5': '27',
#   'pm2.5_avg': '30',
#   'pollutant': '細懸浮微粒',
#   'siteid': '27',
#   'sitename': '三義',
#   'so2': '1.2',
#   'so2_avg': '1',
#   'status': '普通',
#   'unit': '',
#   'winddirec': '19',
#   'windspeed': '1.1'},
#  {'aqi': '82',
#   'co': '0.33',
#   'co_8hr': '0.2',
#   'county': '苗栗縣',
#   'datacreationdate': '2024-03-14 22:00',
#   'latitude': '24.56499183',
#   'longitude': '120.82011468',
#   'no': '1',
#   'no2': '19.6',
#   'nox': '20.6',
#   'o3': '22.2',
#   'o3_8hr': '39.2',
#   'pm10': '63',
#   'pm10_avg': '59',
#   'pm2.5': '35',
#   'pm2.5_avg': '28.1',
#   'pollutant': '細懸浮微粒',
#   'siteid': '26',
#   'sitename': '苗栗',
#   'so2': '2.9',
#   'so2_avg': '1',
#   'status': '普通',
#   'unit': '',
#   'winddirec': '0',
#   'windspeed': '1.1'},
#  {'aqi': '90',
#   'co': '0.5',
#   'co_8hr': '0.3',
#   'county': '苗栗縣',
#   'datacreationdate': '2024-03-14 22:00',
#   'latitude': '24.69690679',
#   'longitude': '120.89869286',
#   'no': '2.6',
#   'no2': '33.7',
#   'nox': '36.4',
#   'o3': '9.3',
#   'o3_8hr': '37.0',
#   'pm10': '64',
#   'pm10_avg': '60',
#   'pm2.5': '32',
#   'pm2.5_avg': '31.5',
#   'pollutant': '細懸浮微粒',
#   'siteid': '25',
#   'sitename': '頭份',
#   'so2': '2.8',
#   'so2_avg': '2',
#   'status': '普通',
#   'unit': '',
#   'winddirec': '310',
#   'windspeed': '1.3'},
#  {'aqi': '102',
#   'co': '0.67',
#   'co_8hr': '0.4',
#   'county': '新竹市',
#   'datacreationdate': '2024-03-14 22:00',
#   'latitude': '24.8056356',
#   'longitude': '120.97236752',
#   'no': '0.8',
#   'no2': '32.9',
#   'nox': '33.8',
#   'o3': '18',
#   'o3_8hr': '37.2',
#   'pm10': '77',
#   'pm10_avg': '61',
#   'pm2.5': '48',
#   'pm2.5_avg': '35.9',
#   'pollutant': '細懸浮微粒',
#   'siteid': '24',
#   'sitename': '新竹',
#   'so2': '2.4',
#   'so2_avg': '1',
#   'status': '對敏感族群不健康',
#   'unit': '',
#   'winddirec': '298',
#   'windspeed': '0.3'},
#  {'aqi': '91',
#   'co': '0.38',
#   'co_8hr': '0.4',
#   'county': '新竹縣',
#   'datacreationdate': '2024-03-14 22:00',
#   'latitude': '24.74091408',
#   'longitude': '121.08895493',
#   'no': '0.9',
#   'no2': '13',
#   'nox': '14',
#   'o3': '21.5',
#   'o3_8hr': '29.6',
#   'pm10': '42',
#   'pm10_avg': '56',
#   'pm2.5': '32',
#   'pm2.5_avg': '31.9',
#   'pollutant': '細懸浮微粒',
#   'siteid': '23',
#   'sitename': '竹東',
#   'so2': '1',
#   'so2_avg': '1',
#   'status': '普通',
#   'unit': '',
#   'winddirec': '129',
#   'windspeed': '0.2'},
#  {'aqi': '106',
#   'co': '0.45',
#   'co_8hr': '0.3',
#   'county': '新竹縣',
#   'datacreationdate': '2024-03-14 22:00',
#   'latitude': '24.90009696',
#   'longitude': '121.03886894',
#   'no': '0.7',
#   'no2': '19.9',
#   'nox': '20.6',
#   'o3': '37',
#   'o3_8hr': '46.7',
#   'pm10': '76',
#   'pm10_avg': '62',
#   'pm2.5': '49',
#   'pm2.5_avg': '37.5',
#   'pollutant': '細懸浮微粒',
#   'siteid': '22',
#   'sitename': '湖口',
#   'so2': '1.9',
#   'so2_avg': '1',
#   'status': '對敏感族群不健康',
#   'unit': '',
#   'winddirec': '6',
#   'windspeed': '1.7'},
#  {'aqi': '119',
#   'co': '0.92',
#   'co_8hr': '0.6',
#   'county': '桃園市',
#   'datacreationdate': '2024-03-14 22:00',
#   'latitude': '24.86400048',
#   'longitude': '121.21645772',
#   'no': '1.9',
#   'no2': '42.6',
#   'nox': '44.6',
#   'o3': '21',
#   'o3_8hr': '39.0',
#   'pm10': '105',
#   'pm10_avg': '78',
#   'pm2.5': '60',
#   'pm2.5_avg': '42.6',
#   'pollutant': '細懸浮微粒',
#   'siteid': '21',
#   'sitename': '龍潭',
#   'so2': '3',
#   'so2_avg': '1',
#   'status': '對敏感族群不健康',
#   'unit': '',
#   'winddirec': '125',
#   'windspeed': '0.9'},
#  {'aqi': '96',
#   'co': '0.81',
#   'co_8hr': '0.6',
#   'county': '桃園市',
#   'datacreationdate': '2024-03-14 22:00',
#   'latitude': '24.952786',
#   'longitude': '121.203986',
#   'no': '1.3',
#   'no2': '48.7',
#   'nox': '50.1',
#   'o3': '23.7',
#   'o3_8hr': '40.5',
#   'pm10': '85',
#   'pm10_avg': '65',
#   'pm2.5': '46',
#   'pm2.5_avg': '33.9',
#   'pollutant': '細懸浮微粒',
#   'siteid': '20',
#   'sitename': '平鎮',
#   'so2': '2.4',
#   'so2_avg': '0',
#   'status': '普通',
#   'unit': '',
#   'winddirec': '21',
#   'windspeed': '0.9'},
#  {'aqi': '74',
#   'co': '0.28',
#   'co_8hr': '0.2',
#   'county': '桃園市',
#   'datacreationdate': '2024-03-14 22:00',
#   'latitude': '25.03556747',
#   'longitude': '121.08283092',
#   'no': '0.6',
#   'no2': '16.3',
#   'nox': '16.9',
#   'o3': '39.4',
#   'o3_8hr': '41.4',
#   'pm10': '62',
#   'pm10_avg': '50',
#   'pm2.5': '29',
#   'pm2.5_avg': '24.8',
#   'pollutant': '細懸浮微粒',
#   'siteid': '19',
#   'sitename': '觀音',
#   'so2': '1.7',
#   'so2_avg': '1',
#   'status': '普通',
#   'unit': '',
#   'winddirec': '48',
#   'windspeed': '1.6'},
#  {'aqi': '85',
#   'co': '0.44',
#   'co_8hr': '0.3',
#   'county': '桃園市',
#   'datacreationdate': '2024-03-14 22:00',
#   'latitude': '25.06100357',
#   'longitude': '121.20251473',
#   'no': '1.3',
#   'no2': '35.8',
#   'nox': '37.1',
#   'o3': '27.5',
#   'o3_8hr': '44.0',
#   'pm10': '63',
#   'pm10_avg': '56',
#   'pm2.5': '36',
#   'pm2.5_avg': '29.5',
#   'pollutant': '細懸浮微粒',
#   'siteid': '18',
#   'sitename': '大園',
#   'so2': '3.6',
#   'so2_avg': '1',
#   'status': '普通',
#   'unit': '',
#   'winddirec': '354',
#   'windspeed': '2.6'},
#  {'aqi': '109',
#   'co': '0.89',
#   'co_8hr': '0.6',
#   'county': '桃園市',
#   'datacreationdate': '2024-03-14 22:00',
#   'latitude': '24.9947107',
#   'longitude': '121.30500531',
#   'no': '1.3',
#   'no2': '42.4',
#   'nox': '43.7',
#   'o3': '17.8',
#   'o3_8hr': '47.4',
#   'pm10': '84',
#   'pm10_avg': '70',
#   'pm2.5': '55',
#   'pm2.5_avg': '38.4',
#   'pollutant': '細懸浮微粒',
#   'siteid': '17',
#   'sitename': '桃園',
#   'so2': '2',
#   'so2_avg': '1',
#   'status': '對敏感族群不健康',
#   'unit': '',
#   'winddirec': '325',
#   'windspeed': '0.5'},
#  {'aqi': '101',
#   'co': '1.27',
#   'co_8hr': '1.2',
#   'county': '臺北市',
#   'datacreationdate': '2024-03-14 22:00',
#   'latitude': '25.06331455',
#   'longitude': '121.51342074',
#   'no': '22.3',
#   'no2': '42.3',
#   'nox': '64.7',
#   'o3': '11.2',
#   'o3_8hr': '29.8',
#   'pm10': '61',
#   'pm10_avg': '68',
#   'pm2.5': '31',
#   'pm2.5_avg': '35.6',
#   'pollutant': '細懸浮微粒',
#   'siteid': '16',
#   'sitename': '大同',
#   'so2': '1.3',
#   'so2_avg': '1',
#   'status': '對敏感族群不健康',
#   'unit': '',
#   'winddirec': '-',
#   'windspeed': '-'},
#  {'aqi': '90',
#   'co': '0.54',
#   'co_8hr': '0.6',
#   'county': '臺北市',
#   'datacreationdate': '2024-03-14 22:00',
#   'latitude': '25.05',
#   'longitude': '121.578611',
#   'no': '2.7',
#   'no2': '32.9',
#   'nox': '35.7',
#   'o3': '17.6',
#   'o3_8hr': '35.5',
#   'pm10': '40',
#   'pm10_avg': '51',
#   'pm2.5': '29',
#   'pm2.5_avg': '31.5',
#   'pollutant': '細懸浮微粒',
#   'siteid': '15',
#   'sitename': '松山',
#   'so2': '1.8',
#   'so2_avg': '1',
#   'status': '普通',
#   'unit': '',
#   'winddirec': '39',
#   'windspeed': '1'},
#  {'aqi': '84',
#   'co': '0.54',
#   'co_8hr': '0.6',
#   'county': '臺北市',
#   'datacreationdate': '2024-03-14 22:00',
#   'latitude': '25.020608',
#   'longitude': '121.529556',
#   'no': '0.8',
#   'no2': '23.3',
#   'nox': '24.2',
#   'o3': '28.3',
#   'o3_8hr': '42.0',
#   'pm10': '38',
#   'pm10_avg': '49',
#   'pm2.5': '23',
#   'pm2.5_avg': '29.1',
#   'pollutant': '細懸浮微粒',
#   'siteid': '14',
#   'sitename': '古亭',
#   'so2': '0.9',
#   'so2_avg': '1',
#   'status': '普通',
#   'unit': '',
#   'winddirec': '60',
#   'windspeed': '1.5'},
#  {'aqi': '89',
#   'co': '0.89',
#   'co_8hr': '0.8',
#   'county': '臺北市',
#   'datacreationdate': '2024-03-14 22:00',
#   'latitude': '25.046503',
#   'longitude': '121.507972',
#   'no': '4.9',
#   'no2': '51.2',
#   'nox': '56.1',
#   'o3': '13.9',
#   'o3_8hr': '36.5',
#   'pm10': '49',
#   'pm10_avg': '60',
#   'pm2.5': '26',
#   'pm2.5_avg': '31',
#   'pollutant': '細懸浮微粒',
#   'siteid': '13',
#   'sitename': '萬華',
#   'so2': '1.2',
#   'so2_avg': '0',
#   'status': '普通',
#   'unit': '',
#   'winddirec': '87',
#   'windspeed': '1.8'},
#  {'aqi': '90',
#   'co': '0.61',
#   'co_8hr': '0.8',
#   'county': '臺北市',
#   'datacreationdate': '2024-03-14 22:00',
#   'latitude': '25.062361',
#   'longitude': '121.526528',
#   'no': '1.6',
#   'no2': '28.6',
#   'nox': '30.3',
#   'o3': '26.6',
#   'o3_8hr': '29.6',
#   'pm10': '42',
#   'pm10_avg': '62',
#   'pm2.5': '24',
#   'pm2.5_avg': '31.2',
#   'pollutant': '細懸浮微粒',
#   'siteid': '12',
#   'sitename': '中山',
#   'so2': '1',
#   'so2_avg': '1',
#   'status': '普通',
#   'unit': '',
#   'winddirec': '120',
#   'windspeed': '1.6'},
#  {'aqi': '79',
#   'co': '0.49',
#   'co_8hr': '0.4',
#   'county': '臺北市',
#   'datacreationdate': '2024-03-14 22:00',
#   'latitude': '25.10334003',
#   'longitude': '121.51666356',
#   'no': '1.1',
#   'no2': '24.7',
#   'nox': '25.8',
#   'o3': '26.1',
#   'o3_8hr': '44.7',
#   'pm10': '42',
#   'pm10_avg': '57',
#   'pm2.5': '15',
#   'pm2.5_avg': '27',
#   'pollutant': '細懸浮微粒',
#   'siteid': '11',
#   'sitename': '士林',
#   'so2': '1.2',
#   'so2_avg': '1',
#   'status': '普通',
#   'unit': '',
#   'winddirec': '127',
#   'windspeed': '1.1'},
#  {'aqi': '86',
#   'co': '0.77',
#   'co_8hr': '0.4',
#   'county': '新北市',
#   'datacreationdate': '2024-03-14 22:00',
#   'latitude': '25.1645',
#   'longitude': '121.449239',
#   'no': '1',
#   'no2': '32',
#   'nox': '33.1',
#   'o3': '17.7',
#   'o3_8hr': '50.0',
#   'pm10': '59',
#   'pm10_avg': '55',
#   'pm2.5': '38',
#   'pm2.5_avg': '29.7',
#   'pollutant': '細懸浮微粒',
#   'siteid': '10',
#   'sitename': '淡水',
#   'so2': '0.8',
#   'so2_avg': '0',
#   'status': '普通',
#   'unit': '',
#   'winddirec': '40',
#   'windspeed': '0.4'},
#  {'aqi': '96',
#   'co': '0.78',
#   'co_8hr': '0.4',
#   'county': '新北市',
#   'datacreationdate': '2024-03-14 22:00',
#   'latitude': '25.07798949',
#   'longitude': '121.36548982',
#   'no': '1.5',
#   'no2': '39.4',
#   'nox': '40.9',
#   'o3': '21.4',
#   'o3_8hr': '54.9',
#   'pm10': '64',
#   'pm10_avg': '62',
#   'pm2.5': '36',
#   'pm2.5_avg': '33.8',
#   'pollutant': '細懸浮微粒',
#   'siteid': '9',
#   'sitename': '林口',
#   'so2': '2.2',
#   'so2_avg': '1',
#   'status': '普通',
#   'unit': '',
#   'winddirec': '93',
#   'windspeed': '1.5'}]

# %% [markdown]
# [{'aqi': '64',
#   'co': '0.18',
#   'co_8hr': '0.1',
#   'county': '屏東縣',
#   'datacreationdate': '2024-03-15 09:00',
#   'latitude': '22.260899',
#   'longitude': '120.651472',
#   'no': '0.3',
#   'no2': '2.1',
#   'nox': '2.4',
#   'o3': '58.1',
#   'o3_8hr': '60.0',
#   'pm10': '25',
#   'pm10_avg': '25',
#   'pm2.5': '14',
#   'pm2.5_avg': '12.5',
#   'pollutant': '臭氧八小時',
#   'siteid': '313',
#   'sitename': '屏東(枋山)',
#   'so2': '0.4',
#   'so2_avg': '0',
#   'status': '普通',
#   'unit': '',
#   'winddirec': '91'
#   'windspeed': '7.3'},

# %%
from pydantic import BaseModel,Field,field_validator
from datetime import datetime

class AirSite(BaseModel):
    aqi:int
    county:str
    date:datetime = Field(alias="datacreationdate")
    lat:float = Field(alias = "latitude")
    lon:float = Field(alias="longitude")
    pm25:float = Field(alias="pm2.5")
    pollutant:str 
    site_name:str = Field(alias="sitename")
    status:str  

    @field_validator('aqi','lat','lon','pm25', mode='before')
    @classmethod
    def empty_to_zero(cls, v):
        return 0 if v == '' else v

# %%
class Root(BaseModel):
    status:bool = True
    sites:list[AirSite]

# %%
root = Root(sites=[AirSite(**item) for item in contents])

# %%
for site in root.sites:
    print(site)
# Out:
# aqi=64 county='屏東縣' date=datetime.datetime(2024, 3, 15, 9, 0) lat=22.260899 lon=120.651472 pm25=14.0 pollutant='臭氧八小時' site_name='屏東(枋山)' status='普通'
# aqi=78 county='新北市' date=datetime.datetime(2024, 3, 15, 9, 0) lat=24.94902778 lon=121.38352778 pm25=27.0 pollutant='細懸浮微粒' site_name='新北(樹林)' status='普通'
# aqi=94 county='屏東縣' date=datetime.datetime(2024, 3, 15, 9, 0) lat=22.35222 lon=120.37722 pm25=33.0 pollutant='細懸浮微粒' site_name='屏東(琉球)' status='普通'
# aqi=152 county='臺南市' date=datetime.datetime(2024, 3, 15, 9, 0) lat=23.17904722 lon=120.24583056 pm25=61.0 pollutant='細懸浮微粒' site_name='臺南(麻豆)' status='對所有族群不健康'
# aqi=148 county='高雄市' date=datetime.datetime(2024, 3, 15, 9, 0) lat=22.87985556 lon=120.24535 pm25=57.0 pollutant='細懸浮微粒' site_name='高雄(湖內)' status='對敏感族群不健康'
# aqi=119 county='彰化縣' date=datetime.datetime(2024, 3, 15, 9, 0) lat=23.96117 lon=120.56373 pm25=41.0 pollutant='細懸浮微粒' site_name='彰化(員林)' status='對敏感族群不健康'
# aqi=84 county='彰化縣' date=datetime.datetime(2024, 3, 15, 9, 0) lat=23.85493056 lon=120.26964167 pm25=34.0 pollutant='細懸浮微粒' site_name='大城' status='普通'
# aqi=52 county='新北市' date=datetime.datetime(2024, 3, 15, 9, 0) lat=25.29681695 lon=121.53656894 pm25=15.0 pollutant='細懸浮微粒' site_name='富貴角' status='普通'
# aqi=86 county='雲林縣' date=datetime.datetime(2024, 3, 15, 9, 0) lat=23.753506 lon=120.251825 pm25=37.0 pollutant='細懸浮微粒' site_name='麥寮' status='普通'
# aqi=55 county='臺東縣' date=datetime.datetime(2024, 3, 15, 9, 0) lat=23.045083 lon=121.161933 pm25=21.0 pollutant='細懸浮微粒' site_name='關山' status='普通'
# aqi=65 county='澎湖縣' date=datetime.datetime(2024, 3, 15, 9, 0) lat=23.569031 lon=119.566158 pm25=27.0 pollutant='細懸浮微粒' site_name='馬公' status='普通'
# aqi=126 county='金門縣' date=datetime.datetime(2024, 3, 15, 9, 0) lat=24.432133 lon=118.312256 pm25=45.0 pollutant='細懸浮微粒' site_name='金門' status='對敏感族群不健康'
# aqi=65 county='連江縣' date=datetime.datetime(2024, 3, 15, 9, 0) lat=26.15188416 lon=119.93149378 pm25=18.0 pollutant='細懸浮微粒' site_name='馬祖' status='普通'
# aqi=69 county='南投縣' date=datetime.datetime(2024, 3, 15, 9, 0) lat=23.968842 lon=120.967903 pm25=22.0 pollutant='細懸浮微粒' site_name='埔里' status='普通'
# aqi=137 county='高雄市' date=datetime.datetime(2024, 3, 15, 9, 0) lat=22.608711 lon=120.312017 pm25=39.0 pollutant='細懸浮微粒' site_name='復興' status='對敏感族群不健康'
# aqi=72 county='新北市' date=datetime.datetime(2024, 3, 15, 9, 0) lat=25.017 lon=121.516306 pm25=31.0 pollutant='細懸浮微粒' site_name='永和' status='普通'
# aqi=101 county='南投縣' date=datetime.datetime(2024, 3, 15, 9, 0) lat=23.756389 lon=120.677306 pm25=31.0 pollutant='細懸浮微粒' site_name='竹山' status='對敏感族群不健康'
# aqi=137 county='桃園市' date=datetime.datetime(2024, 3, 15, 9, 0) lat=24.953278 lon=121.221667 pm25=46.0 pollutant='細懸浮微粒' site_name='中壢' status='對敏感族群不健康'
# aqi=75 county='新北市' date=datetime.datetime(2024, 3, 15, 9, 0) lat=25.072611 lon=121.493806 pm25=32.0 pollutant='細懸浮微粒' site_name='三重' status='普通'
# aqi=64 county='宜蘭縣' date=datetime.datetime(2024, 3, 15, 9, 0) lat=24.632203 lon=121.792928 pm25=24.0 pollutant='細懸浮微粒' site_name='冬山' status='普通'
# aqi=58 county='宜蘭縣' date=datetime.datetime(2024, 3, 15, 9, 0) lat=24.747917 lon=121.746394 pm25=17.0 pollutant='細懸浮微粒' site_name='宜蘭' status='普通'
# aqi=54 county='臺北市' date=datetime.datetime(2024, 3, 15, 9, 0) lat=25.182722 lon=121.529583 pm25=19.0 pollutant='細懸浮微粒' site_name='陽明' status='普通'
# aqi=55 county='花蓮縣' date=datetime.datetime(2024, 3, 15, 9, 0) lat=23.971306 lon=121.599769 pm25=18.0 pollutant='細懸浮微粒' site_name='花蓮' status='普通'
# aqi=57 county='臺東縣' date=datetime.datetime(2024, 3, 15, 9, 0) lat=22.755358 lon=121.15045 pm25=17.0 pollutant='細懸浮微粒' site_name='臺東' status='普通'
# aqi=67 county='屏東縣' date=datetime.datetime(2024, 3, 15, 9, 0) lat=21.958069 lon=120.788928 pm25=14.0 pollutant='臭氧八小時' site_name='恆春' status='普通'
# aqi=91 county='屏東縣' date=datetime.datetime(2024, 3, 15, 9, 0) lat=22.523108 lon=120.561175 pm25=32.0 pollutant='細懸浮微粒' site_name='潮州' status='普通'
# aqi=106 county='屏東縣' date=datetime.datetime(2024, 3, 15, 9, 0) lat=22.673081 lon=120.488033 pm25=34.0 pollutant='細懸浮微粒' site_name='屏東' status='對敏感族群不健康'
# aqi=118 county='高雄市' date=datetime.datetime(2024, 3, 15, 9, 0) lat=22.565833 lon=120.337736 pm25=40.0 pollutant='細懸浮微粒' site_name='小港' status='對敏感族群不健康'
# aqi=125 county='高雄市' date=datetime.datetime(2024, 3, 15, 9, 0) lat=22.6044507 lon=120.30833356 pm25=36.0 pollutant='細懸浮微粒' site_name='前鎮' status='對敏感族群不健康'
# aqi=147 county='高雄市' date=datetime.datetime(2024, 3, 15, 9, 0) lat=22.63390278 lon=120.28676111 pm25=48.0 pollutant='細懸浮微粒' site_name='前金' status='對敏感族群不健康'
# aqi=151 county='高雄市' date=datetime.datetime(2024, 3, 15, 9, 0) lat=22.674861 lon=120.292917 pm25=50.0 pollutant='細懸浮微粒' site_name='左營' status='對所有族群不健康'
# aqi=130 county='高雄市' date=datetime.datetime(2024, 3, 15, 9, 0) lat=22.733667 lon=120.328289 pm25=42.0 pollutant='細懸浮微粒' site_name='楠梓' status='對敏感族群不健康'
# aqi=127 county='高雄市' date=datetime.datetime(2024, 3, 15, 9, 0) lat=22.4795 lon=120.41175 pm25=43.0 pollutant='細懸浮微粒' site_name='林園' status='對敏感族群不健康'
# aqi=133 county='高雄市' date=datetime.datetime(2024, 3, 15, 9, 0) lat=22.56413611 lon=120.425311 pm25=43.0 pollutant='細懸浮微粒' site_name='大寮' status='對敏感族群不健康'
# aqi=120 county='高雄市' date=datetime.datetime(2024, 3, 15, 9, 0) lat=22.628126 lon=120.357422 pm25=34.0 pollutant='細懸浮微粒' site_name='鳳山' status='對敏感族群不健康'
# aqi=151 county='高雄市' date=datetime.datetime(2024, 3, 15, 9, 0) lat=22.689056 lon=120.332631 pm25=52.0 pollutant='細懸浮微粒' site_name='仁武' status='對所有族群不健康'
# aqi=138 county='高雄市' date=datetime.datetime(2024, 3, 15, 9, 0) lat=22.757506 lon=120.305689 pm25=47.0 pollutant='細懸浮微粒' site_name='橋頭' status='對敏感族群不健康'
# aqi=90 county='高雄市' date=datetime.datetime(2024, 3, 15, 9, 0) lat=22.883583 lon=120.530542 pm25=31.0 pollutant='細懸浮微粒' site_name='美濃' status='普通'
# aqi=155 county='臺南市' date=datetime.datetime(2024, 3, 15, 9, 0) lat=22.98928311 lon=120.21947897 pm25=85.0 pollutant='細懸浮微粒' site_name='臺南' status='對所有族群不健康'
# aqi=156 county='臺南市' date=datetime.datetime(2024, 3, 15, 9, 0) lat=23.048197 lon=120.2175 pm25=75.0 pollutant='細懸浮微粒' site_name='安南' status='對所有族群不健康'
# aqi=145 county='臺南市' date=datetime.datetime(2024, 3, 15, 9, 0) lat=23.11337642 lon=120.29740529 pm25=66.0 pollutant='細懸浮微粒' site_name='善化' status='對敏感族群不健康'
# aqi=152 county='臺南市' date=datetime.datetime(2024, 3, 15, 9, 0) lat=23.305633 lon=120.31725 pm25=59.0 pollutant='細懸浮微粒' site_name='新營' status='對所有族群不健康'
# aqi=153 county='嘉義市' date=datetime.datetime(2024, 3, 15, 9, 0) lat=23.46477865 lon=120.44125148 pm25=64.0 pollutant='細懸浮微粒' site_name='嘉義' status='對所有族群不健康'
# aqi=73 county='雲林縣' date=datetime.datetime(2024, 3, 15, 9, 0) lat=23.702175 lon=120.19933333 pm25=31.0 pollutant='細懸浮微粒' site_name='臺西' status='普通'
# aqi=128 county='嘉義縣' date=datetime.datetime(2024, 3, 15, 9, 0) lat=23.46538 lon=120.2478 pm25=56.0 pollutant='細懸浮微粒' site_name='朴子' status='對敏感族群不健康'
# aqi=134 county='嘉義縣' date=datetime.datetime(2024, 3, 15, 9, 0) lat=23.554839 lon=120.345531 pm25=60.0 pollutant='細懸浮微粒' site_name='新港' status='對敏感族群不健康'
# aqi=111 county='雲林縣' date=datetime.datetime(2024, 3, 15, 9, 0) lat=23.757547 lon=120.348742 pm25=56.0 pollutant='細懸浮微粒' site_name='崙背' status='對敏感族群不健康'
# aqi=152 county='雲林縣' date=datetime.datetime(2024, 3, 15, 9, 0) lat=23.711853 lon=120.544994 pm25=53.0 pollutant='細懸浮微粒' site_name='斗六' status='對所有族群不健康'
# aqi=90 county='南投縣' date=datetime.datetime(2024, 3, 15, 9, 0) lat=23.913 lon=120.685306 pm25=39.0 pollutant='細懸浮微粒' site_name='南投' status='普通'
# aqi=102 county='彰化縣' date=datetime.datetime(2024, 3, 15, 9, 0) lat=23.925175 lon=120.409653 pm25=42.0 pollutant='細懸浮微粒' site_name='二林' status='對敏感族群不健康'
# aqi=77 county='彰化縣' date=datetime.datetime(2024, 3, 15, 9, 0) lat=24.131672 lon=120.469061 pm25=29.0 pollutant='細懸浮微粒' site_name='線西' status='普通'
# aqi=92 county='彰化縣' date=datetime.datetime(2024, 3, 15, 9, 0) lat=24.066 lon=120.541519 pm25=42.0 pollutant='細懸浮微粒' site_name='彰化' status='普通'
# aqi=107 county='臺中市' date=datetime.datetime(2024, 3, 15, 9, 0) lat=24.162197 lon=120.616917 pm25=48.0 pollutant='細懸浮微粒' site_name='西屯' status='對敏感族群不健康'
# aqi=105 county='臺中市' date=datetime.datetime(2024, 3, 15, 9, 0) lat=24.151958 lon=120.641092 pm25=35.0 pollutant='細懸浮微粒' site_name='忠明' status='對敏感族群不健康'
# aqi=120 county='臺中市' date=datetime.datetime(2024, 3, 15, 9, 0) lat=24.09961111 lon=120.67844444 pm25=48.0 pollutant='細懸浮微粒' site_name='大里' status='對敏感族群不健康'
# aqi=87 county='臺中市' date=datetime.datetime(2024, 3, 15, 9, 0) lat=24.225628 lon=120.568794 pm25=39.0 pollutant='細懸浮微粒' site_name='沙鹿' status='普通'
# aqi=71 county='臺中市' date=datetime.datetime(2024, 3, 15, 9, 0) lat=24.25699731 lon=120.74252414 pm25=30.0 pollutant='細懸浮微粒' site_name='豐原' status='普通'
# aqi=83 county='苗栗縣' date=datetime.datetime(2024, 3, 15, 9, 0) lat=24.38248443 lon=120.75956754 pm25=24.0 pollutant='細懸浮微粒' site_name='三義' status='普通'
# aqi=100 county='苗栗縣' date=datetime.datetime(2024, 3, 15, 9, 0) lat=24.56499183 lon=120.82011468 pm25=42.0 pollutant='細懸浮微粒' site_name='苗栗' status='普通'
# aqi=95 county='苗栗縣' date=datetime.datetime(2024, 3, 15, 9, 0) lat=24.69690679 lon=120.89869286 pm25=42.0 pollutant='細懸浮微粒' site_name='頭份' status='普通'
# aqi=107 county='新竹市' date=datetime.datetime(2024, 3, 15, 9, 0) lat=24.8056356 lon=120.97236752 pm25=41.0 pollutant='細懸浮微粒' site_name='新竹' status='對敏感族群不健康'
# aqi=70 county='新竹縣' date=datetime.datetime(2024, 3, 15, 9, 0) lat=24.74091408 lon=121.08895493 pm25=31.0 pollutant='細懸浮微粒' site_name='竹東' status='普通'
# aqi=135 county='新竹縣' date=datetime.datetime(2024, 3, 15, 9, 0) lat=24.90009696 lon=121.03886894 pm25=49.0 pollutant='細懸浮微粒' site_name='湖口' status='對敏感族群不健康'
# aqi=102 county='桃園市' date=datetime.datetime(2024, 3, 15, 9, 0) lat=24.86400048 lon=121.21645772 pm25=38.0 pollutant='細懸浮微粒' site_name='龍潭' status='對敏感族群不健康'
# aqi=122 county='桃園市' date=datetime.datetime(2024, 3, 15, 9, 0) lat=24.952786 lon=121.203986 pm25=44.0 pollutant='細懸浮微粒' site_name='平鎮' status='對敏感族群不健康'
# aqi=145 county='桃園市' date=datetime.datetime(2024, 3, 15, 9, 0) lat=25.03556747 lon=121.08283092 pm25=47.0 pollutant='細懸浮微粒' site_name='觀音' status='對敏感族群不健康'
# aqi=144 county='桃園市' date=datetime.datetime(2024, 3, 15, 9, 0) lat=25.06100357 lon=121.20251473 pm25=60.0 pollutant='細懸浮微粒' site_name='大園' status='對敏感族群不健康'
# aqi=87 county='桃園市' date=datetime.datetime(2024, 3, 15, 9, 0) lat=24.9947107 lon=121.30500531 pm25=25.0 pollutant='細懸浮微粒' site_name='桃園' status='普通'
# aqi=80 county='臺北市' date=datetime.datetime(2024, 3, 15, 9, 0) lat=25.06331455 lon=121.51342074 pm25=37.0 pollutant='細懸浮微粒' site_name='大同' status='普通'
# aqi=79 county='臺北市' date=datetime.datetime(2024, 3, 15, 9, 0) lat=25.05 lon=121.578611 pm25=29.0 pollutant='細懸浮微粒' site_name='松山' status='普通'
# aqi=67 county='臺北市' date=datetime.datetime(2024, 3, 15, 9, 0) lat=25.020608 lon=121.529556 pm25=27.0 pollutant='細懸浮微粒' site_name='古亭' status='普通'
# aqi=70 county='臺北市' date=datetime.datetime(2024, 3, 15, 9, 0) lat=25.046503 lon=121.507972 pm25=25.0 pollutant='細懸浮微粒' site_name='萬華' status='普通'
# aqi=64 county='臺北市' date=datetime.datetime(2024, 3, 15, 9, 0) lat=25.062361 lon=121.526528 pm25=26.0 pollutant='細懸浮微粒' site_name='中山' status='普通'
# aqi=62 county='臺北市' date=datetime.datetime(2024, 3, 15, 9, 0) lat=25.10334003 lon=121.51666356 pm25=32.0 pollutant='細懸浮微粒' site_name='士林' status='普通'
# aqi=71 county='新北市' date=datetime.datetime(2024, 3, 15, 9, 0) lat=25.1645 lon=121.449239 pm25=21.0 pollutant='細懸浮微粒' site_name='淡水' status='普通'
# aqi=60 county='新北市' date=datetime.datetime(2024, 3, 15, 9, 0) lat=25.07798949 lon=121.36548982 pm25=21.0 pollutant='細懸浮微粒' site_name='林口' status='普通'
# aqi=78 county='新北市' date=datetime.datetime(2024, 3, 15, 9, 0) lat=25.06895 lon=121.481028 pm25=34.0 pollutant='細懸浮微粒' site_name='菜寮' status='普通'
# aqi=79 county='新北市' date=datetime.datetime(2024, 3, 15, 9, 0) lat=25.037972 lon=121.4325 pm25=27.0 pollutant='細懸浮微粒' site_name='新莊' status='普通'
# aqi=65 county='新北市' date=datetime.datetime(2024, 3, 15, 9, 0) lat=25.012972 lon=121.458667 pm25=21.0 pollutant='細懸浮微粒' site_name='板橋' status='普通'
# aqi=73 county='新北市' date=datetime.datetime(2024, 3, 15, 9, 0) lat=24.982528 lon=121.451861 pm25=29.0 pollutant='細懸浮微粒' site_name='土城' status='普通'
# aqi=65 county='新北市' date=datetime.datetime(2024, 3, 15, 9, 0) lat=24.977222 lon=121.537778 pm25=24.0 pollutant='細懸浮微粒' site_name='新店' status='普通'
# aqi=49 county='新北市' date=datetime.datetime(2024, 3, 15, 9, 0) lat=25.179667 lon=121.689881 pm25=18.0 pollutant='' site_name='萬里' status='良好'
# aqi=60 county='新北市' date=datetime.datetime(2024, 3, 15, 9, 0) lat=25.06624 lon=121.64081 pm25=23.0 pollutant='細懸浮微粒' site_name='汐止' status='普通'
# aqi=59 county='基隆市' date=datetime.datetime(2024, 3, 15, 9, 0) lat=25.129167 lon=121.760056 pm25=18.0 pollutant='細懸浮微粒' site_name='基隆' status='普通'
# aqi=67 county='屏東縣' date=datetime.datetime(2024, 3, 15, 8, 0) lat=22.260899 lon=120.651472 pm25=11.0 pollutant='臭氧八小時' site_name='屏東(枋山)' status='普通'
# aqi=79 county='新北市' date=datetime.datetime(2024, 3, 15, 8, 0) lat=24.94902778 lon=121.38352778 pm25=22.0 pollutant='細懸浮微粒' site_name='新北(樹林)' status='普通'
# aqi=94 county='屏東縣' date=datetime.datetime(2024, 3, 15, 8, 0) lat=22.35222 lon=120.37722 pm25=32.0 pollutant='細懸浮微粒' site_name='屏東(琉球)' status='普通'
# aqi=152 county='臺南市' date=datetime.datetime(2024, 3, 15, 8, 0) lat=23.17904722 lon=120.24583056 pm25=61.0 pollutant='細懸浮微粒' site_name='臺南(麻豆)' status='對所有族群不健康'
# aqi=144 county='高雄市' date=datetime.datetime(2024, 3, 15, 8, 0) lat=22.87985556 lon=120.24535 pm25=64.0 pollutant='細懸浮微粒' site_name='高雄(湖內)' status='對敏感族群不健康'
# aqi=118 county='彰化縣' date=datetime.datetime(2024, 3, 15, 8, 0) lat=23.96117 lon=120.56373 pm25=0.0 pollutant='細懸浮微粒' site_name='彰化(員林)' status='對敏感族群不健康'
# aqi=80 county='彰化縣' date=datetime.datetime(2024, 3, 15, 8, 0) lat=23.85493056 lon=120.26964167 pm25=28.0 pollutant='細懸浮微粒' site_name='大城' status='普通'
# aqi=52 county='新北市' date=datetime.datetime(2024, 3, 15, 8, 0) lat=25.29681695 lon=121.53656894 pm25=18.0 pollutant='細懸浮微粒' site_name='富貴角' status='普通'
# aqi=84 county='雲林縣' date=datetime.datetime(2024, 3, 15, 8, 0) lat=23.753506 lon=120.251825 pm25=29.0 pollutant='細懸浮微粒' site_name='麥寮' status='普通'
# aqi=53 county='臺東縣' date=datetime.datetime(2024, 3, 15, 8, 0) lat=23.045083 lon=121.161933 pm25=18.0 pollutant='細懸浮微粒' site_name='關山' status='普通'
# aqi=62 county='澎湖縣' date=datetime.datetime(2024, 3, 15, 8, 0) lat=23.569031 lon=119.566158 pm25=21.0 pollutant='細懸浮微粒' site_name='馬公' status='普通'
# aqi=126 county='金門縣' date=datetime.datetime(2024, 3, 15, 8, 0) lat=24.432133 lon=118.312256 pm25=45.0 pollutant='細懸浮微粒' site_name='金門' status='對敏感族群不健康'
# aqi=68 county='連江縣' date=datetime.datetime(2024, 3, 15, 8, 0) lat=26.15188416 lon=119.93149378 pm25=18.0 pollutant='細懸浮微粒' site_name='馬祖' status='普通'
# aqi=68 county='南投縣' date=datetime.datetime(2024, 3, 15, 8, 0) lat=23.968842 lon=120.967903 pm25=25.0 pollutant='細懸浮微粒' site_name='埔里' status='普通'
# aqi=140 county='高雄市' date=datetime.datetime(2024, 3, 15, 8, 0) lat=22.608711 lon=120.312017 pm25=46.0 pollutant='細懸浮微粒' site_name='復興' status='對敏感族群不健康'
# aqi=69 county='新北市' date=datetime.datetime(2024, 3, 15, 8, 0) lat=25.017 lon=121.516306 pm25=23.0 pollutant='細懸浮微粒' site_name='永和' status='普通'
# aqi=103 county='南投縣' date=datetime.datetime(2024, 3, 15, 8, 0) lat=23.756389 lon=120.677306 pm25=40.0 pollutant='細懸浮微粒' site_name='竹山' status='對敏感族群不健康'
# aqi=139 county='桃園市' date=datetime.datetime(2024, 3, 15, 8, 0) lat=24.953278 lon=121.221667 pm25=55.0 pollutant='細懸浮微粒' site_name='中壢' status='對敏感族群不健康'
# aqi=73 county='新北市' date=datetime.datetime(2024, 3, 15, 8, 0) lat=25.072611 lon=121.493806 pm25=31.0 pollutant='細懸浮微粒' site_name='三重' status='普通'
# aqi=64 county='宜蘭縣' date=datetime.datetime(2024, 3, 15, 8, 0) lat=24.632203 lon=121.792928 pm25=20.0 pollutant='細懸浮微粒' site_name='冬山' status='普通'
# aqi=59 county='宜蘭縣' date=datetime.datetime(2024, 3, 15, 8, 0) lat=24.747917 lon=121.746394 pm25=25.0 pollutant='細懸浮微粒' site_name='宜蘭' status='普通'
# aqi=52 county='臺北市' date=datetime.datetime(2024, 3, 15, 8, 0) lat=25.182722 lon=121.529583 pm25=14.0 pollutant='細懸浮微粒' site_name='陽明' status='普通'
# aqi=54 county='花蓮縣' date=datetime.datetime(2024, 3, 15, 8, 0) lat=23.971306 lon=121.599769 pm25=17.0 pollutant='細懸浮微粒' site_name='花蓮' status='普通'
# aqi=57 county='臺東縣' date=datetime.datetime(2024, 3, 15, 8, 0) lat=22.755358 lon=121.15045 pm25=19.0 pollutant='細懸浮微粒' site_name='臺東' status='普通'
# aqi=67 county='屏東縣' date=datetime.datetime(2024, 3, 15, 8, 0) lat=21.958069 lon=120.788928 pm25=13.0 pollutant='臭氧八小時' site_name='恆春' status='普通'
# aqi=90 county='屏東縣' date=datetime.datetime(2024, 3, 15, 8, 0) lat=22.523108 lon=120.561175 pm25=35.0 pollutant='細懸浮微粒' site_name='潮州' status='普通'
# aqi=109 county='屏東縣' date=datetime.datetime(2024, 3, 15, 8, 0) lat=22.673081 lon=120.488033 pm25=31.0 pollutant='細懸浮微粒' site_name='屏東' status='對敏感族群不健康'
# aqi=119 county='高雄市' date=datetime.datetime(2024, 3, 15, 8, 0) lat=22.565833 lon=120.337736 pm25=41.0 pollutant='細懸浮微粒' site_name='小港' status='對敏感族群不健康'
# aqi=130 county='高雄市' date=datetime.datetime(2024, 3, 15, 8, 0) lat=22.6044507 lon=120.30833356 pm25=41.0 pollutant='細懸浮微粒' site_name='前鎮' status='對敏感族群不健康'
# aqi=148 county='高雄市' date=datetime.datetime(2024, 3, 15, 8, 0) lat=22.63390278 lon=120.28676111 pm25=59.0 pollutant='細懸浮微粒' site_name='前金' status='對敏感族群不健康'
# aqi=152 county='高雄市' date=datetime.datetime(2024, 3, 15, 8, 0) lat=22.674861 lon=120.292917 pm25=53.0 pollutant='細懸浮微粒' site_name='左營' status='對所有族群不健康'
# aqi=131 county='高雄市' date=datetime.datetime(2024, 3, 15, 8, 0) lat=22.733667 lon=120.328289 pm25=43.0 pollutant='細懸浮微粒' site_name='楠梓' status='對敏感族群不健康'
# aqi=128 county='高雄市' date=datetime.datetime(2024, 3, 15, 8, 0) lat=22.4795 lon=120.41175 pm25=45.0 pollutant='細懸浮微粒' site_name='林園' status='對敏感族群不健康'
# aqi=137 county='高雄市' date=datetime.datetime(2024, 3, 15, 8, 0) lat=22.56413611 lon=120.425311 pm25=43.0 pollutant='細懸浮微粒' site_name='大寮' status='對敏感族群不健康'
# aqi=124 county='高雄市' date=datetime.datetime(2024, 3, 15, 8, 0) lat=22.628126 lon=120.357422 pm25=37.0 pollutant='細懸浮微粒' site_name='鳳山' status='對敏感族群不健康'
# aqi=152 county='高雄市' date=datetime.datetime(2024, 3, 15, 8, 0) lat=22.689056 lon=120.332631 pm25=53.0 pollutant='細懸浮微粒' site_name='仁武' status='對所有族群不健康'
# aqi=143 county='高雄市' date=datetime.datetime(2024, 3, 15, 8, 0) lat=22.757506 lon=120.305689 pm25=40.0 pollutant='細懸浮微粒' site_name='橋頭' status='對敏感族群不健康'
# aqi=92 county='高雄市' date=datetime.datetime(2024, 3, 15, 8, 0) lat=22.883583 lon=120.530542 pm25=32.0 pollutant='細懸浮微粒' site_name='美濃' status='普通'
# aqi=152 county='臺南市' date=datetime.datetime(2024, 3, 15, 8, 0) lat=22.98928311 lon=120.21947897 pm25=71.0 pollutant='細懸浮微粒' site_name='臺南' status='對所有族群不健康'
# aqi=155 county='臺南市' date=datetime.datetime(2024, 3, 15, 8, 0) lat=23.048197 lon=120.2175 pm25=78.0 pollutant='細懸浮微粒' site_name='安南' status='對所有族群不健康'
# aqi=135 county='臺南市' date=datetime.datetime(2024, 3, 15, 8, 0) lat=23.11337642 lon=120.29740529 pm25=58.0 pollutant='細懸浮微粒' site_name='善化' status='對敏感族群不健康'
# aqi=149 county='臺南市' date=datetime.datetime(2024, 3, 15, 8, 0) lat=23.305633 lon=120.31725 pm25=57.0 pollutant='細懸浮微粒' site_name='新營' status='對敏感族群不健康'
# aqi=153 county='嘉義市' date=datetime.datetime(2024, 3, 15, 8, 0) lat=23.46477865 lon=120.44125148 pm25=61.0 pollutant='細懸浮微粒' site_name='嘉義' status='對所有族群不健康'
# aqi=70 county='雲林縣' date=datetime.datetime(2024, 3, 15, 8, 0) lat=23.702175 lon=120.19933333 pm25=30.0 pollutant='細懸浮微粒' site_name='臺西' status='普通'
# aqi=122 county='嘉義縣' date=datetime.datetime(2024, 3, 15, 8, 0) lat=23.46538 lon=120.2478 pm25=52.0 pollutant='細懸浮微粒' site_name='朴子' status='對敏感族群不健康'
# aqi=127 county='嘉義縣' date=datetime.datetime(2024, 3, 15, 8, 0) lat=23.554839 lon=120.345531 pm25=47.0 pollutant='細懸浮微粒' site_name='新港' status='對敏感族群不健康'
# aqi=102 county='雲林縣' date=datetime.datetime(2024, 3, 15, 8, 0) lat=23.757547 lon=120.348742 pm25=37.0 pollutant='細懸浮微粒' site_name='崙背' status='對敏感族群不健康'
# aqi=152 county='雲林縣' date=datetime.datetime(2024, 3, 15, 8, 0) lat=23.711853 lon=120.544994 pm25=71.0 pollutant='細懸浮微粒' site_name='斗六' status='對所有族群不健康'
# aqi=86 county='南投縣' date=datetime.datetime(2024, 3, 15, 8, 0) lat=23.913 lon=120.685306 pm25=31.0 pollutant='細懸浮微粒' site_name='南投' status='普通'
# aqi=101 county='彰化縣' date=datetime.datetime(2024, 3, 15, 8, 0) lat=23.925175 lon=120.409653 pm25=33.0 pollutant='細懸浮微粒' site_name='二林' status='對敏感族群不健康'
# aqi=75 county='彰化縣' date=datetime.datetime(2024, 3, 15, 8, 0) lat=24.131672 lon=120.469061 pm25=21.0 pollutant='細懸浮微粒' site_name='線西' status='普通'
# aqi=88 county='彰化縣' date=datetime.datetime(2024, 3, 15, 8, 0) lat=24.066 lon=120.541519 pm25=29.0 pollutant='細懸浮微粒' site_name='彰化' status='普通'
# aqi=103 county='臺中市' date=datetime.datetime(2024, 3, 15, 8, 0) lat=24.162197 lon=120.616917 pm25=37.0 pollutant='細懸浮微粒' site_name='西屯' status='對敏感族群不健康'
# aqi=105 county='臺中市' date=datetime.datetime(2024, 3, 15, 8, 0) lat=24.151958 lon=120.641092 pm25=45.0 pollutant='細懸浮微粒' site_name='忠明' status='對敏感族群不健康'
# aqi=120 county='臺中市' date=datetime.datetime(2024, 3, 15, 8, 0) lat=24.09961111 lon=120.67844444 pm25=44.0 pollutant='細懸浮微粒' site_name='大里' status='對敏感族群不健康'
# aqi=86 county='臺中市' date=datetime.datetime(2024, 3, 15, 8, 0) lat=24.225628 lon=120.568794 pm25=26.0 pollutant='細懸浮微粒' site_name='沙鹿' status='普通'
# aqi=68 county='臺中市' date=datetime.datetime(2024, 3, 15, 8, 0) lat=24.25699731 lon=120.74252414 pm25=23.0 pollutant='細懸浮微粒' site_name='豐原' status='普通'
# aqi=89 county='苗栗縣' date=datetime.datetime(2024, 3, 15, 8, 0) lat=24.38248443 lon=120.75956754 pm25=32.0 pollutant='細懸浮微粒' site_name='三義' status='普通'
# aqi=95 county='苗栗縣' date=datetime.datetime(2024, 3, 15, 8, 0) lat=24.56499183 lon=120.82011468 pm25=41.0 pollutant='細懸浮微粒' site_name='苗栗' status='普通'
# aqi=89 county='苗栗縣' date=datetime.datetime(2024, 3, 15, 8, 0) lat=24.69690679 lon=120.89869286 pm25=35.0 pollutant='細懸浮微粒' site_name='頭份' status='普通'
# aqi=103 county='新竹市' date=datetime.datetime(2024, 3, 15, 8, 0) lat=24.8056356 lon=120.97236752 pm25=43.0 pollutant='細懸浮微粒' site_name='新竹' status='對敏感族群不健康'
# aqi=67 county='新竹縣' date=datetime.datetime(2024, 3, 15, 8, 0) lat=24.74091408 lon=121.08895493 pm25=23.0 pollutant='細懸浮微粒' site_name='竹東' status='普通'
# aqi=139 county='新竹縣' date=datetime.datetime(2024, 3, 15, 8, 0) lat=24.90009696 lon=121.03886894 pm25=46.0 pollutant='細懸浮微粒' site_name='湖口' status='對敏感族群不健康'
# aqi=97 county='桃園市' date=datetime.datetime(2024, 3, 15, 8, 0) lat=24.86400048 lon=121.21645772 pm25=29.0 pollutant='細懸浮微粒' site_name='龍潭' status='普通'
# aqi=123 county='桃園市' date=datetime.datetime(2024, 3, 15, 8, 0) lat=24.952786 lon=121.203986 pm25=44.0 pollutant='細懸浮微粒' site_name='平鎮' status='對敏感族群不健康'
# aqi=147 county='桃園市' date=datetime.datetime(2024, 3, 15, 8, 0) lat=25.03556747 lon=121.08283092 pm25=55.0 pollutant='細懸浮微粒' site_name='觀音' status='對敏感族群不健康'
# aqi=138 county='桃園市' date=datetime.datetime(2024, 3, 15, 8, 0) lat=25.06100357 lon=121.20251473 pm25=64.0 pollutant='細懸浮微粒' site_name='大園' status='對敏感族群不健康'
# aqi=91 county='桃園市' date=datetime.datetime(2024, 3, 15, 8, 0) lat=24.9947107 lon=121.30500531 pm25=29.0 pollutant='細懸浮微粒' site_name='桃園' status='普通'
# aqi=77 county='臺北市' date=datetime.datetime(2024, 3, 15, 8, 0) lat=25.06331455 lon=121.51342074 pm25=26.0 pollutant='細懸浮微粒' site_name='大同' status='普通'
# aqi=77 county='臺北市' date=datetime.datetime(2024, 3, 15, 8, 0) lat=25.05 lon=121.578611 pm25=29.0 pollutant='細懸浮微粒' site_name='松山' status='普通'
# aqi=64 county='臺北市' date=datetime.datetime(2024, 3, 15, 8, 0) lat=25.020608 lon=121.529556 pm25=24.0 pollutant='細懸浮微粒' site_name='古亭' status='普通'
# aqi=69 county='臺北市' date=datetime.datetime(2024, 3, 15, 8, 0) lat=25.046503 lon=121.507972 pm25=30.0 pollutant='細懸浮微粒' site_name='萬華' status='普通'
# aqi=63 county='臺北市' date=datetime.datetime(2024, 3, 15, 8, 0) lat=25.062361 lon=121.526528 pm25=23.0 pollutant='細懸浮微粒' site_name='中山' status='普通'
# aqi=58 county='臺北市' date=datetime.datetime(2024, 3, 15, 8, 0) lat=25.10334003 lon=121.51666356 pm25=27.0 pollutant='細懸浮微粒' site_name='士林' status='普通'
# aqi=71 county='新北市' date=datetime.datetime(2024, 3, 15, 8, 0) lat=25.1645 lon=121.449239 pm25=24.0 pollutant='細懸浮微粒' site_name='淡水' status='普通'
# aqi=61 county='新北市' date=datetime.datetime(2024, 3, 15, 8, 0) lat=25.07798949 lon=121.36548982 pm25=17.0 pollutant='細懸浮微粒' site_name='林口' status='普通'
# aqi=76 county='新北市' date=datetime.datetime(2024, 3, 15, 8, 0) lat=25.06895 lon=121.481028 pm25=25.0 pollutant='細懸浮微粒' site_name='菜寮' status='普通'
# aqi=81 county='新北市' date=datetime.datetime(2024, 3, 15, 8, 0) lat=25.037972 lon=121.4325 pm25=28.0 pollutant='細懸浮微粒' site_name='新莊' status='普通'
# aqi=66 county='新北市' date=datetime.datetime(2024, 3, 15, 8, 0) lat=25.012972 lon=121.458667 pm25=21.0 pollutant='細懸浮微粒' site_name='板橋' status='普通'
# aqi=72 county='新北市' date=datetime.datetime(2024, 3, 15, 8, 0) lat=24.982528 lon=121.451861 pm25=27.0 pollutant='細懸浮微粒' site_name='土城' status='普通'
# aqi=64 county='新北市' date=datetime.datetime(2024, 3, 15, 8, 0) lat=24.977222 lon=121.537778 pm25=22.0 pollutant='細懸浮微粒' site_name='新店' status='普通'
# aqi=47 county='新北市' date=datetime.datetime(2024, 3, 15, 8, 0) lat=25.179667 lon=121.689881 pm25=15.0 pollutant='' site_name='萬里' status='良好'
# aqi=57 county='新北市' date=datetime.datetime(2024, 3, 15, 8, 0) lat=25.06624 lon=121.64081 pm25=22.0 pollutant='細懸浮微粒' site_name='汐止' status='普通'
# aqi=58 county='基隆市' date=datetime.datetime(2024, 3, 15, 8, 0) lat=25.129167 lon=121.760056 pm25=19.0 pollutant='細懸浮微粒' site_name='基隆' status='普通'
# aqi=71 county='屏東縣' date=datetime.datetime(2024, 3, 15, 7, 0) lat=22.260899 lon=120.651472 pm25=12.0 pollutant='臭氧八小時' site_name='屏東(枋山)' status='普通'
# aqi=83 county='新北市' date=datetime.datetime(2024, 3, 15, 7, 0) lat=24.94902778 lon=121.38352778 pm25=25.0 pollutant='細懸浮微粒' site_name='新北(樹林)' status='普通'
# aqi=95 county='屏東縣' date=datetime.datetime(2024, 3, 15, 7, 0) lat=22.35222 lon=120.37722 pm25=40.0 pollutant='細懸浮微粒' site_name='屏東(琉球)' status='普通'
# aqi=151 county='臺南市' date=datetime.datetime(2024, 3, 15, 7, 0) lat=23.17904722 lon=120.24583056 pm25=60.0 pollutant='細懸浮微粒' site_name='臺南(麻豆)' status='對所有族群不健康'
# aqi=136 county='高雄市' date=datetime.datetime(2024, 3, 15, 7, 0) lat=22.87985556 lon=120.24535 pm25=51.0 pollutant='細懸浮微粒' site_name='高雄(湖內)' status='對敏感族群不健康'
# aqi=119 county='彰化縣' date=datetime.datetime(2024, 3, 15, 7, 0) lat=23.96117 lon=120.56373 pm25=46.0 pollutant='細懸浮微粒' site_name='彰化(員林)' status='對敏感族群不健康'
# aqi=80 county='彰化縣' date=datetime.datetime(2024, 3, 15, 7, 0) lat=23.85493056 lon=120.26964167 pm25=28.0 pollutant='細懸浮微粒' site_name='大城' status='普通'
# aqi=53 county='新北市' date=datetime.datetime(2024, 3, 15, 7, 0) lat=25.29681695 lon=121.53656894 pm25=14.0 pollutant='細懸浮微粒' site_name='富貴角' status='普通'
# aqi=85 county='雲林縣' date=datetime.datetime(2024, 3, 15, 7, 0) lat=23.753506 lon=120.251825 pm25=27.0 pollutant='細懸浮微粒' site_name='麥寮' status='普通'
# aqi=53 county='臺東縣' date=datetime.datetime(2024, 3, 15, 7, 0) lat=23.045083 lon=121.161933 pm25=16.0 pollutant='細懸浮微粒' site_name='關山' status='普通'
# aqi=61 county='澎湖縣' date=datetime.datetime(2024, 3, 15, 7, 0) lat=23.569031 lon=119.566158 pm25=20.0 pollutant='細懸浮微粒' site_name='馬公' status='普通'
# aqi=126 county='金門縣' date=datetime.datetime(2024, 3, 15, 7, 0) lat=24.432133 lon=118.312256 pm25=47.0 pollutant='細懸浮微粒' site_name='金門' status='對敏感族群不健康'
# aqi=71 county='連江縣' date=datetime.datetime(2024, 3, 15, 7, 0) lat=26.15188416 lon=119.93149378 pm25=16.0 pollutant='細懸浮微粒' site_name='馬祖' status='普通'
# aqi=67 county='南投縣' date=datetime.datetime(2024, 3, 15, 7, 0) lat=23.968842 lon=120.967903 pm25=23.0 pollutant='細懸浮微粒' site_name='埔里' status='普通'
# aqi=144 county='高雄市' date=datetime.datetime(2024, 3, 15, 7, 0) lat=22.608711 lon=120.312017 pm25=64.0 pollutant='細懸浮微粒' site_name='復興' status='對敏感族群不健康'
# aqi=69 county='新北市' date=datetime.datetime(2024, 3, 15, 7, 0) lat=25.017 lon=121.516306 pm25=26.0 pollutant='細懸浮微粒' site_name='永和' status='普通'
# aqi=101 county='南投縣' date=datetime.datetime(2024, 3, 15, 7, 0) lat=23.756389 lon=120.677306 pm25=32.0 pollutant='細懸浮微粒' site_name='竹山' status='對敏感族群不健康'
# aqi=136 county='桃園市' date=datetime.datetime(2024, 3, 15, 7, 0) lat=24.953278 lon=121.221667 pm25=45.0 pollutant='細懸浮微粒' site_name='中壢' status='對敏感族群不健康'
# aqi=72 county='新北市' date=datetime.datetime(2024, 3, 15, 7, 0) lat=25.072611 lon=121.493806 pm25=22.0 pollutant='細懸浮微粒' site_name='三重' status='普通'
# aqi=64 county='宜蘭縣' date=datetime.datetime(2024, 3, 15, 7, 0) lat=24.632203 lon=121.792928 pm25=19.0 pollutant='細懸浮微粒' site_name='冬山' status='普通'
# aqi=53 county='宜蘭縣' date=datetime.datetime(2024, 3, 15, 7, 0) lat=24.747917 lon=121.746394 pm25=17.0 pollutant='細懸浮微粒' site_name='宜蘭' status='普通'
# aqi=54 county='臺北市' date=datetime.datetime(2024, 3, 15, 7, 0) lat=25.182722 lon=121.529583 pm25=16.0 pollutant='臭氧八小時' site_name='陽明' status='普通'
# aqi=53 county='花蓮縣' date=datetime.datetime(2024, 3, 15, 7, 0) lat=23.971306 lon=121.599769 pm25=18.0 pollutant='細懸浮微粒' site_name='花蓮' status='普通'
# aqi=58 county='臺東縣' date=datetime.datetime(2024, 3, 15, 7, 0) lat=22.755358 lon=121.15045 pm25=19.0 pollutant='細懸浮微粒' site_name='臺東' status='普通'
# aqi=71 county='屏東縣' date=datetime.datetime(2024, 3, 15, 7, 0) lat=21.958069 lon=120.788928 pm25=16.0 pollutant='臭氧八小時' site_name='恆春' status='普通'
# aqi=89 county='屏東縣' date=datetime.datetime(2024, 3, 15, 7, 0) lat=22.523108 lon=120.561175 pm25=38.0 pollutant='細懸浮微粒' site_name='潮州' status='普通'
# aqi=114 county='屏東縣' date=datetime.datetime(2024, 3, 15, 7, 0) lat=22.673081 lon=120.488033 pm25=36.0 pollutant='細懸浮微粒' site_name='屏東' status='對敏感族群不健康'
# aqi=122 county='高雄市' date=datetime.datetime(2024, 3, 15, 7, 0) lat=22.565833 lon=120.337736 pm25=42.0 pollutant='細懸浮微粒' site_name='小港' status='對敏感族群不健康'
# aqi=133 county='高雄市' date=datetime.datetime(2024, 3, 15, 7, 0) lat=22.6044507 lon=120.30833356 pm25=56.0 pollutant='細懸浮微粒' site_name='前鎮' status='對敏感族群不健康'
# aqi=146 county='高雄市' date=datetime.datetime(2024, 3, 15, 7, 0) lat=22.63390278 lon=120.28676111 pm25=60.0 pollutant='細懸浮微粒' site_name='前金' status='對敏感族群不健康'
# aqi=152 county='高雄市' date=datetime.datetime(2024, 3, 15, 7, 0) lat=22.674861 lon=120.292917 pm25=51.0 pollutant='細懸浮微粒' site_name='左營' status='對所有族群不健康'
# aqi=134 county='高雄市' date=datetime.datetime(2024, 3, 15, 7, 0) lat=22.733667 lon=120.328289 pm25=40.0 pollutant='細懸浮微粒' site_name='楠梓' status='對敏感族群不健康'
# aqi=128 county='高雄市' date=datetime.datetime(2024, 3, 15, 7, 0) lat=22.4795 lon=120.41175 pm25=50.0 pollutant='細懸浮微粒' site_name='林園' status='對敏感族群不健康'
# aqi=142 county='高雄市' date=datetime.datetime(2024, 3, 15, 7, 0) lat=22.56413611 lon=120.425311 pm25=51.0 pollutant='細懸浮微粒' site_name='大寮' status='對敏感族群不健康'
# aqi=129 county='高雄市' date=datetime.datetime(2024, 3, 15, 7, 0) lat=22.628126 lon=120.357422 pm25=50.0 pollutant='細懸浮微粒' site_name='鳳山' status='對敏感族群不健康'
# aqi=152 county='高雄市' date=datetime.datetime(2024, 3, 15, 7, 0) lat=22.689056 lon=120.332631 pm25=49.0 pollutant='細懸浮微粒' site_name='仁武' status='對所有族群不健康'
# aqi=148 county='高雄市' date=datetime.datetime(2024, 3, 15, 7, 0) lat=22.757506 lon=120.305689 pm25=41.0 pollutant='細懸浮微粒' site_name='橋頭' status='對敏感族群不健康'
# aqi=93 county='高雄市' date=datetime.datetime(2024, 3, 15, 7, 0) lat=22.883583 lon=120.530542 pm25=29.0 pollutant='細懸浮微粒' site_name='美濃' status='普通'
# aqi=146 county='臺南市' date=datetime.datetime(2024, 3, 15, 7, 0) lat=22.98928311 lon=120.21947897 pm25=58.0 pollutant='細懸浮微粒' site_name='臺南' status='對敏感族群不健康'
# aqi=153 county='臺南市' date=datetime.datetime(2024, 3, 15, 7, 0) lat=23.048197 lon=120.2175 pm25=67.0 pollutant='細懸浮微粒' site_name='安南' status='對所有族群不健康'
# aqi=130 county='臺南市' date=datetime.datetime(2024, 3, 15, 7, 0) lat=23.11337642 lon=120.29740529 pm25=51.0 pollutant='細懸浮微粒' site_name='善化' status='對敏感族群不健康'
# aqi=144 county='臺南市' date=datetime.datetime(2024, 3, 15, 7, 0) lat=23.305633 lon=120.31725 pm25=59.0 pollutant='細懸浮微粒' site_name='新營' status='對敏感族群不健康'
# aqi=152 county='嘉義市' date=datetime.datetime(2024, 3, 15, 7, 0) lat=23.46477865 lon=120.44125148 pm25=54.0 pollutant='細懸浮微粒' site_name='嘉義' status='對所有族群不健康'
# aqi=69 county='雲林縣' date=datetime.datetime(2024, 3, 15, 7, 0) lat=23.702175 lon=120.19933333 pm25=20.0 pollutant='細懸浮微粒' site_name='臺西' status='普通'
# aqi=121 county='嘉義縣' date=datetime.datetime(2024, 3, 15, 7, 0) lat=23.46538 lon=120.2478 pm25=44.0 pollutant='細懸浮微粒' site_name='朴子' status='對敏感族群不健康'
# aqi=125 county='嘉義縣' date=datetime.datetime(2024, 3, 15, 7, 0) lat=23.554839 lon=120.345531 pm25=49.0 pollutant='細懸浮微粒' site_name='新港' status='對敏感族群不健康'
# aqi=104 county='雲林縣' date=datetime.datetime(2024, 3, 15, 7, 0) lat=23.757547 lon=120.348742 pm25=31.0 pollutant='細懸浮微粒' site_name='崙背' status='對敏感族群不健康'
# aqi=143 county='雲林縣' date=datetime.datetime(2024, 3, 15, 7, 0) lat=23.711853 lon=120.544994 pm25=60.0 pollutant='細懸浮微粒' site_name='斗六' status='對敏感族群不健康'
# aqi=86 county='南投縣' date=datetime.datetime(2024, 3, 15, 7, 0) lat=23.913 lon=120.685306 pm25=30.0 pollutant='細懸浮微粒' site_name='南投' status='普通'
# aqi=104 county='彰化縣' date=datetime.datetime(2024, 3, 15, 7, 0) lat=23.925175 lon=120.409653 pm25=30.0 pollutant='細懸浮微粒' site_name='二林' status='對敏感族群不健康'
# aqi=80 county='彰化縣' date=datetime.datetime(2024, 3, 15, 7, 0) lat=24.131672 lon=120.469061 pm25=21.0 pollutant='細懸浮微粒' site_name='線西' status='普通'
# aqi=90 county='彰化縣' date=datetime.datetime(2024, 3, 15, 7, 0) lat=24.066 lon=120.541519 pm25=21.0 pollutant='細懸浮微粒' site_name='彰化' status='普通'
# aqi=105 county='臺中市' date=datetime.datetime(2024, 3, 15, 7, 0) lat=24.162197 lon=120.616917 pm25=32.0 pollutant='細懸浮微粒' site_name='西屯' status='對敏感族群不健康'
# aqi=100 county='臺中市' date=datetime.datetime(2024, 3, 15, 7, 0) lat=24.151958 lon=120.641092 pm25=34.0 pollutant='細懸浮微粒' site_name='忠明' status='普通'
# aqi=120 county='臺中市' date=datetime.datetime(2024, 3, 15, 7, 0) lat=24.09961111 lon=120.67844444 pm25=35.0 pollutant='細懸浮微粒' site_name='大里' status='對敏感族群不健康'
# aqi=89 county='臺中市' date=datetime.datetime(2024, 3, 15, 7, 0) lat=24.225628 lon=120.568794 pm25=21.0 pollutant='細懸浮微粒' site_name='沙鹿' status='普通'
# aqi=69 county='臺中市' date=datetime.datetime(2024, 3, 15, 7, 0) lat=24.25699731 lon=120.74252414 pm25=20.0 pollutant='細懸浮微粒' site_name='豐原' status='普通'
# aqi=88 county='苗栗縣' date=datetime.datetime(2024, 3, 15, 7, 0) lat=24.38248443 lon=120.75956754 pm25=33.0 pollutant='細懸浮微粒' site_name='三義' status='普通'
# aqi=89 county='苗栗縣' date=datetime.datetime(2024, 3, 15, 7, 0) lat=24.56499183 lon=120.82011468 pm25=32.0 pollutant='細懸浮微粒' site_name='苗栗' status='普通'
# aqi=88 county='苗栗縣' date=datetime.datetime(2024, 3, 15, 7, 0) lat=24.69690679 lon=120.89869286 pm25=28.0 pollutant='細懸浮微粒' site_name='頭份' status='普通'
# aqi=99 county='新竹市' date=datetime.datetime(2024, 3, 15, 7, 0) lat=24.8056356 lon=120.97236752 pm25=29.0 pollutant='細懸浮微粒' site_name='新竹' status='普通'
# aqi=67 county='新竹縣' date=datetime.datetime(2024, 3, 15, 7, 0) lat=24.74091408 lon=121.08895493 pm25=22.0 pollutant='細懸浮微粒' site_name='竹東' status='普通'
# aqi=142 county='新竹縣' date=datetime.datetime(2024, 3, 15, 7, 0) lat=24.90009696 lon=121.03886894 pm25=36.0 pollutant='細懸浮微粒' site_name='湖口' status='對敏感族群不健康'
# aqi=103 county='桃園市' date=datetime.datetime(2024, 3, 15, 7, 0) lat=24.86400048 lon=121.21645772 pm25=29.0 pollutant='細懸浮微粒' site_name='龍潭' status='對敏感族群不健康'
# aqi=125 county='桃園市' date=datetime.datetime(2024, 3, 15, 7, 0) lat=24.952786 lon=121.203986 pm25=43.0 pollutant='細懸浮微粒' site_name='平鎮' status='對敏感族群不健康'
# aqi=141 county='桃園市' date=datetime.datetime(2024, 3, 15, 7, 0) lat=25.03556747 lon=121.08283092 pm25=66.0 pollutant='細懸浮微粒' site_name='觀音' status='對敏感族群不健康'
# aqi=128 county='桃園市' date=datetime.datetime(2024, 3, 15, 7, 0) lat=25.06100357 lon=121.20251473 pm25=56.0 pollutant='細懸浮微粒' site_name='大園' status='對敏感族群不健康'
# aqi=92 county='桃園市' date=datetime.datetime(2024, 3, 15, 7, 0) lat=24.9947107 lon=121.30500531 pm25=30.0 pollutant='細懸浮微粒' site_name='桃園' status='普通'
# aqi=77 county='臺北市' date=datetime.datetime(2024, 3, 15, 7, 0) lat=25.06331455 lon=121.51342074 pm25=25.0 pollutant='細懸浮微粒' site_name='大同' status='普通'
# aqi=76 county='臺北市' date=datetime.datetime(2024, 3, 15, 7, 0) lat=25.05 lon=121.578611 pm25=25.0 pollutant='細懸浮微粒' site_name='松山' status='普通'
# aqi=64 county='臺北市' date=datetime.datetime(2024, 3, 15, 7, 0) lat=25.020608 lon=121.529556 pm25=23.0 pollutant='細懸浮微粒' site_name='古亭' status='普通'
# aqi=68 county='臺北市' date=datetime.datetime(2024, 3, 15, 7, 0) lat=25.046503 lon=121.507972 pm25=22.0 pollutant='細懸浮微粒' site_name='萬華' status='普通'
# aqi=64 county='臺北市' date=datetime.datetime(2024, 3, 15, 7, 0) lat=25.062361 lon=121.526528 pm25=17.0 pollutant='細懸浮微粒' site_name='中山' status='普通'
# aqi=54 county='臺北市' date=datetime.datetime(2024, 3, 15, 7, 0) lat=25.10334003 lon=121.51666356 pm25=16.0 pollutant='細懸浮微粒' site_name='士林' status='普通'
# aqi=71 county='新北市' date=datetime.datetime(2024, 3, 15, 7, 0) lat=25.1645 lon=121.449239 pm25=24.0 pollutant='細懸浮微粒' site_name='淡水' status='普通'
# aqi=64 county='新北市' date=datetime.datetime(2024, 3, 15, 7, 0) lat=25.07798949 lon=121.36548982 pm25=16.0 pollutant='細懸浮微粒' site_name='林口' status='普通'
# aqi=76 county='新北市' date=datetime.datetime(2024, 3, 15, 7, 0) lat=25.06895 lon=121.481028 pm25=0.0 pollutant='細懸浮微粒' site_name='菜寮' status='普通'
# aqi=81 county='新北市' date=datetime.datetime(2024, 3, 15, 7, 0) lat=25.037972 lon=121.4325 pm25=26.0 pollutant='細懸浮微粒' site_name='新莊' status='普通'
# aqi=68 county='新北市' date=datetime.datetime(2024, 3, 15, 7, 0) lat=25.012972 lon=121.458667 pm25=22.0 pollutant='細懸浮微粒' site_name='板橋' status='普通'
# aqi=73 county='新北市' date=datetime.datetime(2024, 3, 15, 7, 0) lat=24.982528 lon=121.451861 pm25=24.0 pollutant='細懸浮微粒' site_name='土城' status='普通'
# aqi=64 county='新北市' date=datetime.datetime(2024, 3, 15, 7, 0) lat=24.977222 lon=121.537778 pm25=20.0 pollutant='細懸浮微粒' site_name='新店' status='普通'
# aqi=47 county='新北市' date=datetime.datetime(2024, 3, 15, 7, 0) lat=25.179667 lon=121.689881 pm25=15.0 pollutant='' site_name='萬里' status='良好'
# aqi=57 county='新北市' date=datetime.datetime(2024, 3, 15, 7, 0) lat=25.06624 lon=121.64081 pm25=17.0 pollutant='細懸浮微粒' site_name='汐止' status='普通'
# aqi=57 county='基隆市' date=datetime.datetime(2024, 3, 15, 7, 0) lat=25.129167 lon=121.760056 pm25=19.0 pollutant='細懸浮微粒' site_name='基隆' status='普通'
# aqi=74 county='屏東縣' date=datetime.datetime(2024, 3, 15, 6, 0) lat=22.260899 lon=120.651472 pm25=11.0 pollutant='臭氧八小時' site_name='屏東(枋山)' status='普通'
# aqi=85 county='新北市' date=datetime.datetime(2024, 3, 15, 6, 0) lat=24.94902778 lon=121.38352778 pm25=22.0 pollutant='細懸浮微粒' site_name='新北(樹林)' status='普通'
# aqi=88 county='屏東縣' date=datetime.datetime(2024, 3, 15, 6, 0) lat=22.35222 lon=120.37722 pm25=39.0 pollutant='細懸浮微粒' site_name='屏東(琉球)' status='普通'
# aqi=145 county='臺南市' date=datetime.datetime(2024, 3, 15, 6, 0) lat=23.17904722 lon=120.24583056 pm25=63.0 pollutant='細懸浮微粒' site_name='臺南(麻豆)' status='對敏感族群不健康'
# aqi=135 county='高雄市' date=datetime.datetime(2024, 3, 15, 6, 0) lat=22.87985556 lon=120.24535 pm25=54.0 pollutant='細懸浮微粒' site_name='高雄(湖內)' status='對敏感族群不健康'
# aqi=116 county='彰化縣' date=datetime.datetime(2024, 3, 15, 6, 0) lat=23.96117 lon=120.56373 pm25=46.0 pollutant='細懸浮微粒' site_name='彰化(員林)' status='對敏感族群不健康'
# aqi=81 county='彰化縣' date=datetime.datetime(2024, 3, 15, 6, 0) lat=23.85493056 lon=120.26964167 pm25=24.0 pollutant='細懸浮微粒' site_name='大城' status='普通'
# aqi=53 county='新北市' date=datetime.datetime(2024, 3, 15, 6, 0) lat=25.29681695 lon=121.53656894 pm25=14.0 pollutant='細懸浮微粒' site_name='富貴角' status='普通'
# aqi=88 county='雲林縣' date=datetime.datetime(2024, 3, 15, 6, 0) lat=23.753506 lon=120.251825 pm25=23.0 pollutant='細懸浮微粒' site_name='麥寮' status='普通'
# aqi=53 county='臺東縣' date=datetime.datetime(2024, 3, 15, 6, 0) lat=23.045083 lon=121.161933 pm25=16.0 pollutant='細懸浮微粒' site_name='關山' status='普通'
# aqi=62 county='澎湖縣' date=datetime.datetime(2024, 3, 15, 6, 0) lat=23.569031 lon=119.566158 pm25=21.0 pollutant='細懸浮微粒' site_name='馬公' status='普通'
# aqi=124 county='金門縣' date=datetime.datetime(2024, 3, 15, 6, 0) lat=24.432133 lon=118.312256 pm25=43.0 pollutant='細懸浮微粒' site_name='金門' status='對敏感族群不健康'
# aqi=76 county='連江縣' date=datetime.datetime(2024, 3, 15, 6, 0) lat=26.15188416 lon=119.93149378 pm25=18.0 pollutant='細懸浮微粒' site_name='馬祖' status='普通'
# aqi=68 county='南投縣' date=datetime.datetime(2024, 3, 15, 6, 0) lat=23.968842 lon=120.967903 pm25=22.0 pollutant='細懸浮微粒' site_name='埔里' status='普通'
# aqi=137 county='高雄市' date=datetime.datetime(2024, 3, 15, 6, 0) lat=22.608711 lon=120.312017 pm25=56.0 pollutant='細懸浮微粒' site_name='復興' status='對敏感族群不健康'
# aqi=67 county='新北市' date=datetime.datetime(2024, 3, 15, 6, 0) lat=25.017 lon=121.516306 pm25=21.0 pollutant='細懸浮微粒' site_name='永和' status='普通'
# aqi=105 county='南投縣' date=datetime.datetime(2024, 3, 15, 6, 0) lat=23.756389 lon=120.677306 pm25=34.0 pollutant='細懸浮微粒' site_name='竹山' status='對敏感族群不健康'
# aqi=138 county='桃園市' date=datetime.datetime(2024, 3, 15, 6, 0) lat=24.953278 lon=121.221667 pm25=44.0 pollutant='細懸浮微粒' site_name='中壢' status='對敏感族群不健康'
# aqi=73 county='新北市' date=datetime.datetime(2024, 3, 15, 6, 0) lat=25.072611 lon=121.493806 pm25=22.0 pollutant='細懸浮微粒' site_name='三重' status='普通'
# aqi=65 county='宜蘭縣' date=datetime.datetime(2024, 3, 15, 6, 0) lat=24.632203 lon=121.792928 pm25=19.0 pollutant='細懸浮微粒' site_name='冬山' status='普通'
# aqi=56 county='宜蘭縣' date=datetime.datetime(2024, 3, 15, 6, 0) lat=24.747917 lon=121.746394 pm25=16.0 pollutant='細懸浮微粒' site_name='宜蘭' status='普通'
# aqi=58 county='臺北市' date=datetime.datetime(2024, 3, 15, 6, 0) lat=25.182722 lon=121.529583 pm25=17.0 pollutant='臭氧八小時' site_name='陽明' status='普通'
# aqi=52 county='花蓮縣' date=datetime.datetime(2024, 3, 15, 6, 0) lat=23.971306 lon=121.599769 pm25=12.0 pollutant='細懸浮微粒' site_name='花蓮' status='普通'
# aqi=57 county='臺東縣' date=datetime.datetime(2024, 3, 15, 6, 0) lat=22.755358 lon=121.15045 pm25=18.0 pollutant='細懸浮微粒' site_name='臺東' status='普通'
# aqi=71 county='屏東縣' date=datetime.datetime(2024, 3, 15, 6, 0) lat=21.958069 lon=120.788928 pm25=17.0 pollutant='臭氧八小時' site_name='恆春' status='普通'
# aqi=84 county='屏東縣' date=datetime.datetime(2024, 3, 15, 6, 0) lat=22.523108 lon=120.561175 pm25=26.0 pollutant='細懸浮微粒' site_name='潮州' status='普通'
# aqi=118 county='屏東縣' date=datetime.datetime(2024, 3, 15, 6, 0) lat=22.673081 lon=120.488033 pm25=39.0 pollutant='細懸浮微粒' site_name='屏東' status='對敏感族群不健康'
# aqi=123 county='高雄市' date=datetime.datetime(2024, 3, 15, 6, 0) lat=22.565833 lon=120.337736 pm25=48.0 pollutant='細懸浮微粒' site_name='小港' status='對敏感族群不健康'
# aqi=130 county='高雄市' date=datetime.datetime(2024, 3, 15, 6, 0) lat=22.6044507 lon=120.30833356 pm25=48.0 pollutant='細懸浮微粒' site_name='前鎮' status='對敏感族群不健康'
# aqi=144 county='高雄市' date=datetime.datetime(2024, 3, 15, 6, 0) lat=22.63390278 lon=120.28676111 pm25=56.0 pollutant='細懸浮微粒' site_name='前金' status='對敏感族群不健康'
# aqi=152 county='高雄市' date=datetime.datetime(2024, 3, 15, 6, 0) lat=22.674861 lon=120.292917 pm25=64.0 pollutant='細懸浮微粒' site_name='左營' status='對所有族群不健康'
# aqi=135 county='高雄市' date=datetime.datetime(2024, 3, 15, 6, 0) lat=22.733667 lon=120.328289 pm25=49.0 pollutant='細懸浮微粒' site_name='楠梓' status='對敏感族群不健康'
# aqi=125 county='高雄市' date=datetime.datetime(2024, 3, 15, 6, 0) lat=22.4795 lon=120.41175 pm25=52.0 pollutant='細懸浮微粒' site_name='林園' status='對敏感族群不健康'
# aqi=140 county='高雄市' date=datetime.datetime(2024, 3, 15, 6, 0) lat=22.56413611 lon=120.425311 pm25=52.0 pollutant='細懸浮微粒' site_name='大寮' status='對敏感族群不健康'
# aqi=130 county='高雄市' date=datetime.datetime(2024, 3, 15, 6, 0) lat=22.628126 lon=120.357422 pm25=46.0 pollutant='細懸浮微粒' site_name='鳳山' status='對敏感族群不健康'
# aqi=152 county='高雄市' date=datetime.datetime(2024, 3, 15, 6, 0) lat=22.689056 lon=120.332631 pm25=63.0 pollutant='細懸浮微粒' site_name='仁武' status='對所有族群不健康'
# aqi=151 county='高雄市' date=datetime.datetime(2024, 3, 15, 6, 0) lat=22.757506 lon=120.305689 pm25=55.0 pollutant='細懸浮微粒' site_name='橋頭' status='對所有族群不健康'
# aqi=94 county='高雄市' date=datetime.datetime(2024, 3, 15, 6, 0) lat=22.883583 lon=120.530542 pm25=31.0 pollutant='細懸浮微粒' site_name='美濃' status='普通'
# aqi=143 county='臺南市' date=datetime.datetime(2024, 3, 15, 6, 0) lat=22.98928311 lon=120.21947897 pm25=56.0 pollutant='細懸浮微粒' site_name='臺南' status='對敏感族群不健康'
# aqi=152 county='臺南市' date=datetime.datetime(2024, 3, 15, 6, 0) lat=23.048197 lon=120.2175 pm25=62.0 pollutant='細懸浮微粒' site_name='安南' status='對所有族群不健康'
# aqi=127 county='臺南市' date=datetime.datetime(2024, 3, 15, 6, 0) lat=23.11337642 lon=120.29740529 pm25=53.0 pollutant='細懸浮微粒' site_name='善化' status='對敏感族群不健康'
# aqi=140 county='臺南市' date=datetime.datetime(2024, 3, 15, 6, 0) lat=23.305633 lon=120.31725 pm25=64.0 pollutant='細懸浮微粒' site_name='新營' status='對敏感族群不健康'
# aqi=152 county='嘉義市' date=datetime.datetime(2024, 3, 15, 6, 0) lat=23.46477865 lon=120.44125148 pm25=60.0 pollutant='細懸浮微粒' site_name='嘉義' status='對所有族群不健康'
# aqi=71 county='雲林縣' date=datetime.datetime(2024, 3, 15, 6, 0) lat=23.702175 lon=120.19933333 pm25=20.0 pollutant='細懸浮微粒' site_name='臺西' status='普通'
# aqi=124 county='嘉義縣' date=datetime.datetime(2024, 3, 15, 6, 0) lat=23.46538 lon=120.2478 pm25=40.0 pollutant='細懸浮微粒' site_name='朴子' status='對敏感族群不健康'
# aqi=122 county='嘉義縣' date=datetime.datetime(2024, 3, 15, 6, 0) lat=23.554839 lon=120.345531 pm25=47.0 pollutant='細懸浮微粒' site_name='新港' status='對敏感族群不健康'
# aqi=108 county='雲林縣' date=datetime.datetime(2024, 3, 15, 6, 0) lat=23.757547 lon=120.348742 pm25=36.0 pollutant='細懸浮微粒' site_name='崙背' status='對敏感族群不健康'
# aqi=137 county='雲林縣' date=datetime.datetime(2024, 3, 15, 6, 0) lat=23.711853 lon=120.544994 pm25=54.0 pollutant='細懸浮微粒' site_name='斗六' status='對敏感族群不健康'
# aqi=87 county='南投縣' date=datetime.datetime(2024, 3, 15, 6, 0) lat=23.913 lon=120.685306 pm25=26.0 pollutant='細懸浮微粒' site_name='南投' status='普通'
# aqi=109 county='彰化縣' date=datetime.datetime(2024, 3, 15, 6, 0) lat=23.925175 lon=120.409653 pm25=30.0 pollutant='細懸浮微粒' site_name='二林' status='對敏感族群不健康'
# aqi=86 county='彰化縣' date=datetime.datetime(2024, 3, 15, 6, 0) lat=24.131672 lon=120.469061 pm25=22.0 pollutant='細懸浮微粒' site_name='線西' status='普通'
# aqi=99 county='彰化縣' date=datetime.datetime(2024, 3, 15, 6, 0) lat=24.066 lon=120.541519 pm25=28.0 pollutant='細懸浮微粒' site_name='彰化' status='普通'
# aqi=107 county='臺中市' date=datetime.datetime(2024, 3, 15, 6, 0) lat=24.162197 lon=120.616917 pm25=35.0 pollutant='細懸浮微粒' site_name='西屯' status='對敏感族群不健康'
# aqi=101 county='臺中市' date=datetime.datetime(2024, 3, 15, 6, 0) lat=24.151958 lon=120.641092 pm25=40.0 pollutant='細懸浮微粒' site_name='忠明' status='對敏感族群不健康'
# aqi=122 county='臺中市' date=datetime.datetime(2024, 3, 15, 6, 0) lat=24.09961111 lon=120.67844444 pm25=49.0 pollutant='細懸浮微粒' site_name='大里' status='對敏感族群不健康'
# aqi=94 county='臺中市' date=datetime.datetime(2024, 3, 15, 6, 0) lat=24.225628 lon=120.568794 pm25=22.0 pollutant='細懸浮微粒' site_name='沙鹿' status='普通'
# aqi=70 county='臺中市' date=datetime.datetime(2024, 3, 15, 6, 0) lat=24.25699731 lon=120.74252414 pm25=18.0 pollutant='細懸浮微粒' site_name='豐原' status='普通'
# aqi=82 county='苗栗縣' date=datetime.datetime(2024, 3, 15, 6, 0) lat=24.38248443 lon=120.75956754 pm25=34.0 pollutant='細懸浮微粒' site_name='三義' status='普通'
# aqi=89 county='苗栗縣' date=datetime.datetime(2024, 3, 15, 6, 0) lat=24.56499183 lon=120.82011468 pm25=32.0 pollutant='細懸浮微粒' site_name='苗栗' status='普通'
# aqi=88 county='苗栗縣' date=datetime.datetime(2024, 3, 15, 6, 0) lat=24.69690679 lon=120.89869286 pm25=28.0 pollutant='細懸浮微粒' site_name='頭份' status='普通'
# aqi=105 county='新竹市' date=datetime.datetime(2024, 3, 15, 6, 0) lat=24.8056356 lon=120.97236752 pm25=32.0 pollutant='細懸浮微粒' site_name='新竹' status='對敏感族群不健康'
# aqi=67 county='新竹縣' date=datetime.datetime(2024, 3, 15, 6, 0) lat=24.74091408 lon=121.08895493 pm25=20.0 pollutant='細懸浮微粒' site_name='竹東' status='普通'
# aqi=149 county='新竹縣' date=datetime.datetime(2024, 3, 15, 6, 0) lat=24.90009696 lon=121.03886894 pm25=54.0 pollutant='細懸浮微粒' site_name='湖口' status='對敏感族群不健康'
# aqi=109 county='桃園市' date=datetime.datetime(2024, 3, 15, 6, 0) lat=24.86400048 lon=121.21645772 pm25=25.0 pollutant='細懸浮微粒' site_name='龍潭' status='對敏感族群不健康'
# aqi=127 county='桃園市' date=datetime.datetime(2024, 3, 15, 6, 0) lat=24.952786 lon=121.203986 pm25=38.0 pollutant='細懸浮微粒' site_name='平鎮' status='對敏感族群不健康'
# aqi=129 county='桃園市' date=datetime.datetime(2024, 3, 15, 6, 0) lat=25.03556747 lon=121.08283092 pm25=64.0 pollutant='細懸浮微粒' site_name='觀音' status='對敏感族群不健康'
# aqi=120 county='桃園市' date=datetime.datetime(2024, 3, 15, 6, 0) lat=25.06100357 lon=121.20251473 pm25=56.0 pollutant='細懸浮微粒' site_name='大園' status='對敏感族群不健康'
# ...
# aqi=88 county='臺中市' date=datetime.datetime(2024, 3, 14, 23, 0) lat=24.225628 lon=120.568794 pm25=34.0 pollutant='細懸浮微粒' site_name='沙鹿' status='普通'
# aqi=92 county='臺中市' date=datetime.datetime(2024, 3, 14, 23, 0) lat=24.25699731 lon=120.74252414 pm25=34.0 pollutant='細懸浮微粒' site_name='豐原' status='普通'
# aqi=83 county='苗栗縣' date=datetime.datetime(2024, 3, 14, 23, 0) lat=24.38248443 lon=120.75956754 pm25=17.0 pollutant='細懸浮微粒' site_name='三義' status='普通'
# aqi=84 county='苗栗縣' date=datetime.datetime(2024, 3, 14, 23, 0) lat=24.56499183 lon=120.82011468 pm25=33.0 pollutant='細懸浮微粒' site_name='苗栗' status='普通'
# aqi=94 county='苗栗縣' date=datetime.datetime(2024, 3, 14, 23, 0) lat=24.69690679 lon=120.89869286 pm25=36.0 pollutant='細懸浮微粒' site_name='頭份' status='普通'
# aqi=108 county='新竹市' date=datetime.datetime(2024, 3, 14, 23, 0) lat=24.8056356 lon=120.97236752 pm25=46.0 pollutant='細懸浮微粒' site_name='新竹' status='對敏感族群不健康'
# aqi=89 county='新竹縣' date=datetime.datetime(2024, 3, 14, 23, 0) lat=24.74091408 lon=121.08895493 pm25=24.0 pollutant='細懸浮微粒' site_name='竹東' status='普通'
# aqi=112 county='新竹縣' date=datetime.datetime(2024, 3, 14, 23, 0) lat=24.90009696 lon=121.03886894 pm25=44.0 pollutant='細懸浮微粒' site_name='湖口' status='對敏感族群不健康'
# aqi=133 county='桃園市' date=datetime.datetime(2024, 3, 14, 23, 0) lat=24.86400048 lon=121.21645772 pm25=68.0 pollutant='細懸浮微粒' site_name='龍潭' status='對敏感族群不健康'
# aqi=107 county='桃園市' date=datetime.datetime(2024, 3, 14, 23, 0) lat=24.952786 lon=121.203986 pm25=51.0 pollutant='細懸浮微粒' site_name='平鎮' status='對敏感族群不健康'
# aqi=77 county='桃園市' date=datetime.datetime(2024, 3, 14, 23, 0) lat=25.03556747 lon=121.08283092 pm25=29.0 pollutant='細懸浮微粒' site_name='觀音' status='普通'
# aqi=86 county='桃園市' date=datetime.datetime(2024, 3, 14, 23, 0) lat=25.06100357 lon=121.20251473 pm25=30.0 pollutant='細懸浮微粒' site_name='大園' status='普通'
# aqi=106 county='桃園市' date=datetime.datetime(2024, 3, 14, 23, 0) lat=24.9947107 lon=121.30500531 pm25=29.0 pollutant='細懸浮微粒' site_name='桃園' status='對敏感族群不健康'
# aqi=98 county='臺北市' date=datetime.datetime(2024, 3, 14, 23, 0) lat=25.06331455 lon=121.51342074 pm25=30.0 pollutant='細懸浮微粒' site_name='大同' status='普通'
# aqi=86 county='臺北市' date=datetime.datetime(2024, 3, 14, 23, 0) lat=25.05 lon=121.578611 pm25=30.0 pollutant='細懸浮微粒' site_name='松山' status='普通'
# aqi=81 county='臺北市' date=datetime.datetime(2024, 3, 14, 23, 0) lat=25.020608 lon=121.529556 pm25=25.0 pollutant='細懸浮微粒' site_name='古亭' status='普通'
# aqi=83 county='臺北市' date=datetime.datetime(2024, 3, 14, 23, 0) lat=25.046503 lon=121.507972 pm25=19.0 pollutant='細懸浮微粒' site_name='萬華' status='普通'
# aqi=87 county='臺北市' date=datetime.datetime(2024, 3, 14, 23, 0) lat=25.062361 lon=121.526528 pm25=25.0 pollutant='細懸浮微粒' site_name='中山' status='普通'
# aqi=75 county='臺北市' date=datetime.datetime(2024, 3, 14, 23, 0) lat=25.10334003 lon=121.51666356 pm25=20.0 pollutant='細懸浮微粒' site_name='士林' status='普通'
# aqi=84 county='新北市' date=datetime.datetime(2024, 3, 14, 23, 0) lat=25.1645 lon=121.449239 pm25=24.0 pollutant='細懸浮微粒' site_name='淡水' status='普通'
# aqi=95 county='新北市' date=datetime.datetime(2024, 3, 14, 23, 0) lat=25.07798949 lon=121.36548982 pm25=22.0 pollutant='細懸浮微粒' site_name='林口' status='普通'
# aqi=93 county='新北市' date=datetime.datetime(2024, 3, 14, 23, 0) lat=25.06895 lon=121.481028 pm25=25.0 pollutant='細懸浮微粒' site_name='菜寮' status='普通'
# aqi=98 county='新北市' date=datetime.datetime(2024, 3, 14, 23, 0) lat=25.037972 lon=121.4325 pm25=36.0 pollutant='細懸浮微粒' site_name='新莊' status='普通'
# aqi=77 county='新北市' date=datetime.datetime(2024, 3, 14, 23, 0) lat=25.012972 lon=121.458667 pm25=22.0 pollutant='細懸浮微粒' site_name='板橋' status='普通'
# aqi=91 county='新北市' date=datetime.datetime(2024, 3, 14, 23, 0) lat=24.982528 lon=121.451861 pm25=17.0 pollutant='細懸浮微粒' site_name='土城' status='普通'
# aqi=74 county='新北市' date=datetime.datetime(2024, 3, 14, 23, 0) lat=24.977222 lon=121.537778 pm25=22.0 pollutant='細懸浮微粒' site_name='新店' status='普通'
# aqi=58 county='新北市' date=datetime.datetime(2024, 3, 14, 23, 0) lat=25.179667 lon=121.689881 pm25=14.0 pollutant='細懸浮微粒' site_name='萬里' status='普通'
# aqi=62 county='新北市' date=datetime.datetime(2024, 3, 14, 23, 0) lat=25.06624 lon=121.64081 pm25=19.0 pollutant='細懸浮微粒' site_name='汐止' status='普通'
# aqi=59 county='基隆市' date=datetime.datetime(2024, 3, 14, 23, 0) lat=25.129167 lon=121.760056 pm25=22.0 pollutant='細懸浮微粒' site_name='基隆' status='普通'
# aqi=80 county='屏東縣' date=datetime.datetime(2024, 3, 14, 22, 0) lat=22.260899 lon=120.651472 pm25=17.0 pollutant='臭氧八小時' site_name='屏東(枋山)' status='普通'
# aqi=113 county='新北市' date=datetime.datetime(2024, 3, 14, 22, 0) lat=24.94902778 lon=121.38352778 pm25=44.0 pollutant='細懸浮微粒' site_name='新北(樹林)' status='對敏感族群不健康'
# aqi=97 county='屏東縣' date=datetime.datetime(2024, 3, 14, 22, 0) lat=22.35222 lon=120.37722 pm25=27.0 pollutant='臭氧八小時' site_name='屏東(琉球)' status='普通'
# aqi=104 county='臺南市' date=datetime.datetime(2024, 3, 14, 22, 0) lat=23.17904722 lon=120.24583056 pm25=40.0 pollutant='細懸浮微粒' site_name='臺南(麻豆)' status='對敏感族群不健康'
# aqi=92 county='高雄市' date=datetime.datetime(2024, 3, 14, 22, 0) lat=22.87985556 lon=120.24535 pm25=43.0 pollutant='細懸浮微粒' site_name='高雄(湖內)' status='普通'
# aqi=105 county='彰化縣' date=datetime.datetime(2024, 3, 14, 22, 0) lat=23.96117 lon=120.56373 pm25=34.0 pollutant='細懸浮微粒' site_name='彰化(員林)' status='對敏感族群不健康'
# aqi=79 county='彰化縣' date=datetime.datetime(2024, 3, 14, 22, 0) lat=23.85493056 lon=120.26964167 pm25=28.0 pollutant='細懸浮微粒' site_name='大城' status='普通'
# aqi=61 county='新北市' date=datetime.datetime(2024, 3, 14, 22, 0) lat=25.29681695 lon=121.53656894 pm25=20.0 pollutant='臭氧八小時' site_name='富貴角' status='普通'
# aqi=88 county='雲林縣' date=datetime.datetime(2024, 3, 14, 22, 0) lat=23.753506 lon=120.251825 pm25=33.0 pollutant='細懸浮微粒' site_name='麥寮' status='普通'
# aqi=60 county='臺東縣' date=datetime.datetime(2024, 3, 14, 22, 0) lat=23.045083 lon=121.161933 pm25=15.0 pollutant='細懸浮微粒' site_name='關山' status='普通'
# aqi=71 county='澎湖縣' date=datetime.datetime(2024, 3, 14, 22, 0) lat=23.569031 lon=119.566158 pm25=16.0 pollutant='臭氧八小時' site_name='馬公' status='普通'
# aqi=122 county='金門縣' date=datetime.datetime(2024, 3, 14, 22, 0) lat=24.432133 lon=118.312256 pm25=52.0 pollutant='細懸浮微粒' site_name='金門' status='對敏感族群不健康'
# aqi=116 county='連江縣' date=datetime.datetime(2024, 3, 14, 22, 0) lat=26.15188416 lon=119.93149378 pm25=27.0 pollutant='細懸浮微粒' site_name='馬祖' status='對敏感族群不健康'
# aqi=73 county='南投縣' date=datetime.datetime(2024, 3, 14, 22, 0) lat=23.968842 lon=120.967903 pm25=21.0 pollutant='細懸浮微粒' site_name='埔里' status='普通'
# aqi=150 county='高雄市' date=datetime.datetime(2024, 3, 14, 22, 0) lat=22.608711 lon=120.312017 pm25=27.0 pollutant='臭氧八小時' site_name='復興' status='對敏感族群不健康'
# aqi=83 county='新北市' date=datetime.datetime(2024, 3, 14, 22, 0) lat=25.017 lon=121.516306 pm25=25.0 pollutant='細懸浮微粒' site_name='永和' status='普通'
# aqi=114 county='南投縣' date=datetime.datetime(2024, 3, 14, 22, 0) lat=23.756389 lon=120.677306 pm25=42.0 pollutant='細懸浮微粒' site_name='竹山' status='對敏感族群不健康'
# aqi=119 county='桃園市' date=datetime.datetime(2024, 3, 14, 22, 0) lat=24.953278 lon=121.221667 pm25=54.0 pollutant='細懸浮微粒' site_name='中壢' status='對敏感族群不健康'
# aqi=98 county='新北市' date=datetime.datetime(2024, 3, 14, 22, 0) lat=25.072611 lon=121.493806 pm25=27.0 pollutant='細懸浮微粒' site_name='三重' status='普通'
# aqi=69 county='宜蘭縣' date=datetime.datetime(2024, 3, 14, 22, 0) lat=24.632203 lon=121.792928 pm25=23.0 pollutant='細懸浮微粒' site_name='冬山' status='普通'
# aqi=63 county='宜蘭縣' date=datetime.datetime(2024, 3, 14, 22, 0) lat=24.747917 lon=121.746394 pm25=19.0 pollutant='細懸浮微粒' site_name='宜蘭' status='普通'
# aqi=64 county='臺北市' date=datetime.datetime(2024, 3, 14, 22, 0) lat=25.182722 lon=121.529583 pm25=21.0 pollutant='細懸浮微粒' site_name='陽明' status='普通'
# aqi=70 county='花蓮縣' date=datetime.datetime(2024, 3, 14, 22, 0) lat=23.971306 lon=121.599769 pm25=26.0 pollutant='細懸浮微粒' site_name='花蓮' status='普通'
# aqi=60 county='臺東縣' date=datetime.datetime(2024, 3, 14, 22, 0) lat=22.755358 lon=121.15045 pm25=17.0 pollutant='細懸浮微粒' site_name='臺東' status='普通'
# aqi=93 county='屏東縣' date=datetime.datetime(2024, 3, 14, 22, 0) lat=21.958069 lon=120.788928 pm25=19.0 pollutant='臭氧八小時' site_name='恆春' status='普通'
# aqi=85 county='屏東縣' date=datetime.datetime(2024, 3, 14, 22, 0) lat=22.523108 lon=120.561175 pm25=31.0 pollutant='細懸浮微粒' site_name='潮州' status='普通'
# aqi=122 county='屏東縣' date=datetime.datetime(2024, 3, 14, 22, 0) lat=22.673081 lon=120.488033 pm25=37.0 pollutant='臭氧八小時' site_name='屏東' status='對敏感族群不健康'
# aqi=108 county='高雄市' date=datetime.datetime(2024, 3, 14, 22, 0) lat=22.565833 lon=120.337736 pm25=33.0 pollutant='臭氧八小時' site_name='小港' status='對敏感族群不健康'
# aqi=151 county='高雄市' date=datetime.datetime(2024, 3, 14, 22, 0) lat=22.6044507 lon=120.30833356 pm25=31.0 pollutant='臭氧八小時' site_name='前鎮' status='對所有族群不健康'
# aqi=146 county='高雄市' date=datetime.datetime(2024, 3, 14, 22, 0) lat=22.63390278 lon=120.28676111 pm25=39.0 pollutant='臭氧八小時' site_name='前金' status='對敏感族群不健康'
# aqi=132 county='高雄市' date=datetime.datetime(2024, 3, 14, 22, 0) lat=22.674861 lon=120.292917 pm25=39.0 pollutant='臭氧八小時' site_name='左營' status='對敏感族群不健康'
# aqi=104 county='高雄市' date=datetime.datetime(2024, 3, 14, 22, 0) lat=22.733667 lon=120.328289 pm25=64.0 pollutant='細懸浮微粒' site_name='楠梓' status='對敏感族群不健康'
# aqi=104 county='高雄市' date=datetime.datetime(2024, 3, 14, 22, 0) lat=22.4795 lon=120.41175 pm25=32.0 pollutant='臭氧八小時' site_name='林園' status='對敏感族群不健康'
# aqi=108 county='高雄市' date=datetime.datetime(2024, 3, 14, 22, 0) lat=22.56413611 lon=120.425311 pm25=39.0 pollutant='臭氧八小時' site_name='大寮' status='對敏感族群不健康'
# aqi=115 county='高雄市' date=datetime.datetime(2024, 3, 14, 22, 0) lat=22.628126 lon=120.357422 pm25=34.0 pollutant='臭氧八小時' site_name='鳳山' status='對敏感族群不健康'
# aqi=166 county='高雄市' date=datetime.datetime(2024, 3, 14, 22, 0) lat=22.689056 lon=120.332631 pm25=48.0 pollutant='臭氧八小時' site_name='仁武' status='對所有族群不健康'
# aqi=107 county='高雄市' date=datetime.datetime(2024, 3, 14, 22, 0) lat=22.757506 lon=120.305689 pm25=46.0 pollutant='細懸浮微粒' site_name='橋頭' status='對敏感族群不健康'
# aqi=101 county='高雄市' date=datetime.datetime(2024, 3, 14, 22, 0) lat=22.883583 lon=120.530542 pm25=35.0 pollutant='臭氧八小時' site_name='美濃' status='對敏感族群不健康'
# aqi=106 county='臺南市' date=datetime.datetime(2024, 3, 14, 22, 0) lat=22.98928311 lon=120.21947897 pm25=45.0 pollutant='細懸浮微粒' site_name='臺南' status='對敏感族群不健康'
# aqi=107 county='臺南市' date=datetime.datetime(2024, 3, 14, 22, 0) lat=23.048197 lon=120.2175 pm25=40.0 pollutant='細懸浮微粒' site_name='安南' status='對敏感族群不健康'
# aqi=100 county='臺南市' date=datetime.datetime(2024, 3, 14, 22, 0) lat=23.11337642 lon=120.29740529 pm25=34.0 pollutant='細懸浮微粒' site_name='善化' status='普通'
# aqi=104 county='臺南市' date=datetime.datetime(2024, 3, 14, 22, 0) lat=23.305633 lon=120.31725 pm25=38.0 pollutant='細懸浮微粒' site_name='新營' status='對敏感族群不健康'
# aqi=125 county='嘉義市' date=datetime.datetime(2024, 3, 14, 22, 0) lat=23.46477865 lon=120.44125148 pm25=53.0 pollutant='細懸浮微粒' site_name='嘉義' status='對敏感族群不健康'
# aqi=74 county='雲林縣' date=datetime.datetime(2024, 3, 14, 22, 0) lat=23.702175 lon=120.19933333 pm25=25.0 pollutant='細懸浮微粒' site_name='臺西' status='普通'
# aqi=104 county='嘉義縣' date=datetime.datetime(2024, 3, 14, 22, 0) lat=23.46538 lon=120.2478 pm25=35.0 pollutant='細懸浮微粒' site_name='朴子' status='對敏感族群不健康'
# aqi=110 county='嘉義縣' date=datetime.datetime(2024, 3, 14, 22, 0) lat=23.554839 lon=120.345531 pm25=41.0 pollutant='細懸浮微粒' site_name='新港' status='對敏感族群不健康'
# aqi=105 county='雲林縣' date=datetime.datetime(2024, 3, 14, 22, 0) lat=23.757547 lon=120.348742 pm25=38.0 pollutant='細懸浮微粒' site_name='崙背' status='對敏感族群不健康'
# aqi=122 county='雲林縣' date=datetime.datetime(2024, 3, 14, 22, 0) lat=23.711853 lon=120.544994 pm25=48.0 pollutant='細懸浮微粒' site_name='斗六' status='對敏感族群不健康'
# aqi=93 county='南投縣' date=datetime.datetime(2024, 3, 14, 22, 0) lat=23.913 lon=120.685306 pm25=39.0 pollutant='細懸浮微粒' site_name='南投' status='普通'
# aqi=107 county='彰化縣' date=datetime.datetime(2024, 3, 14, 22, 0) lat=23.925175 lon=120.409653 pm25=39.0 pollutant='細懸浮微粒' site_name='二林' status='對敏感族群不健康'
# aqi=80 county='彰化縣' date=datetime.datetime(2024, 3, 14, 22, 0) lat=24.131672 lon=120.469061 pm25=32.0 pollutant='細懸浮微粒' site_name='線西' status='普通'
# aqi=86 county='彰化縣' date=datetime.datetime(2024, 3, 14, 22, 0) lat=24.066 lon=120.541519 pm25=30.0 pollutant='細懸浮微粒' site_name='彰化' status='普通'
# aqi=92 county='臺中市' date=datetime.datetime(2024, 3, 14, 22, 0) lat=24.162197 lon=120.616917 pm25=32.0 pollutant='細懸浮微粒' site_name='西屯' status='普通'
# aqi=92 county='臺中市' date=datetime.datetime(2024, 3, 14, 22, 0) lat=24.151958 lon=120.641092 pm25=35.0 pollutant='細懸浮微粒' site_name='忠明' status='普通'
# aqi=105 county='臺中市' date=datetime.datetime(2024, 3, 14, 22, 0) lat=24.09961111 lon=120.67844444 pm25=39.0 pollutant='細懸浮微粒' site_name='大里' status='對敏感族群不健康'
# aqi=84 county='臺中市' date=datetime.datetime(2024, 3, 14, 22, 0) lat=24.225628 lon=120.568794 pm25=31.0 pollutant='細懸浮微粒' site_name='沙鹿' status='普通'
# aqi=91 county='臺中市' date=datetime.datetime(2024, 3, 14, 22, 0) lat=24.25699731 lon=120.74252414 pm25=26.0 pollutant='細懸浮微粒' site_name='豐原' status='普通'
# aqi=87 county='苗栗縣' date=datetime.datetime(2024, 3, 14, 22, 0) lat=24.38248443 lon=120.75956754 pm25=27.0 pollutant='細懸浮微粒' site_name='三義' status='普通'
# aqi=82 county='苗栗縣' date=datetime.datetime(2024, 3, 14, 22, 0) lat=24.56499183 lon=120.82011468 pm25=35.0 pollutant='細懸浮微粒' site_name='苗栗' status='普通'
# aqi=90 county='苗栗縣' date=datetime.datetime(2024, 3, 14, 22, 0) lat=24.69690679 lon=120.89869286 pm25=32.0 pollutant='細懸浮微粒' site_name='頭份' status='普通'
# aqi=102 county='新竹市' date=datetime.datetime(2024, 3, 14, 22, 0) lat=24.8056356 lon=120.97236752 pm25=48.0 pollutant='細懸浮微粒' site_name='新竹' status='對敏感族群不健康'
# aqi=91 county='新竹縣' date=datetime.datetime(2024, 3, 14, 22, 0) lat=24.74091408 lon=121.08895493 pm25=32.0 pollutant='細懸浮微粒' site_name='竹東' status='普通'
# aqi=106 county='新竹縣' date=datetime.datetime(2024, 3, 14, 22, 0) lat=24.90009696 lon=121.03886894 pm25=49.0 pollutant='細懸浮微粒' site_name='湖口' status='對敏感族群不健康'
# aqi=119 county='桃園市' date=datetime.datetime(2024, 3, 14, 22, 0) lat=24.86400048 lon=121.21645772 pm25=60.0 pollutant='細懸浮微粒' site_name='龍潭' status='對敏感族群不健康'
# aqi=96 county='桃園市' date=datetime.datetime(2024, 3, 14, 22, 0) lat=24.952786 lon=121.203986 pm25=46.0 pollutant='細懸浮微粒' site_name='平鎮' status='普通'
# aqi=74 county='桃園市' date=datetime.datetime(2024, 3, 14, 22, 0) lat=25.03556747 lon=121.08283092 pm25=29.0 pollutant='細懸浮微粒' site_name='觀音' status='普通'
# aqi=85 county='桃園市' date=datetime.datetime(2024, 3, 14, 22, 0) lat=25.06100357 lon=121.20251473 pm25=36.0 pollutant='細懸浮微粒' site_name='大園' status='普通'
# aqi=109 county='桃園市' date=datetime.datetime(2024, 3, 14, 22, 0) lat=24.9947107 lon=121.30500531 pm25=55.0 pollutant='細懸浮微粒' site_name='桃園' status='對敏感族群不健康'
# aqi=101 county='臺北市' date=datetime.datetime(2024, 3, 14, 22, 0) lat=25.06331455 lon=121.51342074 pm25=31.0 pollutant='細懸浮微粒' site_name='大同' status='對敏感族群不健康'
# aqi=90 county='臺北市' date=datetime.datetime(2024, 3, 14, 22, 0) lat=25.05 lon=121.578611 pm25=29.0 pollutant='細懸浮微粒' site_name='松山' status='普通'
# aqi=84 county='臺北市' date=datetime.datetime(2024, 3, 14, 22, 0) lat=25.020608 lon=121.529556 pm25=23.0 pollutant='細懸浮微粒' site_name='古亭' status='普通'
# aqi=89 county='臺北市' date=datetime.datetime(2024, 3, 14, 22, 0) lat=25.046503 lon=121.507972 pm25=26.0 pollutant='細懸浮微粒' site_name='萬華' status='普通'
# aqi=90 county='臺北市' date=datetime.datetime(2024, 3, 14, 22, 0) lat=25.062361 lon=121.526528 pm25=24.0 pollutant='細懸浮微粒' site_name='中山' status='普通'
# aqi=79 county='臺北市' date=datetime.datetime(2024, 3, 14, 22, 0) lat=25.10334003 lon=121.51666356 pm25=15.0 pollutant='細懸浮微粒' site_name='士林' status='普通'
# aqi=86 county='新北市' date=datetime.datetime(2024, 3, 14, 22, 0) lat=25.1645 lon=121.449239 pm25=38.0 pollutant='細懸浮微粒' site_name='淡水' status='普通'
# aqi=96 county='新北市' date=datetime.datetime(2024, 3, 14, 22, 0) lat=25.07798949 lon=121.36548982 pm25=36.0 pollutant='細懸浮微粒' site_name='林口' status='普通'
