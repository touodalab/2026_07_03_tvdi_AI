# %%
import pydantic
print(pydantic.__version__)
# Out:
# 2.13.4

# %%
from pydantic import BaseModel

class Person(BaseModel):
    first_name: str
    last_name: str
    age: int

# %%
p:Person = Person(first_name="John", last_name="Smith", age=42)
print(p.first_name)
print(p.last_name)
print(p.age)
# Out:
# John
# Smith
# 42

# %%
print(repr(p))
# Out:
# Person(first_name='John', last_name='Smith', age=42)

# %%
#自動型態轉換 (Type Coercion)

p1:Person = Person(first_name="John", last_name="Smith", age="42")
print(repr(p1))
# Out:
# Person(first_name='John', last_name='Smith', age=42)

# %%
#驗證錯誤 (ValidationError)
from pydantic import ValidationError
try:
    p2:Person = Person(first_name="John", last_name="Smith", age="42a")
except ValidationError as e:
    print(e)
except Exception as e:
    print(f"不知明的錯誤{e}")
# Out:
# 1 validation error for Person
# age
#   Input should be a valid integer, unable to parse string as an integer [type=int_parsing, input_value='42a', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.13/v/int_parsing

# %%
# 反序列化 (Deserializing Data)
data = {
    "first_name": "John",
    "last_name": "Smith",
    "age": "42"
}

p3: Person = Person.model_validate(data)
print(repr(p3))
# Out:
# Person(first_name='John', last_name='Smith', age=42)

# %%
data_json = '''
{
    "first_name": "John",
    "last_name": "Smith",
    "age":42
}
'''

p4:Person = Person.model_validate_json(data_json)
print(repr(p4))
# Out:
# Person(first_name='John', last_name='Smith', age=42)

# %%
class Person1(BaseModel):
    first_name: str
    last_name: str
    age: int = 0

# %%
print(Person.model_fields)
# Out:
# {'first_name': FieldInfo(annotation=str, required=True), 'last_name': FieldInfo(annotation=str, required=True), 'age': FieldInfo(annotation=int, required=False, default=0)}

# %%
p4 = Person1(first_name="john", last_name='Smith', age=10)
print(repr(p4))
p5 = Person1(first_name="john", last_name='Smith')
print(repr(p5))
# Out:
# Person1(first_name='john', last_name='Smith', age=10)
# Person1(first_name='john', last_name='Smith', age=0)

# %%
class Person2(BaseModel):
    first_name: str | None = None
    last_name: str
    age: int = 0

p6 = Person2(last_name="Simit")
print(repr(p6))
# Out:
# Person2(first_name=None, last_name='Simit', age=0)

# %%
class Person3(BaseModel):
    first_name:str | None = None
    last_name: str
    age: int = 0
    lucky_numbers:list[int] = []

p7 = Person3(last_name="Smith", lucky_numbers=[1, "2", 3.0])
print(repr(p7))
# Out:
# Person3(first_name=None, last_name='Smith', age=0, lucky_numbers=[1, 2, 3])

# %%
from pydantic import Field
data = {
    "id":100,
    "First Name": "John",
    "LASTNAME": "Smith",
    "age in years": 42
}

class Person4(BaseModel):
    id_:int = Field(alias="id")
    first_name: str = Field(alias="First Name")
    last_name: str = Field(alias="LASTNAME")
    age:int = Field(alias="age in years",default=0)

p8 = Person4.model_validate(data)
print(repr(p8))
# Out:
# Person4(id_=100, first_name='John', last_name='Smith', age=0)

# %%
p8.model_dump_json()
# Out:
# '{"id_":100,"first_name":"John","last_name":"Smith","age":0}'

# %%
from datetime import datetime, timezone
from zoneinfo import ZoneInfo

datetime.now(ZoneInfo("Asia/Taipei"))
# Out:
# datetime.datetime(2026, 7, 17, 15, 55, 12, 868791, tzinfo=zoneinfo.ZoneInfo(key='Asia/Taipei'))

# %%
class Log(BaseModel):
    dt: datetime = datetime.now(ZoneInfo("Asia/Taipei"))
    message: str
log1 = Log(message="log1")
print(repr(log1))
# Out:
# Log(dt=datetime.datetime(2026, 7, 17, 15, 58, 25, 577789, tzinfo=zoneinfo.ZoneInfo(key='Asia/Taipei')), message='log1')

# %%
log2 = Log(message="log2")
print(repr(log2))
# Out:
# Log(dt=datetime.datetime(2026, 7, 17, 15, 58, 25, 577789, tzinfo=zoneinfo.ZoneInfo(key='Asia/Taipei')), message='log2')

# %%
class Log1(BaseModel):
    dt: datetime = Field(default_factory=lambda:datetime.now(ZoneInfo("Asia/Taipei")))
    message: str
log1 = Log1(message="log1")
print(repr(log1))
# Out:
# Log1(dt=datetime.datetime(2026, 7, 17, 16, 1, 31, 855347, tzinfo=zoneinfo.ZoneInfo(key='Asia/Taipei')), message='log1')

# %%
log2 = Log1(message="log2")
print(repr(log2))
# Out:
# Log1(dt=datetime.datetime(2026, 7, 17, 16, 2, 7, 806811, tzinfo=zoneinfo.ZoneInfo(key='Asia/Taipei')), message='log2')

# %%
def my_time():
    return datetime.now(ZoneInfo("Asia/Taipei"))

class Log2(BaseModel):
    dt: datetime = Field(default_factory=my_time)
    message: str
log1 = Log2(message="log1")
print(repr(log1))
# Out:
# Log2(dt=datetime.datetime(2026, 7, 17, 16, 6, 31, 534360, tzinfo=zoneinfo.ZoneInfo(key='Asia/Taipei')), message='log1')

# %%
data = {
    "firstName": "Arthur",
    "lastName": "Clarke",
    "born":{
        "place":{
            "country":"Lunar Colony",
            "city": "Central City"
        },
        "date":"2001-01-01"
    }
}

# %%
from datetime import date
class Place(BaseModel):
    country: str
    city: str

class Born(BaseModel):
    place:Place
    dt:date = Field(alias="date")
    
class Person(BaseModel):
    first_name:str = Field(alias="firstName")
    last_name:str = Field(alias="lastName")
    born:Born

p10 = Person.model_validate(data)
print(repr(p10))
# Out:
# Person(first_name='Arthur', last_name='Clarke', born=Born(place=Place(country='Lunar Colony', city='Central City'), dt=datetime.date(2001, 1, 1)))

# %%
p10.model_dump_json()
# Out:
# '{"first_name":"Arthur","last_name":"Clarke","born":{"place":{"country":"Lunar Colony","city":"Central City"},"dt":"2001-01-01"}}'

# %%
data = [
    {
    "year": "114",
    "bureau": "蘆洲分局",
    "unit": "更寮派出所",
    "location": "四維路5號",
    "build_case_unit": "自建案"
    },
    {
    "year": "114",
    "bureau": "蘆洲分局",
    "unit": "更寮派出所",
    "location": "四維路5號",
    "build_case_unit": "自建案"
    }
]

# %%
from pydantic import TypeAdapter
import requests

class VideoPosition(BaseModel):
    year:str
    bureau:str
    unit:str
    location:str
    build_case_unit: str

url = 'https://data.ntpc.gov.tw/api/datasets/1b72abe8-8862-4130-aeb8-178c1240e6c4/json?page=0&size=1000'
response = requests.get(url)
data = response.json()

adapter = TypeAdapter(list[VideoPosition])
list_position = adapter.validate_python(data)

list_position
# Out:
# [VideoPosition(year='114', bureau='蘆洲分局', unit='更寮派出所', location='四維路5號', build_case_unit='自建案'),
#  VideoPosition(year='114', bureau
build_case_unit='自建案'),
#  VideoPosition(year='114', bureau='汐止分局', unit='汐止派出所', location='汐碇路42號汐碇幹9號', build_case_unit='自建案'),
#  VideoPosition(year='114', bureau='汐止分局', unit='汐止派出所', location='汐碇路42號汐碇幹9號', build_case_unit='自建案'),
#  VideoPosition(year='114', bureau='汐止分局', unit='汐止派出所', location='汐碇路42號汐碇幹9支1', build_case_unit='自建案'),
#  VideoPosition(year='114', bureau='汐止分局', unit='汐止派出所', location='汐碇路42號汐碇幹9支1', build_case_unit='自建案'),
#  VideoPosition(year='114', bureau='土城分局', unit='清水派出所', location='清水路、明德路路口燈桿(79002)', build_case_unit='自建案'),
#  VideoPosition(year='114', bureau='土城分局', unit='清水派出所', location='金城路二段與明德路二段口（行人號誌桿）', build_case_unit='自建案'),
#  VideoPosition(year='114', bureau='土城分局', unit='清水派出所', location='金城路二段與明德路二段口(燈70521)', build_case_unit='自建案'),
#  VideoPosition(year='114', bureau='土城分局', unit='清水派出所', location='金城路二段與明德路二段口(燈70521)', build_case_unit='自建案'),
#  VideoPosition(year='114', bureau='土城分局', unit='金城派出所', location='金城路三段207巷口分隔島', build_case_unit='自建案'),
#  VideoPosition(year='114', bureau='土城分局', unit='金城派出所', location='延和路248號外牆', build_case_unit='自建案'),
#  VideoPosition(year='114', bureau='土城分局', unit='金城派出所', location='延和路227號前', build_case_unit='自建案'),
#  VideoPosition(year='114', bureau='土城分局', unit='金城派出所', location='永豐路13巷22號', build_case_unit='自建案'),
#  VideoPosition(year='114', bureau='土城分局', unit='金城派出所', location='永豐路13巷22號', build_case_unit='自建案'),
#  VideoPosition(year='114', bureau='樹林分局', unit='柑園派出所', location='柑園街1段353號前(柑園國小前路燈：63076)', build_case_unit='自建案'),
#  VideoPosition(year='114', bureau='樹林分局', unit='柑園派出所', location='柑園街1段與佳園路2段路口(號誌桿)', build_case_unit='自建案'),
#  VideoPosition(year='114', bureau='樹林分局', unit='柑園派出所', location='大義、佳園、三樹路口（三峽區三樹路250號前路燈）', build_case_unit='自建案'),
#  VideoPosition(year='114', bureau='樹林分局', unit='柑園派出所', location='柑園二橋（號誌桿）', build_case_unit='自建案'),
#  VideoPosition(year='114', bureau='樹林分局', unit='柑園派出所', location='柑園二橋（號誌桿）', build_case_unit='自建案'),
#  VideoPosition(year='114', bureau='樹林分局', unit='柑園派出所', location='佳園路二段95號路燈(61089)', build_case_unit='自建案'),
#  VideoPosition(year='114', bureau='樹林分局', unit='柑園派出所', location='佳園路二段77號前號誌桿', build_case_unit='自建案'),
#  VideoPosition(year='114', bureau='樹林分局', unit='柑園派出所', location='柑園街一段353號前、柑園國小前路燈(63076)', build_case_unit='自建案'),
#  VideoPosition(year='114', bureau='樹林分局', unit='柑園派出所', location='柑園街一段與佳園路二段路口號誌桿', build_case_unit='自建案'),
#  VideoPosition(year='114', bureau='樹林分局', unit='柑園派出所', location='柑園街二段362巷口電信桿', build_case_unit='自建案'),
#  VideoPosition(year='114', bureau='樹林分局', unit='柑園派出所', location='柑園街二段362巷口電信桿', build_case_unit='自建案'),
#  VideoPosition(year='114', bureau='樹林分局', unit='柑園派出所', location='柑園街二段384巷2號路燈(42131)', build_case_unit='自建案'),
#  VideoPosition(year='114', bureau='樹林分局', unit='柑園派出所', location='柑園街二段384巷2號路燈(42131)', build_case_unit='自建案'),
#  VideoPosition(year='114', bureau='樹林分局', unit='柑園派出所', location='佳園路二段15巷口號誌桿', build_case_unit='自建案'),
#  VideoPosition(year='114', bureau='樹林分局', unit='柑園派出所', location='佳園路二段15巷口號誌桿', build_case_unit='自建案'),
#  VideoPosition(year='114', bureau='樹林分局', unit='柑園派出所', location='柑園街二段303巷18-1號門口電信桿', build_case_unit='自建案'),
#  VideoPosition(year='114', bureau='樹林分局', unit='柑園派出所', location='柑園街二段303巷巷底涵洞附壁', build_case_unit='自建案'),
#  VideoPosition(year='114', bureau='樹林分局', unit='三多派出所', location='保安街二段253號前路燈(55072)', build_case_unit='自建案'),
#  VideoPosition(year='114', bureau='樹林分局', unit='三多派出所', location='中正、俊保路口路燈', build_case_unit='自建案'),
#  VideoPosition(year='114', bureau='樹林分局', unit='三多派出所', location='中正、俊保路口路燈', build_case_unit='自建案'),
#  VideoPosition(year='114', bureau='樹林分局', unit='三多派出所', location='中正三福街口', build_case_unit='自建案'),
#  VideoPosition(year='114', bureau='樹林分局', unit='三多派出所', location='中正、三福街口路燈(02013)', build_case_unit='自建案'),
#  VideoPosition(year='114', bureau='樹林分局', unit='三多派出所', location='中正、俊保路口', build_case_unit='自建案'),
#  VideoPosition(year='114', bureau='樹林分局', unit='三多派出所', location='三福街56巷口路燈(02097)', build_case_unit='自建案'),
#  VideoPosition(year='114', bureau='樹林分局', unit='三多派出所', location='三福街56巷口路燈(02097)', build_case_unit='自建案'),
#  VideoPosition(year='114', bureau='樹林分局', unit='三多派出所', location='保安街二段,光華街口號誌桿', build_case_unit='自建案'),
#  VideoPosition(year='114', bureau='樹林分局', unit='三多派出所', location='光華街號誌桿', build_case_unit='自建案'),
#  VideoPosition(year='114', bureau='樹林分局', unit='三多派出所', location='保安街三段71之3號路燈(55092)', build_case_unit='自建案'),
#  VideoPosition(year='114', bureau='樹林分局', unit='三多派出所', location='保安街三段71之3號對面號誌桿', build_case_unit='自建案'),
#  VideoPosition(year='114', bureau='樹林分局', unit='樹林派出所', location='八德、啟智往備前街全景', build_case_unit='自建案'),
#  VideoPosition(year='114', bureau='樹林分局', unit='樹林派出所', location='復興、八德街口（號誌桿）', build_case_unit='自建案'),
#  VideoPosition(year='114', bureau='樹林分局', unit='樹林派出所', location='復興、八德街口(號誌桿)', build_case_unit='自建案'),
#  VideoPosition(year='114', bureau='樹林分局', unit='樹林派出所', location='大安路與保安街口（路燈：52038）', build_case_unit='自建案'),
#  VideoPosition(year='114', bureau='樹林分局', unit='樹林派出所', location='大安路與保安街口（路燈：52038）', build_case_unit='自建案'),
#  VideoPosition(year='114', bureau='樹林分局', unit='樹林派出所', location='大安路、俊英街口（路燈：52015）', build_case_unit='自建案'),
#  VideoPosition(year='114', bureau='樹林分局', unit='樹林派出所', location='大安路、俊英街口（號誌桿）', build_case_unit='自建案'),
#  VideoPosition(year='114', bureau='樹林分局', unit='樹林派出所', location='保安街二段47號號誌桿', build_case_unit='自建案'),
#  VideoPosition(year='114', bureau='樹林分局', unit='樹林派出所', location='保安街二段47號號誌桿', build_case_unit='自建案'),
#  VideoPosition(year='114', bureau='樹林分局', unit='樹林派出所', location='保安街二段69號號誌桿', build_case_unit='自建案'),
#  VideoPosition(year='114', bureau='樹林分局', unit='樹林派出所', location='武林國小前（路燈：55060）', build_case_unit='自建案'),
#  VideoPosition(year='114', bureau='樹林分局', unit='樹林派出所', location='復興路102號旁（號誌桿）', build_case_unit='自建案'),
#  VideoPosition(year='114', bureau='樹林分局', unit='樹林派出所', location='鎮前街、保安街1段（號誌桿）', build_case_unit='自建案'),
#  VideoPosition(year='114', bureau='樹林分局', unit='樹林派出所', location='鎮前街、保安街1段（路名標示桿）', build_case_unit='自建案'),
#  VideoPosition(year='114', bureau='樹林分局', unit='樹林派出所', location='復興路390巷20號(樹林公八停車場)路燈', build_case_unit='自建案'),
#  VideoPosition(year='114', bureau='樹林分局', unit='樹林派出所', location='復興路390巷20號(樹林公八停車場)路燈', build_case_unit='自建案'),
#  VideoPosition(year='114', bureau='樹林分局', unit='樹林派出所', location='樹新路127號路燈(228160)', build_case_unit='自建案'),
#  VideoPosition(year='114', bureau='樹林分局', unit='樹林派出所', location='樹新路127號路燈(228160)-02', build_case_unit='自建案'),
#  VideoPosition(year='114', bureau='樹林分局', unit='樹林派出所', location='保順街97號旁路燈', build_case_unit='自建案'),
#  VideoPosition(year='114', bureau='樹林分局', unit='樹林派出所', location='保順街97號旁路燈-02', build_case_unit='自建案'),
#  VideoPosition(year='114', bureau='樹林分局', unit='樹林派出所', location='水源街32巷口號誌桿', build_case_unit='自建案'),
#  VideoPosition(year='114', bureau='樹林分局', unit='樹林派出所', location='水源街32巷口號誌桿-02', build_case_unit='自建案'),
#  VideoPosition(year='114', bureau='樹林分局', unit='彭厝派出所', location='水源街32巷口號誌桿-03', build_case_unit='自建案')]

# %%
# 序列化為 JSON
# list_position 是 list，需要用 TypeAdapter 來序列化
from pprint import pprint

adapter_json = TypeAdapter(list[VideoPosition])
json_str = adapter_json.dump_json(list_position)
pprint(json_str[:200].decde())
print(f"\n總共 {len(list_position)} 筆資料")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       1 # 序列化為 JSON
#       2 # list_position 是 list，需要用 TypeAdapter 來序列化
#       3 from pprint import pprint
#       4
# ----> 5 adapter_json = TypeAdapter(list[VideoPosition])
#       6 json_str = adapter_json.dump_json(list_position)
#       7 pprint(json_str[:200].decode())
#       8 print(f"\n總共 {len(list_position)} 筆資料")
#
# NameError: name 'TypeAdapter' is not defined
